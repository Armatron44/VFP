# %% [markdown]
# # Using `vfp` with refl1d
#
# In this notebook, we'll run through how to use refl1d with `vfp`. There's an analogous notebook for fitting a `vfp` model with refnx [here](vfp_with_refnx.ipynb).
#
# To demonstrate the `vfp` we'll model some NR data taken with a Si substrate. This data is included in the `vfp` package.
#
# Two NR contrasts were taken in a solid-liquid cell with dodecane ($\mathrm{C}_{12}\mathrm{H}_{26}$ \& $\mathrm{C}_{12}\mathrm{D}_{26}$).
#
# Two other contrasts were taken with the same substrate with solutions of glycerol monooleate, a surfactant, in $\mathrm{C}_{12}\mathrm{H}_{26}$ \& $\mathrm{C}_{12}\mathrm{D}_{26}$.

# %%
import pathlib
import matplotlib.pyplot as plt
import numpy as np
from functools import partial

from bumps.parameter import Parameter
from bumps.parameter import Parameter
from bumps.fitproblem import FitProblem 

from refl1d.experiment import Experiment
from refl1d.sample.material import SLD
from refl1d.probe import NeutronProbe

import vfp

# %% [markdown]
# ## Load data into `refl1d.probe.NeutronProbe`s
#
# The following two functions are used to load data stored in the vfp directory.
# The main function is `tof_loader`, which uses numpy to load reflectometry data
# and convert $Q_{z}$ to wavelength to be compatible with the `NeutronProbe` object from refl1d.
#
# <div class="alert alert-info">
#
# Notice that we are using `back_reflectivity=True` when creating the `NeutronProbe`s. By default, structures created by refl1d are expected to have the incident radiation propagate through air/vacuum (mainly used for hard condensed matter studies), and so structures are commonly expected to have a structure like so:
# $\text{Air} | \text{SiO}_{2} | \text{Si}$, so that the roughness of the $\mathrm{SiO}_{2}$ layer applies to the $\text{Air-SiO}_{2}$ interface, and the roughness of the $\text{Si}$ interface applies to the $\text{SiO}_{2}\text{-Si}$ interface. To be compatible with our structures, take the bare substrate in dodecane for example, we'd have to define our structure like:
# $\text{ddod} | \text{SiO}_{2} | \text{Si}$. `vfp` is designed to have no roughness for the last layer, much like `refnx`. However, by setting `back_relectivity=True`, we can switch this behaviour.
#
# </div>

# %%
def qt2l(q: np.ndarray, t: float) -> np.ndarray:
    """
    Get wavelength from q and theta from ToF data.
    
    Parameters
    ----------
    q : np.ndarray
        The magnitude of the scattering vector.
    t : float
        The scattering angle.
        
    Returns
    -------
    np.ndarray
        The wavelength at each datum.
    """
    return 4 * np.pi * np.sin(np.radians(t)) / q

def tof_loader(filename: str | pathlib.Path,
               t: float = 0.7, 
               dqoq: float = 0.03, 
               delimiter: str = "\t", 
               **kw) -> NeutronProbe:
    """
    Create `refl1d.probe.NeutronProbe` for each file, with given parameters.
    
    Parameters
    ----------
    filename: str | pathlib.Path
        Name of data file to load.
    t: float
        Incident angle data was collected with.
    dqoq: float
        Resolution data was collected with (sigma not FWHM).
    delimiter: str
        The delimiter between data entries in data file.
    kw : dict
        Keywords to be passed to NeutronProbe init.
    
    Returns
    -------
    NeutronProbe
    """
    q, r, dr = np.loadtxt(filename, delimiter=delimiter).T
    data_in = (r, dr)
    
    l = qt2l(q, t)
    # Convert the dq/q resolution into a dq value for each Q point
    dq = q * dqoq # refl1d works in sigma, not FWHM.

    probe_out = NeutronProbe(
        T=t, 
        dT=0, 
        L=l, 
        dL=0, 
        data=data_in, 
        dQo=dq, 
        resolution='normal',
        back_reflectivity=True,
        **kw 
    )

    return probe_out

# %%
dataset_dir = pathlib.Path(vfp.__path__[0]).parents[1] / 'docs'
data_fn_dict = {
    'ddod' : 'IvsQ_71299_71300_71301.dat',
    'hdod' : 'IvsQ_71313_71314_71315.dat',
    'hdod_gmo' : 'IvsQ_71332_71333_71334.dat',
    'ddod_gmo' : 'IvsQ_71357_71358_71359.dat'
}

# %%
tof_loader_partial = partial(tof_loader, t=0.7, delimiter=',')
probes = map(tof_loader_partial, (dataset_dir / file_name for file_name in data_fn_dict.values()))

# %%
si_dd_probe, si_hd_probe, si_hd_gmo_probe, si_dd_gmo_probe = probes

# %%
plt.errorbar(x=si_dd_probe.Q, 
             y=si_dd_probe.R, 
             yerr=si_dd_probe.dR, 
             marker='.', 
             linestyle='None',
             label=r'Si dd')
plt.errorbar(x=si_dd_gmo_probe.Q, 
             y=si_dd_gmo_probe.R, 
             yerr=si_dd_gmo_probe.dR, 
             marker='.', 
             linestyle='None',
             label=r'Si dd gmo')
plt.errorbar(x=si_hd_probe.Q, 
             y=si_hd_probe.R, 
             yerr=si_hd_probe.dR, 
             marker='.', 
             linestyle='None',
             label=r'Si hd')
plt.errorbar(x=si_hd_gmo_probe.Q, 
             y=si_hd_gmo_probe.R, 
             yerr=si_hd_gmo_probe.dR, 
             marker='.', 
             linestyle='None',
             label=r'Si hd gmo')
plt.legend(frameon=False)
plt.xscale('log') 
plt.yscale('log')
plt.xlabel(r'$Q$ / $\mathrm{\AA{}}^{-1}$')
plt.ylabel(r'$R\left(Q\right)$')
plt.show()

# %% [markdown]
# ## The model
# We'll model the bare Si data with a fronting of Si, and layer of $\mathrm{SiO}_{2}$ and a solvent backing.
#
# The SLDs of the materials will be fixed but we'll model the thickness of the $\mathrm{SiO}_{2}$ and the roughness of the interfaces between the materials.
#
# For those contrasts with GMO, we'll model a GMO layer with a fixed SLD of GMO = $0.21 \times 10 ^{-6}~$&#8491;$^{-2}$, a varying solvation, thickness and roughness.
#
# There will be the same interface width between $\mathrm{SiO}_{2}$ and the solvent and between $\mathrm{SiO}_{2}$ and GMO.

# %%
Si = SLD(rho=2.07, name='Si')
SiO2 = SLD(rho=3.47, name='SiO2')
gmo = SLD(rho=0.21, name='gmo')

hdod = SLD(rho=-0.46, name='hdod')
ddod = SLD(rho=6.7, name='ddod')

# lets vary the ddod but not the hdod.
ddod.rho.range(6, 6.7)
# Out:
# Parameter(ddod rho)

# %%
# define thickness and roughness parameters.
SiO2_thick = Parameter(value=3, name='SiO2_thick', vary=True, bounds=(1, 30))
gmo_thick = Parameter(value=20, name='gmo_thick', vary=True, bounds=(1, 30))

Si_SiO2_rough = Parameter(value=4, name='Si_SiO2_rough', vary=True, bounds=(1, 10))
SiO2_solv_rough = Parameter(2, name='SiO2_solv_rough', vary=True, bounds=(1, 10))

SiO2_gmo_rough = SiO2_solv_rough # set constraint.
gmo_solv_rough = Parameter(5, name='gmo_solv_rough', vary=True, bounds=(1, 10))

gmo_vf = Parameter(value=1, name='gmo_vf', vary=True, bounds=(0, 1))

# %% [markdown]
# ## refl1d works from backing to fronting...

# %%
# define the SLDs of the materials in two lists for the two contrasts.
dd_nslds = [Si.rho,
            SiO2.rho,
            ddod.rho]

hd_nslds = [Si.rho,
            SiO2.rho,
            hdod.rho]

dd_gmo_nslds = [Si.rho,
                SiO2.rho,
                gmo.rho * gmo_vf + ddod.rho * (1-gmo_vf),
                ddod.rho]

hd_gmo_nslds = [Si.rho,
                SiO2.rho,
                gmo.rho * gmo_vf + hdod.rho * (1-gmo_vf),
                hdod.rho]

# define the thicknesses of the all layers, including the fronting but not the backing.
list_of_thicknesses_bare = [0, SiO2_thick]
list_of_thicknesses_gmo = [0, SiO2_thick, gmo_thick]
# define the width the of the interfaces between the materials.
list_of_roughnesses_bare = [Si_SiO2_rough, SiO2_solv_rough]
list_of_roughnesses_gmo = [Si_SiO2_rough, SiO2_gmo_rough, gmo_solv_rough]

# use the list of SLDs, thicknesses and roughnesses to define refnxVFP objects.
dd_vfp_bare = vfp.refl1dVFP(nslds=dd_nslds,
                            thicknesses=list_of_thicknesses_bare,
                            roughnesses=list_of_roughnesses_bare)

hd_vfp_bare = vfp.refl1dVFP(nslds=hd_nslds,
                            thicknesses=list_of_thicknesses_bare,
                            roughnesses=list_of_roughnesses_bare)

dd_vfp_gmo = vfp.refl1dVFP(nslds=dd_gmo_nslds,
                           thicknesses=list_of_thicknesses_gmo,
                           roughnesses=list_of_roughnesses_gmo)

hd_vfp_gmo = vfp.refl1dVFP(nslds=hd_gmo_nslds,
                           thicknesses=list_of_thicknesses_gmo,
                           roughnesses=list_of_roughnesses_gmo)
# Out:
# C:\Users\sandy\OneDrive\PDRA - Job 2021-2024\VFP\src\vfp\vfp.py:748: UserWarning: If msld / isld parameters are part of a function (i.e f(p1, p2) = p1 + p2), they must be of type bumps.parameter.Parameter. Do not use material or SLD objects.
#   arr_attrs = [

# %%
# see the parameters in the refnxVFP
# these contain non varying parameters.
print(dd_vfp_gmo.layer_parameters())
# Out:
# {'nslds': [Parameter(Si rho), Parameter(SiO2 rho), Parameter(gmo rho), Parameter(gmo_vf), Parameter(ddod rho)], 'thicknesses': [Parameter(refl1dVFP - thicknesses - fronting), Parameter(SiO2_thick), Parameter(gmo_thick)], 'roughnesses': [Parameter(Si_SiO2_rough), Parameter(SiO2_solv_rough), Parameter(gmo_solv_rough)], 'islds': [Parameter(refl1dVFP - isld - fronting), Parameter(refl1dVFP - isld - layer 1), Parameter(refl1dVFP - isld - layer 2), Parameter(refl1dVFP - isld - backing)], 'mslds': [Parameter(refl1dVFP - msld - fronting), Parameter(refl1dVFP - msld - layer 1), Parameter(refl1dVFP - msld - layer 2), Parameter(refl1dVFP - msld - backing)]}

# %%
# the refnxVFP objects are refnx Component objects so can be placed in a refnx structure.
# place vfps between SLD objects.
dd_struc = Si | dd_vfp_bare | ddod
hd_struc = Si | hd_vfp_bare | hdod
dd_GMO_struc = Si | dd_vfp_gmo | ddod
hd_GMO_struc = Si | hd_vfp_gmo | hdod

# %%
# define instrument / nuisance parameters
si_dd_probe.intensity.range(0.8, 1.2)
si_dd_probe.intensity.name = "Si_dd_int"
si_hd_probe.intensity.range(0.8, 1.2)
si_hd_probe.intensity.name = "Si_hd_int"
si_dd_gmo_probe.intensity.range(0.8, 1.2)
si_dd_gmo_probe.intensity.name = "Si_gmo_dd_int"
si_hd_gmo_probe.intensity.range(0.8, 1.2)
si_hd_gmo_probe.intensity.name = "Si_gmo_hd_int"

si_dd_probe.background.value = 1e-6
si_dd_probe.background.range(1e-10, 1e-4)
si_dd_probe.background.name = "Si_dd_bkg"
si_hd_probe.background.value = 1e-6
si_hd_probe.background.range(1e-10, 1e-4)
si_hd_probe.background.name = "Si_hd_bkg"
si_dd_gmo_probe.background.range(1e-10, 1e-4)
si_dd_gmo_probe.background.value = 1e-6
si_dd_gmo_probe.background.name = "Si_gmo_dd_bkg"
si_hd_gmo_probe.background.range(1e-10, 1e-4)
si_hd_gmo_probe.background.value = 1e-6
si_hd_gmo_probe.background.name = "Si_gmo_hd_bkg"

# %%
exp_si_dd = Experiment(probe=si_dd_probe, sample=dd_struc)
exp_si_hd = Experiment(probe=si_hd_probe, sample=hd_struc)
exp_si_dd_gmo = Experiment(probe=si_dd_gmo_probe, sample=dd_GMO_struc)
exp_si_hd_gmo = Experiment(probe=si_hd_gmo_probe, sample=hd_GMO_struc)

# %%
problem = FitProblem([exp_si_dd, exp_si_hd, exp_si_dd_gmo, exp_si_hd_gmo])

# %%
# check model looks reasonable with starting parameters

# %matplotlib inline
for mod in problem.models:
    plt.errorbar(x=mod.probe.Q, y=mod.probe.R, yerr=mod.probe.dR, linestyle='None', marker='.')
    plt.plot(*mod.reflectivity(), color='k', zorder=10)
plt.xscale('log')
plt.yscale('log')

# %% [markdown]
# ## Fit via `bumps.fitters.fit`.
#
# It's more common to write a `refl1d` script and use the cli or the GUI.
# But we can do it interactively...

# %%
from bumps.fitters import fit

result = fit(problem, method="de", verbose=True, parallel=0, options=dict(steps=200))
# Out:
# step 1 cost 37.309(28)
#                                Si_dd_bkg |.........      1e-06 in [1e-10, 0.0001]
#                                Si_dd_int ....|.....          1 in [0.8, 1.2]
#                                 ddod rho .........|        6.7 in [6, 6.7]
#                            Si_SiO2_rough ...|......          4 in [1, 10]
#                          SiO2_solv_rough .|........          2 in [1, 10]
#                               SiO2_thick |.........          3 in [1, 30]
#                                Si_hd_bkg |.........      1e-06 in [1e-10, 0.0001]
#                                Si_hd_int ....|.....          1 in [0.8, 1.2]
#                            Si_gmo_dd_bkg |.........      1e-06 in [1e-10, 0.0001]
#                            Si_gmo_dd_int ....|.....          1 in [0.8, 1.2]
#                                   gmo_vf .........|          1 in [0, 1]
#                           gmo_solv_rough ....|.....          5 in [1, 10]
#                                gmo_thick ......|...         20 in [1, 30]
#                            Si_gmo_hd_bkg |.........      1e-06 in [1e-10, 0.0001]
#                            Si_gmo_hd_int ....|.....          1 in [0.8, 1.2]
# step 5 cost 37.309(28)
# step 10 cost 37.309(28)
# step 15 cost 37.309(28)
# step 20 cost 37.309(28)
# step 23 cost 37.309(28)
# step 27 cost 37.309(28)
# step 31 cost 37.309(28)
# step 35 cost 34.905(28)
# step 38 cost 23.172(28)
# step 42 cost 16.677(28)
# step 45 cost 15.992(28)
# step 49 cost 11.761(28)
# step 53 cost 11.761(28)
# step 56 cost 10.931(28)
# step 60 cost 10.244(28)
# step 63 cost 6.383(28)
# step 66 cost 6.256(28)
# step 70 cost 6.256(28)
# step 74 cost 6.256(28)
# step 77 cost 6.256(28)
# step 80 cost 5.233(28)
# step 83 cost 4.837(28)
# step 85 cost 4.837(28)
# step 88 cost 4.837(28)
# step 91 cost 3.443(28)
#                                Si_dd_bkg |......... 9.71067e-06 in [1e-10, 0.0001]
#                                Si_dd_int .....|....     1.0276 in [0.8, 1.2]
#                                 ddod rho .......|..    6.49969 in [6, 6.7]
#                            Si_SiO2_rough ...|......    4.03132 in [1, 10]
#                          SiO2_solv_rough ........|.    8.99767 in [1, 10]
#                               SiO2_thick .|........    4.49792 in [1, 30]
#                                Si_hd_bkg |......... 8.32718e-06 in [1e-10, 0.0001]
#                                Si_hd_int .....|....    1.02318 in [0.8, 1.2]
#                            Si_gmo_dd_bkg .|........ 1.19552e-05 in [1e-10, 0.0001]
#                            Si_gmo_dd_int ....|.....   0.969908 in [0.8, 1.2]
#                                   gmo_vf ......|...   0.665652 in [0, 1]
#                           gmo_solv_rough ...|......    4.08918 in [1, 10]
#                                gmo_thick .|........    5.29537 in [1, 30]
#                            Si_gmo_hd_bkg |......... 4.05125e-06 in [1e-10, 0.0001]
#                            Si_gmo_hd_int ....|.....   0.971481 in [0.8, 1.2]
# step 94 cost 3.443(28)
# step 96 cost 3.443(28)
# step 99 cost 3.443(28)
# step 101 cost 3.443(28)
# step 103 cost 3.443(28)
# step 106 cost 3.443(28)
# step 108 cost 3.443(28)
# step 110 cost 3.322(28)
# step 112 cost 3.307(28)
# step 115 cost 3.289(28)
# step 118 cost 3.119(28)
# step 120 cost 2.570(28)
# step 122 cost 2.570(28)
# step 124 cost 2.570(28)
# step 127 cost 2.570(28)
# step 129 cost 2.570(28)
# step 131 cost 2.570(28)
# step 133 cost 2.268(28)
# step 135 cost 2.268(28)
# step 137 cost 2.268(28)
# step 139 cost 2.268(28)
# step 141 cost 2.268(28)
#                                Si_dd_bkg |......... 8.45645e-06 in [1e-10, 0.0001]
#                                Si_dd_int .....|....    1.03827 in [0.8, 1.2]
#                                 ddod rho .......|..    6.51908 in [6, 6.7]
#                            Si_SiO2_rough ......|...    7.19423 in [1, 10]
#                          SiO2_solv_rough .......|..    7.63831 in [1, 10]
#                               SiO2_thick ..|.......    9.11112 in [1, 30]
#                                Si_hd_bkg |......... 8.01223e-06 in [1e-10, 0.0001]
#                                Si_hd_int ...|......   0.955904 in [0.8, 1.2]
#                            Si_gmo_dd_bkg .|........ 1.12583e-05 in [1e-10, 0.0001]
#                            Si_gmo_dd_int ....|.....   0.985088 in [0.8, 1.2]
#                                   gmo_vf .........|   0.972584 in [0, 1]
#                           gmo_solv_rough ......|...    7.04082 in [1, 10]
#                                gmo_thick .....|....    16.8195 in [1, 30]
#                            Si_gmo_hd_bkg |......... 6.19841e-06 in [1e-10, 0.0001]
#                            Si_gmo_hd_int |.........   0.832357 in [0.8, 1.2]
# step 143 cost 2.157(28)
# step 144 cost 2.157(28)
# step 145 cost 2.157(28)
# step 146 cost 2.157(28)
# step 147 cost 2.157(28)
# step 149 cost 2.157(28)
# step 151 cost 2.157(28)
# step 152 cost 2.157(28)
# step 154 cost 2.157(28)
# step 155 cost 2.127(28)
# step 157 cost 2.025(28)
# step 159 cost 2.025(28)
# step 161 cost 2.025(28)
# step 163 cost 2.025(28)
# step 165 cost 1.722(28)
# step 167 cost 1.722(28)
# step 169 cost 1.722(28)
# step 170 cost 1.722(28)
#                                Si_dd_bkg |......... 8.87114e-06 in [1e-10, 0.0001]
#                                Si_dd_int .....|....    1.03617 in [0.8, 1.2]
#                                 ddod rho .......|..    6.50142 in [6, 6.7]
#                            Si_SiO2_rough ....|.....    4.77907 in [1, 10]
#                          SiO2_solv_rough .........|    9.37915 in [1, 10]
#                               SiO2_thick ...|......    11.9225 in [1, 30]
#                                Si_hd_bkg |......... 7.1069e-06 in [1e-10, 0.0001]
#                                Si_hd_int ...|......   0.958019 in [0.8, 1.2]
#                            Si_gmo_dd_bkg .|........ 1.09905e-05 in [1e-10, 0.0001]
#                            Si_gmo_dd_int ....|.....   0.981665 in [0.8, 1.2]
#                                   gmo_vf .........|   0.961723 in [0, 1]
#                           gmo_solv_rough ......|...    6.77933 in [1, 10]
#                                gmo_thick .....|....    17.9111 in [1, 30]
#                            Si_gmo_hd_bkg |......... 5.69205e-06 in [1e-10, 0.0001]
#                            Si_gmo_hd_int .|........   0.868674 in [0.8, 1.2]
# step 171 cost 1.722(28)
# step 173 cost 1.722(28)
# step 175 cost 1.722(28)
# step 176 cost 1.722(28)
# step 178 cost 1.722(28)
# step 179 cost 1.722(28)
# step 180 cost 1.722(28)
# step 181 cost 1.722(28)
# step 182 cost 1.722(28)
# step 184 cost 1.722(28)
# step 186 cost 1.722(28)
# step 188 cost 1.722(28)
# step 190 cost 1.693(28)
# step 192 cost 1.693(28)
# step 194 cost 1.693(28)
# step 196 cost 1.642(28)
# step 197 cost 1.642(28)
# step 198 cost 1.642(28)
#                                Si_dd_bkg |......... 8.59999e-06 in [1e-10, 0.0001]
#                                Si_dd_int .....|....    1.03682 in [0.8, 1.2]
#                                 ddod rho .......|..    6.50296 in [6, 6.7]
#                            Si_SiO2_rough |.........    1.38721 in [1, 10]
#                          SiO2_solv_rough ........|.    8.99515 in [1, 10]
#                               SiO2_thick ...|......    12.4675 in [1, 30]
#                                Si_hd_bkg |......... 7.12068e-06 in [1e-10, 0.0001]
#                                Si_hd_int ...|......   0.939201 in [0.8, 1.2]
#                            Si_gmo_dd_bkg |......... 8.88559e-06 in [1e-10, 0.0001]
#                            Si_gmo_dd_int ....|.....   0.965928 in [0.8, 1.2]
#                                   gmo_vf .........|   0.965649 in [0, 1]
#                           gmo_solv_rough .....|....    6.04433 in [1, 10]
#                                gmo_thick .....|....    17.7566 in [1, 30]
#                            Si_gmo_hd_bkg |......... 5.70017e-06 in [1e-10, 0.0001]
#                            Si_gmo_hd_int .|........    0.87909 in [0.8, 1.2]
# step 199 cost 1.642(28)
# step 200 cost 1.642(28)
# step 201 cost 1.634(28)
# step 202 cost 1.634(28)
# step 203 cost 1.634(28)
# step 205 cost 1.634(28)
# step 207 cost 1.634(28)
# step 208 cost 1.634(28)
# step 210 cost 1.634(28)
# step 211 cost 1.634(28)
# step 212 cost 1.634(28)
# step 213 cost 1.634(28)
# step 214 cost 1.623(28)
# step 215 cost 1.623(28)
# step 216 cost 1.623(28)
# step 217 cost 1.623(28)
# step 218 cost 1.623(28)
# step 219 cost 1.617(28)
# step 220 cost 1.617(28)
# step 221 cost 1.613(28)
#                                Si_dd_bkg |......... 8.74141e-06 in [1e-10, 0.0001]
#                                Si_dd_int .....|....    1.03549 in [0.8, 1.2]
#                                 ddod rho .......|..    6.50659 in [6, 6.7]
#                            Si_SiO2_rough .......|..      7.324 in [1, 10]
#                          SiO2_solv_rough ........|.    8.78929 in [1, 10]
#                               SiO2_thick ...|......    11.4295 in [1, 30]
#                                Si_hd_bkg |......... 6.39187e-06 in [1e-10, 0.0001]
#                                Si_hd_int ...|......   0.920981 in [0.8, 1.2]
#                            Si_gmo_dd_bkg .|........ 1.01285e-05 in [1e-10, 0.0001]
#                            Si_gmo_dd_int ....|.....   0.975832 in [0.8, 1.2]
#                                   gmo_vf .........|   0.946467 in [0, 1]
#                           gmo_solv_rough ......|...    6.74938 in [1, 10]
#                                gmo_thick .....|....    18.3513 in [1, 30]
#                            Si_gmo_hd_bkg |......... 5.73121e-06 in [1e-10, 0.0001]
#                            Si_gmo_hd_int .|........   0.855585 in [0.8, 1.2]
# step 222 cost 1.613(28)
# step 223 cost 1.613(28)
# step 224 cost 1.613(28)
# step 225 cost 1.613(28)
# step 226 cost 1.611(28)
# step 227 cost 1.608(28)
# step 228 cost 1.608(28)
# step 229 cost 1.607(28)
# step 230 cost 1.607(28)
# step 231 cost 1.605(28)
# step 232 cost 1.597(28)
# step 233 cost 1.597(28)
# step 234 cost 1.590(28)
# step 235 cost 1.590(28)
# step 236 cost 1.583(28)
# step 237 cost 1.583(28)
# step 238 cost 1.583(28)
# step 239 cost 1.583(28)
# step 240 cost 1.583(28)
#                                Si_dd_bkg |......... 8.24653e-06 in [1e-10, 0.0001]
#                                Si_dd_int .....|....    1.03579 in [0.8, 1.2]
#                                 ddod rho .......|..    6.50283 in [6, 6.7]
#                            Si_SiO2_rough ......|...    6.49552 in [1, 10]
#                          SiO2_solv_rough ........|.    8.69568 in [1, 10]
#                               SiO2_thick ...|......    11.8919 in [1, 30]
#                                Si_hd_bkg |......... 6.56801e-06 in [1e-10, 0.0001]
#                                Si_hd_int ...|......   0.955114 in [0.8, 1.2]
#                            Si_gmo_dd_bkg |......... 8.88407e-06 in [1e-10, 0.0001]
#                            Si_gmo_dd_int ....|.....     0.9679 in [0.8, 1.2]
#                                   gmo_vf .........|   0.904028 in [0, 1]
#                           gmo_solv_rough ....|.....    5.42315 in [1, 10]
#                                gmo_thick ......|...    19.2668 in [1, 30]
#                            Si_gmo_hd_bkg |......... 6.04824e-06 in [1e-10, 0.0001]
#                            Si_gmo_hd_int .|........   0.860429 in [0.8, 1.2]
# step 241 cost 1.583(28)
# step 242 cost 1.583(28)
# step 243 cost 1.583(28)
# step 244 cost 1.583(28)
# step 245 cost 1.583(28)
# step 246 cost 1.576(28)
# step 247 cost 1.574(28)
# step 248 cost 1.574(28)
# step 249 cost 1.574(28)
# step 250 cost 1.571(28)
# step 251 cost 1.562(28)
# step 252 cost 1.562(28)
# step 253 cost 1.562(28)
# step 254 cost 1.562(28)
# step 255 cost 1.562(28)
# step 256 cost 1.557(28)
# step 257 cost 1.557(28)
# step 258 cost 1.557(28)
# step 259 cost 1.557(28)
# step 260 cost 1.557(28)
# step 261 cost 1.557(28)
# step 262 cost 1.556(28)
# step 263 cost 1.554(28)
# step 264 cost 1.543(28)
#                                Si_dd_bkg |......... 8.45883e-06 in [1e-10, 0.0001]
#                                Si_dd_int .....|....    1.03256 in [0.8, 1.2]
#                                 ddod rho .......|..    6.51216 in [6, 6.7]
#                            Si_SiO2_rough ....|.....    5.25239 in [1, 10]
#                          SiO2_solv_rough ........|.    8.32681 in [1, 10]
#                               SiO2_thick ....|.....    12.6996 in [1, 30]
#                                Si_hd_bkg |......... 6.10453e-06 in [1e-10, 0.0001]
#                                Si_hd_int ..|.......   0.918315 in [0.8, 1.2]
#                            Si_gmo_dd_bkg |......... 7.27999e-06 in [1e-10, 0.0001]
#                            Si_gmo_dd_int ....|.....   0.966807 in [0.8, 1.2]
#                                   gmo_vf .........|    0.93738 in [0, 1]
#                           gmo_solv_rough ....|.....    4.61631 in [1, 10]
#                                gmo_thick .....|....    17.1477 in [1, 30]
#                            Si_gmo_hd_bkg |......... 5.59866e-06 in [1e-10, 0.0001]
#                            Si_gmo_hd_int |.........   0.837422 in [0.8, 1.2]
# step 265 cost 1.543(28)
# step 266 cost 1.543(28)
# step 267 cost 1.542(28)
# step 268 cost 1.542(28)
# step 269 cost 1.542(28)
# step 270 cost 1.542(28)
# step 271 cost 1.542(28)
# step 272 cost 1.542(28)
# step 273 cost 1.542(28)
# step 274 cost 1.542(28)
# step 275 cost 1.542(28)
# step 276 cost 1.542(28)
# step 277 cost 1.542(28)
# step 278 cost 1.542(28)
# step 279 cost 1.542(28)
# step 280 cost 1.542(28)
# step 281 cost 1.542(28)
# step 282 cost 1.539(28)
# step 283 cost 1.539(28)
# step 284 cost 1.539(28)
# step 285 cost 1.539(28)
# step 286 cost 1.539(28)
# step 287 cost 1.539(28)
#                                Si_dd_bkg |......... 8.28797e-06 in [1e-10, 0.0001]
#                                Si_dd_int .....|....    1.03356 in [0.8, 1.2]
#                                 ddod rho .......|..    6.50961 in [6, 6.7]
#                            Si_SiO2_rough ....|.....    4.76736 in [1, 10]
#                          SiO2_solv_rough ........|.    8.74442 in [1, 10]
#                               SiO2_thick ....|.....      12.86 in [1, 30]
#                                Si_hd_bkg |......... 6.29238e-06 in [1e-10, 0.0001]
#                                Si_hd_int ...|......    0.93582 in [0.8, 1.2]
#                            Si_gmo_dd_bkg |......... 7.74934e-06 in [1e-10, 0.0001]
#                            Si_gmo_dd_int ....|.....   0.967861 in [0.8, 1.2]
#                                   gmo_vf .........|   0.911956 in [0, 1]
#                           gmo_solv_rough ...|......    4.38438 in [1, 10]
#                                gmo_thick ......|...    18.4328 in [1, 30]
#                            Si_gmo_hd_bkg |......... 5.5706e-06 in [1e-10, 0.0001]
#                            Si_gmo_hd_int .|........   0.849794 in [0.8, 1.2]
# step 288 cost 1.529(28)
# step 289 cost 1.527(28)
# step 290 cost 1.527(28)
# step 291 cost 1.527(28)
# step 292 cost 1.527(28)
# step 293 cost 1.527(28)
# step 294 cost 1.527(28)
# step 295 cost 1.527(28)
# step 296 cost 1.526(28)
# step 297 cost 1.526(28)
# step 298 cost 1.526(28)
# step 299 cost 1.525(28)
# step 300 cost 1.525(28)
# step 301 cost 1.525(28)
# step 302 cost 1.525(28)
# step 303 cost 1.525(28)
# step 304 cost 1.525(28)
# step 305 cost 1.525(28)
# step 306 cost 1.525(28)
# step 307 cost 1.525(28)
# step 308 cost 1.523(28)
#                                Si_dd_bkg |......... 8.37981e-06 in [1e-10, 0.0001]
#                                Si_dd_int .....|....    1.03469 in [0.8, 1.2]
#                                 ddod rho .......|..      6.507 in [6, 6.7]
#                            Si_SiO2_rough ...|......    3.89106 in [1, 10]
#                          SiO2_solv_rough ........|.    8.43558 in [1, 10]
#                               SiO2_thick ....|.....     12.753 in [1, 30]
#                                Si_hd_bkg |......... 6.19389e-06 in [1e-10, 0.0001]
#                                Si_hd_int ...|......   0.939443 in [0.8, 1.2]
#                            Si_gmo_dd_bkg |......... 7.13008e-06 in [1e-10, 0.0001]
#                            Si_gmo_dd_int ....|.....   0.968321 in [0.8, 1.2]
#                                   gmo_vf ........|.   0.893021 in [0, 1]
#                           gmo_solv_rough ...|......    3.74736 in [1, 10]
#                                gmo_thick ......|...     18.877 in [1, 30]
#                            Si_gmo_hd_bkg |......... 5.52638e-06 in [1e-10, 0.0001]
#                            Si_gmo_hd_int .|........   0.848938 in [0.8, 1.2]
# step 309 cost 1.523(28)
# step 310 cost 1.523(28)
# step 311 cost 1.523(28)
# step 312 cost 1.523(28)
# step 313 cost 1.523(28)
# step 314 cost 1.523(28)
# step 315 cost 1.523(28)
# step 316 cost 1.522(28)
# step 317 cost 1.522(28)
# step 318 cost 1.522(28)
# step 319 cost 1.522(28)
# step 320 cost 1.522(28)
# step 321 cost 1.522(28)
# step 322 cost 1.520(28)
# step 323 cost 1.520(28)
# step 324 cost 1.520(28)
# step 325 cost 1.520(28)
# step 326 cost 1.520(28)
#                                Si_dd_bkg |......... 8.27471e-06 in [1e-10, 0.0001]
#                                Si_dd_int .....|....    1.03432 in [0.8, 1.2]
#                                 ddod rho .......|..    6.50727 in [6, 6.7]
#                            Si_SiO2_rough ...|......     4.0902 in [1, 10]
#                          SiO2_solv_rough ........|.    8.30547 in [1, 10]
#                               SiO2_thick ....|.....    12.6842 in [1, 30]
#                                Si_hd_bkg |......... 6.17048e-06 in [1e-10, 0.0001]
#                                Si_hd_int ...|......   0.934737 in [0.8, 1.2]
#                            Si_gmo_dd_bkg |......... 7.12316e-06 in [1e-10, 0.0001]
#                            Si_gmo_dd_int ....|.....   0.967482 in [0.8, 1.2]
#                                   gmo_vf ........|.   0.892561 in [0, 1]
#                           gmo_solv_rough ...|......    3.72257 in [1, 10]
#                                gmo_thick ......|...    18.8437 in [1, 30]
#                            Si_gmo_hd_bkg |......... 5.54651e-06 in [1e-10, 0.0001]
#                            Si_gmo_hd_int .|........   0.841055 in [0.8, 1.2]
# step 327 cost 1.520(28)
# step 328 cost 1.520(28)
# step 329 cost 1.519(28)
# step 330 cost 1.519(28)
# step 331 cost 1.519(28)
# step 332 cost 1.519(28)
# step 333 cost 1.519(28)
# step 334 cost 1.519(28)
# step 335 cost 1.519(28)
# step 336 cost 1.519(28)
# step 337 cost 1.519(28)
# step 338 cost 1.519(28)
# step 339 cost 1.519(28)
# step 340 cost 1.519(28)
# step 341 cost 1.519(28)
# step 342 cost 1.518(28)
# step 343 cost 1.518(28)
# step 344 cost 1.518(28)
#                                Si_dd_bkg |......... 8.39438e-06 in [1e-10, 0.0001]
#                                Si_dd_int .....|....    1.03385 in [0.8, 1.2]
#                                 ddod rho .......|..    6.50743 in [6, 6.7]
#                            Si_SiO2_rough ....|.....    5.20504 in [1, 10]
#                          SiO2_solv_rough ........|.    8.23809 in [1, 10]
#                               SiO2_thick ...|......    12.4187 in [1, 30]
#                                Si_hd_bkg |......... 6.40395e-06 in [1e-10, 0.0001]
#                                Si_hd_int ...|......   0.931573 in [0.8, 1.2]
#                            Si_gmo_dd_bkg |......... 7.1424e-06 in [1e-10, 0.0001]
#                            Si_gmo_dd_int ....|.....    0.96894 in [0.8, 1.2]
#                                   gmo_vf ........|.   0.895547 in [0, 1]
#                           gmo_solv_rough ...|......    3.76052 in [1, 10]
#                                gmo_thick .....|....    18.3441 in [1, 30]
#                            Si_gmo_hd_bkg |......... 5.48115e-06 in [1e-10, 0.0001]
#                            Si_gmo_hd_int |.........   0.839384 in [0.8, 1.2]
# step 345 cost 1.518(28)
# step 346 cost 1.518(28)
# step 347 cost 1.518(28)
# step 348 cost 1.518(28)
# step 349 cost 1.518(28)
# step 350 cost 1.518(28)
# step 351 cost 1.518(28)
# step 352 cost 1.518(28)
# step 353 cost 1.518(28)
# step 354 cost 1.518(28)
# step 355 cost 1.518(28)
# step 356 cost 1.518(28)
# step 357 cost 1.518(28)
# step 358 cost 1.518(28)
# step 359 cost 1.518(28)
# step 360 cost 1.518(28)
# step 361 cost 1.518(28)
# step 362 cost 1.518(28)
# step 363 cost 1.518(28)
# step 364 cost 1.518(28)
# step 365 cost 1.518(28)
# step 366 cost 1.518(28)
# step 367 cost 1.517(28)
# step 368 cost 1.517(28)
#                                Si_dd_bkg |......... 8.39148e-06 in [1e-10, 0.0001]
#                                Si_dd_int .....|....    1.03434 in [0.8, 1.2]
#                                 ddod rho .......|..    6.50635 in [6, 6.7]
#                            Si_SiO2_rough ...|......    3.74511 in [1, 10]
#                          SiO2_solv_rough ........|.    8.26541 in [1, 10]
#                               SiO2_thick ....|.....    12.9723 in [1, 30]
#                                Si_hd_bkg |......... 6.3631e-06 in [1e-10, 0.0001]
#                                Si_hd_int ...|......   0.932943 in [0.8, 1.2]
#                            Si_gmo_dd_bkg |......... 6.77459e-06 in [1e-10, 0.0001]
#                            Si_gmo_dd_int ....|.....   0.968879 in [0.8, 1.2]
#                                   gmo_vf .........|   0.903869 in [0, 1]
#                           gmo_solv_rough ...|......    3.98299 in [1, 10]
#                                gmo_thick ......|...    18.6145 in [1, 30]
#                            Si_gmo_hd_bkg |......... 5.4945e-06 in [1e-10, 0.0001]
#                            Si_gmo_hd_int |.........   0.834001 in [0.8, 1.2]
# step 369 cost 1.517(28)
# step 370 cost 1.517(28)
# step 371 cost 1.517(28)
# step 372 cost 1.517(28)
# step 373 cost 1.517(28)
# step 374 cost 1.517(28)
# step 375 cost 1.517(28)
# step 376 cost 1.517(28)
# step 377 cost 1.517(28)
# step 378 cost 1.517(28)
# step 379 cost 1.517(28)
# step 380 cost 1.517(28)
# step 381 cost 1.517(28)
# step 382 cost 1.517(28)
# step 383 cost 1.517(28)
# step 384 cost 1.517(28)
# step 385 cost 1.517(28)
# step 386 cost 1.517(28)
# step 387 cost 1.517(28)
# step 388 cost 1.517(28)
# step 389 cost 1.517(28)
# step 390 cost 1.517(28)
# step 391 cost 1.517(28)
# step 392 cost 1.517(28)
# step 393 cost 1.517(28)
# step 394 cost 1.517(28)
#                                Si_dd_bkg |......... 8.4521e-06 in [1e-10, 0.0001]
#                                Si_dd_int .....|....    1.03464 in [0.8, 1.2]
#                                 ddod rho .......|..    6.50721 in [6, 6.7]
#                            Si_SiO2_rough ..|.......    3.48369 in [1, 10]
#                          SiO2_solv_rough ........|.    8.32704 in [1, 10]
#                               SiO2_thick ....|.....    13.0497 in [1, 30]
#                                Si_hd_bkg |......... 6.27913e-06 in [1e-10, 0.0001]
#                                Si_hd_int ...|......   0.930574 in [0.8, 1.2]
#                            Si_gmo_dd_bkg |......... 6.67231e-06 in [1e-10, 0.0001]
#                            Si_gmo_dd_int ....|.....   0.968549 in [0.8, 1.2]
#                                   gmo_vf .........|    0.90114 in [0, 1]
#                           gmo_solv_rough ...|......    3.81231 in [1, 10]
#                                gmo_thick ......|...    18.6777 in [1, 30]
#                            Si_gmo_hd_bkg |......... 5.40257e-06 in [1e-10, 0.0001]
#                            Si_gmo_hd_int |.........    0.83328 in [0.8, 1.2]
# step 395 cost 1.517(28)
# step 396 cost 1.517(28)
# step 397 cost 1.517(28)
# step 398 cost 1.517(28)
# step 399 cost 1.517(28)
# step 400 cost 1.517(28)
# step 401 cost 1.517(28)
# step 402 cost 1.517(28)
# step 403 cost 1.517(28)
# step 404 cost 1.517(28)
# step 405 cost 1.516(28)
# step 406 cost 1.516(28)
# step 407 cost 1.516(28)
# step 408 cost 1.516(28)
# step 409 cost 1.516(28)
# step 410 cost 1.516(28)
# step 411 cost 1.516(28)
# step 412 cost 1.516(28)
# step 413 cost 1.516(28)
# step 414 cost 1.516(28)
# step 415 cost 1.516(28)
# step 416 cost 1.516(28)
# step 417 cost 1.516(28)
#                                Si_dd_bkg |.........  8.403e-06 in [1e-10, 0.0001]
#                                Si_dd_int .....|....    1.03438 in [0.8, 1.2]
#                                 ddod rho .......|..    6.50703 in [6, 6.7]
#                            Si_SiO2_rough ..|.......    3.55665 in [1, 10]
#                          SiO2_solv_rough ........|.    8.32149 in [1, 10]
#                               SiO2_thick ....|.....    13.0326 in [1, 30]
#                                Si_hd_bkg |......... 6.31214e-06 in [1e-10, 0.0001]
#                                Si_hd_int ...|......   0.932373 in [0.8, 1.2]
#                            Si_gmo_dd_bkg |......... 6.93748e-06 in [1e-10, 0.0001]
#                            Si_gmo_dd_int ....|.....   0.968713 in [0.8, 1.2]
#                                   gmo_vf .........|   0.904887 in [0, 1]
#                           gmo_solv_rough ...|......    4.05752 in [1, 10]
#                                gmo_thick ......|...    18.6352 in [1, 30]
#                            Si_gmo_hd_bkg |......... 5.42828e-06 in [1e-10, 0.0001]
#                            Si_gmo_hd_int |.........   0.833649 in [0.8, 1.2]
# step 418 cost 1.516(28)
# step 419 cost 1.516(28)
# step 420 cost 1.516(28)
# step 421 cost 1.516(28)
# step 422 cost 1.516(28)
# step 423 cost 1.516(28)
# step 424 cost 1.516(28)
# step 425 cost 1.516(28)
# step 426 cost 1.516(28)
# step 427 cost 1.516(28)
# step 428 cost 1.516(28)
# step 429 cost 1.516(28)
# step 430 cost 1.516(28)
# step 431 cost 1.516(28)
# step 432 cost 1.516(28)
# step 433 cost 1.516(28)
# step 434 cost 1.516(28)
# step 435 cost 1.516(28)
# step 436 cost 1.516(28)
# step 437 cost 1.516(28)
# step 438 cost 1.516(28)
# step 439 cost 1.516(28)
# step 440 cost 1.516(28)
# step 441 cost 1.516(28)
# step 442 cost 1.516(28)
#                                Si_dd_bkg |......... 8.39401e-06 in [1e-10, 0.0001]
#                                Si_dd_int .....|....    1.03439 in [0.8, 1.2]
#                                 ddod rho .......|..    6.50633 in [6, 6.7]
#                            Si_SiO2_rough ...|......     3.7766 in [1, 10]
#                          SiO2_solv_rough ........|.    8.30211 in [1, 10]
#                               SiO2_thick ....|.....    12.9419 in [1, 30]
#                                Si_hd_bkg |......... 6.30116e-06 in [1e-10, 0.0001]
#                                Si_hd_int ...|......   0.932957 in [0.8, 1.2]
#                            Si_gmo_dd_bkg |......... 6.80096e-06 in [1e-10, 0.0001]
#                            Si_gmo_dd_int ....|.....    0.96852 in [0.8, 1.2]
#                                   gmo_vf .........|   0.901136 in [0, 1]
#                           gmo_solv_rough ...|......    3.78771 in [1, 10]
#                                gmo_thick ......|...    18.5482 in [1, 30]
#                            Si_gmo_hd_bkg |......... 5.42932e-06 in [1e-10, 0.0001]
#                            Si_gmo_hd_int |.........   0.834767 in [0.8, 1.2]
# step 443 cost 1.516(28)
# step 444 cost 1.516(28)
# step 445 cost 1.516(28)
# step 446 cost 1.516(28)
# step 447 cost 1.516(28)
# step 448 cost 1.516(28)
# step 449 cost 1.516(28)
# step 450 cost 1.516(28)
# step 451 cost 1.516(28)
# step 452 cost 1.516(28)
# step 453 cost 1.516(28)
# step 454 cost 1.516(28)
# step 455 cost 1.516(28)
# step 456 cost 1.516(28)
# step 457 cost 1.516(28)
# step 458 cost 1.516(28)
# step 459 cost 1.516(28)
# step 460 cost 1.516(28)
# step 461 cost 1.516(28)
# step 462 cost 1.516(28)
# step 463 cost 1.516(28)
# step 464 cost 1.516(28)
# step 465 cost 1.516(28)
#                                Si_dd_bkg |......... 8.41495e-06 in [1e-10, 0.0001]
#                                Si_dd_int .....|....    1.03425 in [0.8, 1.2]
#                                 ddod rho .......|..    6.50651 in [6, 6.7]
#                            Si_SiO2_rough ...|......    3.88518 in [1, 10]
#                          SiO2_solv_rough ........|.     8.3219 in [1, 10]
#                               SiO2_thick ....|.....    12.9102 in [1, 30]
#                                Si_hd_bkg |......... 6.29537e-06 in [1e-10, 0.0001]
#                                Si_hd_int ...|......    0.93309 in [0.8, 1.2]
#                            Si_gmo_dd_bkg |......... 6.74383e-06 in [1e-10, 0.0001]
#                            Si_gmo_dd_int ....|.....    0.96855 in [0.8, 1.2]
#                                   gmo_vf ........|.      0.899 in [0, 1]
#                           gmo_solv_rough ..|.......    3.65388 in [1, 10]
#                                gmo_thick ......|...    18.5348 in [1, 30]
#                            Si_gmo_hd_bkg |......... 5.42602e-06 in [1e-10, 0.0001]
#                            Si_gmo_hd_int |.........   0.834877 in [0.8, 1.2]
# step 466 cost 1.516(28)
# step 467 cost 1.516(28)
# step 468 cost 1.516(28)
# step 469 cost 1.516(28)
# step 470 cost 1.516(28)
# step 471 cost 1.516(28)
# step 472 cost 1.516(28)
# step 473 cost 1.516(28)
# step 474 cost 1.516(28)
# step 475 cost 1.516(28)
# step 476 cost 1.516(28)
# step 477 cost 1.516(28)
# step 478 cost 1.516(28)
# step 479 cost 1.516(28)
# step 480 cost 1.516(28)
# step 481 cost 1.516(28)
# step 482 cost 1.516(28)
# step 483 cost 1.516(28)
# step 484 cost 1.516(28)
# step 485 cost 1.516(28)
# step 486 cost 1.516(28)
# step 487 cost 1.516(28)
# step 488 cost 1.516(28)
# step 489 cost 1.516(28)
# step 490 cost 1.516(28)
# step 491 cost 1.516(28)
#                                Si_dd_bkg |......... 8.41644e-06 in [1e-10, 0.0001]
#                                Si_dd_int .....|....     1.0343 in [0.8, 1.2]
#                                 ddod rho .......|..    6.50672 in [6, 6.7]
#                            Si_SiO2_rough ...|......    3.74829 in [1, 10]
#                          SiO2_solv_rough ........|.    8.32621 in [1, 10]
#                               SiO2_thick ....|.....    12.9321 in [1, 30]
#                                Si_hd_bkg |......... 6.29174e-06 in [1e-10, 0.0001]
#                                Si_hd_int ...|......   0.933268 in [0.8, 1.2]
#                            Si_gmo_dd_bkg |......... 6.68754e-06 in [1e-10, 0.0001]
#                            Si_gmo_dd_int ....|.....   0.968572 in [0.8, 1.2]
#                                   gmo_vf ........|.   0.898531 in [0, 1]
#                           gmo_solv_rough ..|.......    3.60605 in [1, 10]
#                                gmo_thick ......|...    18.5462 in [1, 30]
#                            Si_gmo_hd_bkg |......... 5.41703e-06 in [1e-10, 0.0001]
#                            Si_gmo_hd_int |.........     0.8354 in [0.8, 1.2]
# step 492 cost 1.516(28)
# step 493 cost 1.516(28)
# step 494 cost 1.516(28)
# step 495 cost 1.516(28)
# step 496 cost 1.516(28)
# step 497 cost 1.516(28)
# step 498 cost 1.516(28)
# step 499 cost 1.516(28)
# step 500 cost 1.516(28)
# step 501 cost 1.516(28)
# step 502 cost 1.516(28)
# step 503 cost 1.516(28)
# step 504 cost 1.516(28)
# step 505 cost 1.516(28)
# step 506 cost 1.516(28)
# step 507 cost 1.516(28)
# step 508 cost 1.516(28)
# step 509 cost 1.516(28)
# step 510 cost 1.516(28)
# step 511 cost 1.516(28)
# step 512 cost 1.516(28)
# step 513 cost 1.516(28)
# step 514 cost 1.516(28)
# step 515 cost 1.516(28)
# step 516 cost 1.516(28)
# step 517 cost 1.516(28)
#                                Si_dd_bkg |......... 8.42559e-06 in [1e-10, 0.0001]
#                                Si_dd_int .....|....    1.03456 in [0.8, 1.2]
#                                 ddod rho .......|..    6.50652 in [6, 6.7]
#                            Si_SiO2_rough ..|.......    3.55894 in [1, 10]
#                          SiO2_solv_rough ........|.    8.32716 in [1, 10]
#                               SiO2_thick ....|.....    13.0124 in [1, 30]
#                                Si_hd_bkg |......... 6.28311e-06 in [1e-10, 0.0001]
#                                Si_hd_int ...|......   0.932992 in [0.8, 1.2]
#                            Si_gmo_dd_bkg |......... 6.76672e-06 in [1e-10, 0.0001]
#                            Si_gmo_dd_int ....|.....   0.968581 in [0.8, 1.2]
#                                   gmo_vf .........|   0.901705 in [0, 1]
#                           gmo_solv_rough ...|......    3.76946 in [1, 10]
#                                gmo_thick ......|...     18.549 in [1, 30]
#                            Si_gmo_hd_bkg |......... 5.41662e-06 in [1e-10, 0.0001]
#                            Si_gmo_hd_int |.........   0.834853 in [0.8, 1.2]
# step 518 cost 1.516(28)
# step 519 cost 1.516(28)
# step 520 cost 1.516(28)
# step 521 cost 1.516(28)
# step 522 cost 1.516(28)
# step 523 cost 1.516(28)
# step 524 cost 1.516(28)
# step 525 cost 1.516(28)
# step 526 cost 1.516(28)
# step 527 cost 1.516(28)
# step 528 cost 1.516(28)
# step 529 cost 1.516(28)
# step 530 cost 1.516(28)
# step 531 cost 1.516(28)
# step 532 cost 1.516(28)
# step 533 cost 1.516(28)
# step 534 cost 1.516(28)
# step 535 cost 1.516(28)
# step 536 cost 1.516(28)
# step 537 cost 1.516(28)
# step 538 cost 1.516(28)
# step 539 cost 1.516(28)
# step 540 cost 1.516(28)
#                                Si_dd_bkg |......... 8.42416e-06 in [1e-10, 0.0001]
#                                Si_dd_int .....|....    1.03438 in [0.8, 1.2]
#                                 ddod rho .......|..    6.50669 in [6, 6.7]
#                            Si_SiO2_rough ..|.......    3.45707 in [1, 10]
#                          SiO2_solv_rough ........|.    8.33809 in [1, 10]
#                               SiO2_thick ....|.....    13.0183 in [1, 30]
#                                Si_hd_bkg |......... 6.29518e-06 in [1e-10, 0.0001]
#                                Si_hd_int ...|......   0.933499 in [0.8, 1.2]
#                            Si_gmo_dd_bkg |......... 6.7592e-06 in [1e-10, 0.0001]
#                            Si_gmo_dd_int ....|.....   0.968496 in [0.8, 1.2]
#                                   gmo_vf .........|   0.900998 in [0, 1]
#                           gmo_solv_rough ...|......    3.75222 in [1, 10]
#                                gmo_thick ......|...    18.5824 in [1, 30]
#                            Si_gmo_hd_bkg |......... 5.40618e-06 in [1e-10, 0.0001]
#                            Si_gmo_hd_int |.........   0.835267 in [0.8, 1.2]
# step 541 cost 1.516(28)
# step 542 cost 1.516(28)
# step 543 cost 1.516(28)
# step 544 cost 1.516(28)
# step 545 cost 1.516(28)
# step 546 cost 1.516(28)
# step 547 cost 1.516(28)
# step 548 cost 1.516(28)
# step 549 cost 1.516(28)
# step 550 cost 1.516(28)
# step 551 cost 1.516(28)
# step 552 cost 1.516(28)
# step 553 cost 1.516(28)
# step 554 cost 1.516(28)
# step 555 cost 1.516(28)
# step 556 cost 1.516(28)
# step 557 cost 1.516(28)
# step 558 cost 1.516(28)
# step 559 cost 1.516(28)
# step 560 cost 1.516(28)
#                                Si_dd_bkg |......... 8.4251e-06 in [1e-10, 0.0001]
#                                Si_dd_int .....|....    1.03435 in [0.8, 1.2]
#                                 ddod rho .......|..     6.5068 in [6, 6.7]
#                            Si_SiO2_rough ..|.......    3.37131 in [1, 10]
#                          SiO2_solv_rough ........|.    8.34279 in [1, 10]
#                               SiO2_thick ....|.....    13.0388 in [1, 30]
#                                Si_hd_bkg |......... 6.28723e-06 in [1e-10, 0.0001]
#                                Si_hd_int ...|......   0.933851 in [0.8, 1.2]
#                            Si_gmo_dd_bkg |......... 6.73387e-06 in [1e-10, 0.0001]
#                            Si_gmo_dd_int ....|.....   0.968512 in [0.8, 1.2]
#                                   gmo_vf .........|   0.901022 in [0, 1]
#                           gmo_solv_rough ...|......    3.73407 in [1, 10]
#                                gmo_thick ......|...    18.5827 in [1, 30]
#                            Si_gmo_hd_bkg |......... 5.40639e-06 in [1e-10, 0.0001]
#                            Si_gmo_hd_int |.........    0.83513 in [0.8, 1.2]
# step 561 cost 1.516(28)
# step 562 cost 1.516(28)
# step 563 cost 1.516(28)
# step 564 cost 1.516(28)
# step 565 cost 1.516(28)
# step 566 cost 1.516(28)
# step 567 cost 1.516(28)
# step 568 cost 1.516(28)
# step 569 cost 1.516(28)
# step 570 cost 1.516(28)
# step 571 cost 1.516(28)
# step 572 cost 1.516(28)
# step 573 cost 1.516(28)
# step 574 cost 1.516(28)
# step 575 cost 1.516(28)
# step 576 cost 1.516(28)
# step 577 cost 1.516(28)
# step 578 cost 1.516(28)
# step 579 cost 1.516(28)
#                                Si_dd_bkg |......... 8.42989e-06 in [1e-10, 0.0001]
#                                Si_dd_int .....|....    1.03433 in [0.8, 1.2]
#                                 ddod rho .......|..    6.50687 in [6, 6.7]
#                            Si_SiO2_rough ..|.......    3.46718 in [1, 10]
#                          SiO2_solv_rough ........|.    8.33693 in [1, 10]
#                               SiO2_thick ....|.....    13.0219 in [1, 30]
#                                Si_hd_bkg |......... 6.28837e-06 in [1e-10, 0.0001]
#                                Si_hd_int ...|......   0.933326 in [0.8, 1.2]
#                            Si_gmo_dd_bkg |......... 6.74945e-06 in [1e-10, 0.0001]
#                            Si_gmo_dd_int ....|.....   0.968502 in [0.8, 1.2]
#                                   gmo_vf .........|   0.900865 in [0, 1]
#                           gmo_solv_rough ...|......    3.73893 in [1, 10]
#                                gmo_thick ......|...    18.5809 in [1, 30]
#                            Si_gmo_hd_bkg |......... 5.41409e-06 in [1e-10, 0.0001]
#                            Si_gmo_hd_int |.........   0.835111 in [0.8, 1.2]
# step 580 cost 1.516(28)
# step 581 cost 1.516(28)
# step 582 cost 1.516(28)
# step 583 cost 1.516(28)
# step 584 cost 1.516(28)
# step 585 cost 1.516(28)
# step 586 cost 1.516(28)
# step 587 cost 1.516(28)
# step 588 cost 1.516(28)
# step 589 cost 1.516(28)
# step 590 cost 1.516(28)
# step 591 cost 1.516(28)
# step 592 cost 1.516(28)
# step 593 cost 1.516(28)
# step 594 cost 1.516(28)
# step 595 cost 1.516(28)
# step 596 cost 1.516(28)
# step 597 cost 1.516(28)
# step 598 cost 1.516(28)
# step 599 cost 1.516(28)
# step 600 cost 1.516(28)
# step 601 cost 1.516(28)
# step 602 cost 1.516(28)
# step 603 cost 1.516(28)
#                                Si_dd_bkg |......... 8.43213e-06 in [1e-10, 0.0001]
#                                Si_dd_int .....|....    1.03441 in [0.8, 1.2]
#                                 ddod rho .......|..    6.50678 in [6, 6.7]
#                            Si_SiO2_rough ..|.......     3.4923 in [1, 10]
#                          SiO2_solv_rough ........|.    8.33802 in [1, 10]
#                               SiO2_thick ....|.....    13.0155 in [1, 30]
#                                Si_hd_bkg |......... 6.28918e-06 in [1e-10, 0.0001]
#                                Si_hd_int ...|......   0.933597 in [0.8, 1.2]
#                            Si_gmo_dd_bkg |......... 6.75267e-06 in [1e-10, 0.0001]
#                            Si_gmo_dd_int ....|.....   0.968542 in [0.8, 1.2]
#                                   gmo_vf .........|    0.90097 in [0, 1]
#                           gmo_solv_rough ...|......    3.73706 in [1, 10]
#                                gmo_thick ......|...      18.57 in [1, 30]
#                            Si_gmo_hd_bkg |......... 5.41475e-06 in [1e-10, 0.0001]
#                            Si_gmo_hd_int |.........   0.835052 in [0.8, 1.2]
# step 604 cost 1.516(28)
# step 605 cost 1.516(28)
# step 606 cost 1.516(28)
# step 607 cost 1.516(28)
# step 608 cost 1.516(28)
# step 609 cost 1.516(28)
# step 610 cost 1.516(28)
# step 611 cost 1.516(28)
# step 612 cost 1.516(28)
# step 613 cost 1.516(28)
# step 614 cost 1.516(28)
# step 615 cost 1.516(28)
# step 616 cost 1.516(28)
# step 617 cost 1.516(28)
# step 618 cost 1.516(28)
# step 619 cost 1.516(28)
# step 620 cost 1.516(28)
# step 621 cost 1.516(28)
# step 622 cost 1.516(28)
# step 623 cost 1.516(28)
# step 624 cost 1.516(28)
#                                Si_dd_bkg |......... 8.43074e-06 in [1e-10, 0.0001]
#                                Si_dd_int .....|....    1.03438 in [0.8, 1.2]
#                                 ddod rho .......|..    6.50676 in [6, 6.7]
#                            Si_SiO2_rough ..|.......    3.48108 in [1, 10]
#                          SiO2_solv_rough ........|.    8.33791 in [1, 10]
#                               SiO2_thick ....|.....    13.0151 in [1, 30]
#                                Si_hd_bkg |......... 6.28944e-06 in [1e-10, 0.0001]
#                                Si_hd_int ...|......   0.933476 in [0.8, 1.2]
#                            Si_gmo_dd_bkg |......... 6.75045e-06 in [1e-10, 0.0001]
#                            Si_gmo_dd_int ....|.....   0.968499 in [0.8, 1.2]
#                                   gmo_vf .........|   0.900922 in [0, 1]
#                           gmo_solv_rough ...|......    3.73807 in [1, 10]
#                                gmo_thick ......|...    18.5752 in [1, 30]
#                            Si_gmo_hd_bkg |......... 5.41357e-06 in [1e-10, 0.0001]
#                            Si_gmo_hd_int |.........   0.835062 in [0.8, 1.2]
# step 625 cost 1.516(28)
# step 626 cost 1.516(28)
# step 627 cost 1.516(28)
# step 628 cost 1.516(28)
# step 629 cost 1.516(28)
# step 630 cost 1.516(28)
# step 631 cost 1.516(28)
# step 632 cost 1.516(28)
# step 633 cost 1.516(28)
# step 634 cost 1.516(28)
# step 635 cost 1.516(28)
# step 636 cost 1.516(28)
# step 637 cost 1.516(28)
# step 638 cost 1.516(28)
# step 639 cost 1.516(28)
# step 640 cost 1.516(28)
# step 641 cost 1.516(28)
# step 642 cost 1.516(28)
# step 643 cost 1.516(28)
# step 644 cost 1.516(28)
#                                Si_dd_bkg |......... 8.42976e-06 in [1e-10, 0.0001]
#                                Si_dd_int .....|....    1.03437 in [0.8, 1.2]
#                                 ddod rho .......|..    6.50675 in [6, 6.7]
#                            Si_SiO2_rough ..|.......    3.51216 in [1, 10]
#                          SiO2_solv_rough ........|.    8.33381 in [1, 10]
#                               SiO2_thick ....|.....    13.0053 in [1, 30]
#                                Si_hd_bkg |.........  6.291e-06 in [1e-10, 0.0001]
#                                Si_hd_int ...|......   0.933381 in [0.8, 1.2]
#                            Si_gmo_dd_bkg |......... 6.74784e-06 in [1e-10, 0.0001]
#                            Si_gmo_dd_int ....|.....   0.968477 in [0.8, 1.2]
#                                   gmo_vf .........|   0.900806 in [0, 1]
#                           gmo_solv_rough ...|......    3.72847 in [1, 10]
#                                gmo_thick ......|...    18.5698 in [1, 30]
#                            Si_gmo_hd_bkg |......... 5.4139e-06 in [1e-10, 0.0001]
#                            Si_gmo_hd_int |.........    0.83503 in [0.8, 1.2]
# step 645 cost 1.516(28)
# step 646 cost 1.516(28)
# step 647 cost 1.516(28)
# step 648 cost 1.516(28)
# step 649 cost 1.516(28)
# step 650 cost 1.516(28)
# step 651 cost 1.516(28)
# step 652 cost 1.516(28)
# step 653 cost 1.516(28)
# step 654 cost 1.516(28)
# step 655 cost 1.516(28)
# step 656 cost 1.516(28)
# step 657 cost 1.516(28)
# step 658 cost 1.516(28)
# step 659 cost 1.516(28)
# step 660 cost 1.516(28)
# step 661 cost 1.516(28)
# step 662 cost 1.516(28)
# step 663 cost 1.516(28)
# step 664 cost 1.516(28)
# step 665 cost 1.516(28)
# step 666 cost 1.516(28)
# step 667 cost 1.516(28)
#                                Si_dd_bkg |......... 8.43085e-06 in [1e-10, 0.0001]
#                                Si_dd_int .....|....    1.03437 in [0.8, 1.2]
#                                 ddod rho .......|..    6.50681 in [6, 6.7]
#                            Si_SiO2_rough ..|.......    3.50623 in [1, 10]
#                          SiO2_solv_rough ........|.    8.33498 in [1, 10]
#                               SiO2_thick ....|.....    13.0086 in [1, 30]
#                                Si_hd_bkg |......... 6.29077e-06 in [1e-10, 0.0001]
#                                Si_hd_int ...|......   0.933437 in [0.8, 1.2]
#                            Si_gmo_dd_bkg |......... 6.75126e-06 in [1e-10, 0.0001]
#                            Si_gmo_dd_int ....|.....   0.968468 in [0.8, 1.2]
#                                   gmo_vf .........|   0.900893 in [0, 1]
#                           gmo_solv_rough ...|......    3.73367 in [1, 10]
#                                gmo_thick ......|...    18.5703 in [1, 30]
#                            Si_gmo_hd_bkg |......... 5.41396e-06 in [1e-10, 0.0001]
#                            Si_gmo_hd_int |.........   0.835039 in [0.8, 1.2]
# step 668 cost 1.516(28)
# step 669 cost 1.516(28)
# step 670 cost 1.516(28)
# step 671 cost 1.516(28)
# step 672 cost 1.516(28)
# step 673 cost 1.516(28)
# step 674 cost 1.516(28)
# step 675 cost 1.516(28)
# step 676 cost 1.516(28)
# step 677 cost 1.516(28)
# step 678 cost 1.516(28)
# step 679 cost 1.516(28)
# step 680 cost 1.516(28)
# step 681 cost 1.516(28)
# step 682 cost 1.516(28)
# step 683 cost 1.516(28)
# step 684 cost 1.516(28)
# step 685 cost 1.516(28)
# step 686 cost 1.516(28)
# step 687 cost 1.516(28)
# step 688 cost 1.516(28)
# step 689 cost 1.516(28)
# step 690 cost 1.516(28)
#                                Si_dd_bkg |......... 8.43023e-06 in [1e-10, 0.0001]
#                                Si_dd_int .....|....    1.03438 in [0.8, 1.2]
#                                 ddod rho .......|..    6.50681 in [6, 6.7]
#                            Si_SiO2_rough ..|.......    3.50576 in [1, 10]
#                          SiO2_solv_rough ........|.    8.33451 in [1, 10]
#                               SiO2_thick ....|.....    13.0093 in [1, 30]
#                                Si_hd_bkg |......... 6.2895e-06 in [1e-10, 0.0001]
#                                Si_hd_int ...|......   0.933426 in [0.8, 1.2]
#                            Si_gmo_dd_bkg |......... 6.75298e-06 in [1e-10, 0.0001]
#                            Si_gmo_dd_int ....|.....   0.968476 in [0.8, 1.2]
#                                   gmo_vf .........|    0.90093 in [0, 1]
#                           gmo_solv_rough ...|......    3.73813 in [1, 10]
#                                gmo_thick ......|...    18.5712 in [1, 30]
#                            Si_gmo_hd_bkg |......... 5.41327e-06 in [1e-10, 0.0001]
#                            Si_gmo_hd_int |.........   0.835041 in [0.8, 1.2]
# step 691 cost 1.516(28)
# step 692 cost 1.516(28)
# step 693 cost 1.516(28)
# step 694 cost 1.516(28)
# step 695 cost 1.516(28)
# step 696 cost 1.516(28)
# step 697 cost 1.516(28)
# step 698 cost 1.516(28)
# step 699 cost 1.516(28)
# step 700 cost 1.516(28)
# step 701 cost 1.516(28)
# step 702 cost 1.516(28)
# step 703 cost 1.516(28)
# step 704 cost 1.516(28)
# step 705 cost 1.516(28)
# step 706 cost 1.516(28)
# step 707 cost 1.516(28)
# step 708 cost 1.516(28)
# step 709 cost 1.516(28)
# step 710 cost 1.516(28)
# step 711 cost 1.516(28)
# step 712 cost 1.516(28)
# step 713 cost 1.516(28)
# step 714 cost 1.516(28)
# step 715 cost 1.516(28)
#                                Si_dd_bkg |......... 8.42978e-06 in [1e-10, 0.0001]
#                                Si_dd_int .....|....    1.03438 in [0.8, 1.2]
#                                 ddod rho .......|..     6.5068 in [6, 6.7]
#                            Si_SiO2_rough ..|.......    3.50575 in [1, 10]
#                          SiO2_solv_rough ........|.     8.3339 in [1, 10]
#                               SiO2_thick ....|.....    13.0093 in [1, 30]
#                                Si_hd_bkg |......... 6.28979e-06 in [1e-10, 0.0001]
#                                Si_hd_int ...|......   0.933413 in [0.8, 1.2]
#                            Si_gmo_dd_bkg |......... 6.75216e-06 in [1e-10, 0.0001]
#                            Si_gmo_dd_int ....|.....    0.96848 in [0.8, 1.2]
#                                   gmo_vf .........|   0.900957 in [0, 1]
#                           gmo_solv_rough ...|......    3.73792 in [1, 10]
#                                gmo_thick ......|...    18.5699 in [1, 30]
#                            Si_gmo_hd_bkg |......... 5.41341e-06 in [1e-10, 0.0001]
#                            Si_gmo_hd_int |.........   0.835009 in [0.8, 1.2]
# step 716 cost 1.516(28)
# step 717 cost 1.516(28)
# step 718 cost 1.516(28)
# step 719 cost 1.516(28)
# step 720 cost 1.516(28)
# step 721 cost 1.516(28)
# step 722 cost 1.516(28)
# step 723 cost 1.516(28)
# step 724 cost 1.516(28)
# step 725 cost 1.516(28)
# step 726 cost 1.516(28)
# step 727 cost 1.516(28)
# step 728 cost 1.516(28)
# step 729 cost 1.516(28)
# step 730 cost 1.516(28)
# step 731 cost 1.516(28)
# step 732 cost 1.516(28)
# step 733 cost 1.516(28)
# step 734 cost 1.516(28)
# step 735 cost 1.516(28)
# step 736 cost 1.516(28)
# step 737 cost 1.516(28)
# step 738 cost 1.516(28)
# step 739 cost 1.516(28)
# step 740 cost 1.516(28)
#                                Si_dd_bkg |......... 8.42965e-06 in [1e-10, 0.0001]
#                                Si_dd_int .....|....    1.03438 in [0.8, 1.2]
#                                 ddod rho .......|..    6.50679 in [6, 6.7]
#                            Si_SiO2_rough ..|.......     3.5141 in [1, 10]
#                          SiO2_solv_rough ........|.    8.33372 in [1, 10]
#                               SiO2_thick ....|.....    13.0071 in [1, 30]
#                                Si_hd_bkg |......... 6.28993e-06 in [1e-10, 0.0001]
#                                Si_hd_int ...|......     0.9334 in [0.8, 1.2]
# ...
# step 813 cost 1.516(28)
# step 814 cost 1.516(28)
# step 815 cost 1.516(28)
# step 816 cost 1.516(28)
# step 817 cost 1.516(28)
# step 818 cost 1.516(28)
# step 819 cost 1.516(28)
#                                Si_dd_bkg |......... 8.4291e-06 in [1e-10, 0.0001]
#                                Si_dd_int .....|....    1.03439 in [0.8, 1.2]
#                                 ddod rho .......|..    6.50678 in [6, 6.7]
#                            Si_SiO2_rough ..|.......    3.50698 in [1, 10]
#                          SiO2_solv_rough ........|.    8.33415 in [1, 10]
#                               SiO2_thick ....|.....    13.0087 in [1, 30]
#                                Si_hd_bkg |......... 6.28936e-06 in [1e-10, 0.0001]
#                                Si_hd_int ...|......   0.933415 in [0.8, 1.2]
#                            Si_gmo_dd_bkg |......... 6.7533e-06 in [1e-10, 0.0001]
#                            Si_gmo_dd_int ....|.....   0.968492 in [0.8, 1.2]
#                                   gmo_vf .........|   0.900942 in [0, 1]
#                           gmo_solv_rough ...|......    3.73819 in [1, 10]
#                                gmo_thick ......|...    18.5702 in [1, 30]
#                            Si_gmo_hd_bkg |......... 5.41411e-06 in [1e-10, 0.0001]
#                            Si_gmo_hd_int |.........   0.835027 in [0.8, 1.2]
# step 820 cost 1.516(28)
# step 821 cost 1.516(28)
# step 822 cost 1.516(28)
# step 823 cost 1.516(28)
# step 824 cost 1.516(28)
# step 825 cost 1.516(28)
# step 826 cost 1.516(28)
# step 827 cost 1.516(28)
# step 828 cost 1.516(28)
# step 829 cost 1.516(28)
# step 830 cost 1.516(28)
# step 831 cost 1.516(28)
# step 832 cost 1.516(28)
# step 833 cost 1.516(28)
# step 834 cost 1.516(28)
# step 835 cost 1.516(28)
# step 836 cost 1.516(28)
# step 837 cost 1.516(28)
# step 838 cost 1.516(28)
# step 839 cost 1.516(28)
# step 840 cost 1.516(28)
# step 841 cost 1.516(28)
# step 842 cost 1.516(28)
# step 843 cost 1.516(28)
# step 844 cost 1.516(28)
#                                Si_dd_bkg |......... 8.42886e-06 in [1e-10, 0.0001]
#                                Si_dd_int .....|....    1.03439 in [0.8, 1.2]
#                                 ddod rho .......|..    6.50678 in [6, 6.7]
#                            Si_SiO2_rough ..|.......     3.5041 in [1, 10]
#                          SiO2_solv_rough ........|.    8.33417 in [1, 10]
#                               SiO2_thick ....|.....    13.0093 in [1, 30]
#                                Si_hd_bkg |......... 6.2891e-06 in [1e-10, 0.0001]
#                                Si_hd_int ...|......   0.933425 in [0.8, 1.2]
#                            Si_gmo_dd_bkg |......... 6.75268e-06 in [1e-10, 0.0001]
#                            Si_gmo_dd_int ....|.....   0.968492 in [0.8, 1.2]
#                                   gmo_vf .........|   0.900938 in [0, 1]
#                           gmo_solv_rough ...|......    3.73793 in [1, 10]
#                                gmo_thick ......|...    18.5708 in [1, 30]
#                            Si_gmo_hd_bkg |......... 5.41381e-06 in [1e-10, 0.0001]
#                            Si_gmo_hd_int |.........   0.835028 in [0.8, 1.2]
# step 845 cost 1.516(28)
# step 846 cost 1.516(28)
# step 847 cost 1.516(28)
# step 848 cost 1.516(28)
# step 849 cost 1.516(28)
# step 850 cost 1.516(28)
# step 851 cost 1.516(28)
# step 852 cost 1.516(28)
# step 853 cost 1.516(28)
# step 854 cost 1.516(28)
# step 855 cost 1.516(28)
# step 856 cost 1.516(28)
# step 857 cost 1.516(28)
# step 858 cost 1.516(28)
# step 859 cost 1.516(28)
# step 860 cost 1.516(28)
# step 861 cost 1.516(28)
# step 862 cost 1.516(28)
# step 863 cost 1.516(28)
# step 864 cost 1.516(28)
# step 865 cost 1.516(28)
# step 866 cost 1.516(28)
# step 867 cost 1.516(28)
# step 868 cost 1.516(28)
# step 869 cost 1.516(28)
#                                Si_dd_bkg |......... 8.4291e-06 in [1e-10, 0.0001]
#                                Si_dd_int .....|....    1.03439 in [0.8, 1.2]
#                                 ddod rho .......|..    6.50679 in [6, 6.7]
#                            Si_SiO2_rough ..|.......    3.50518 in [1, 10]
#                          SiO2_solv_rough ........|.      8.334 in [1, 10]
#                               SiO2_thick ....|.....    13.0092 in [1, 30]
#                                Si_hd_bkg |......... 6.28921e-06 in [1e-10, 0.0001]
#                                Si_hd_int ...|......   0.933416 in [0.8, 1.2]
#                            Si_gmo_dd_bkg |......... 6.75314e-06 in [1e-10, 0.0001]
#                            Si_gmo_dd_int ....|.....   0.968492 in [0.8, 1.2]
#                                   gmo_vf .........|   0.900945 in [0, 1]
#                           gmo_solv_rough ...|......    3.73832 in [1, 10]
#                                gmo_thick ......|...    18.5705 in [1, 30]
#                            Si_gmo_hd_bkg |......... 5.4138e-06 in [1e-10, 0.0001]
#                            Si_gmo_hd_int |.........   0.835022 in [0.8, 1.2]
# step 870 cost 1.516(28)
# step 871 cost 1.516(28)
# step 872 cost 1.516(28)
# step 873 cost 1.516(28)
# step 874 cost 1.516(28)
# step 875 cost 1.516(28)
# step 876 cost 1.516(28)
# step 877 cost 1.516(28)
# step 878 cost 1.516(28)
# step 879 cost 1.516(28)
# step 880 cost 1.516(28)
# step 881 cost 1.516(28)
# step 882 cost 1.516(28)
# step 883 cost 1.516(28)
# step 884 cost 1.516(28)
# step 885 cost 1.516(28)
# step 886 cost 1.516(28)
# step 887 cost 1.516(28)
# step 888 cost 1.516(28)
# step 889 cost 1.516(28)
# step 890 cost 1.516(28)
# step 891 cost 1.516(28)
# step 892 cost 1.516(28)
# step 893 cost 1.516(28)
# step 894 cost 1.516(28)
#                                Si_dd_bkg |......... 8.4292e-06 in [1e-10, 0.0001]
#                                Si_dd_int .....|....    1.03439 in [0.8, 1.2]
#                                 ddod rho .......|..    6.50678 in [6, 6.7]
#                            Si_SiO2_rough ..|.......    3.50285 in [1, 10]
#                          SiO2_solv_rough ........|.    8.33419 in [1, 10]
#                               SiO2_thick ....|.....    13.0098 in [1, 30]
#                                Si_hd_bkg |......... 6.28907e-06 in [1e-10, 0.0001]
#                                Si_hd_int ...|......   0.933421 in [0.8, 1.2]
#                            Si_gmo_dd_bkg |......... 6.75338e-06 in [1e-10, 0.0001]
#                            Si_gmo_dd_int ....|.....   0.968492 in [0.8, 1.2]
#                                   gmo_vf .........|   0.900953 in [0, 1]
#                           gmo_solv_rough ...|......    3.73928 in [1, 10]
#                                gmo_thick ......|...    18.5714 in [1, 30]
#                            Si_gmo_hd_bkg |......... 5.41389e-06 in [1e-10, 0.0001]
#                            Si_gmo_hd_int |.........   0.835029 in [0.8, 1.2]
# step 895 cost 1.516(28)
# step 896 cost 1.516(28)
# step 897 cost 1.516(28)
# step 898 cost 1.516(28)
# step 899 cost 1.516(28)
# step 900 cost 1.516(28)
# step 901 cost 1.516(28)
# step 902 cost 1.516(28)
# step 903 cost 1.516(28)
# step 904 cost 1.516(28)
# step 905 cost 1.516(28)
# step 906 cost 1.516(28)
# step 907 cost 1.516(28)
# step 908 cost 1.516(28)
# step 909 cost 1.516(28)
# step 910 cost 1.516(28)
# step 911 cost 1.516(28)
# step 912 cost 1.516(28)
# step 913 cost 1.516(28)
# step 914 cost 1.516(28)
# step 915 cost 1.516(28)
# step 916 cost 1.516(28)
#                                Si_dd_bkg |......... 8.4292e-06 in [1e-10, 0.0001]
#                                Si_dd_int .....|....    1.03439 in [0.8, 1.2]
#                                 ddod rho .......|..    6.50679 in [6, 6.7]
#                            Si_SiO2_rough ..|.......    3.50235 in [1, 10]
#                          SiO2_solv_rough ........|.    8.33412 in [1, 10]
#                               SiO2_thick ....|.....    13.0099 in [1, 30]
#                                Si_hd_bkg |......... 6.28895e-06 in [1e-10, 0.0001]
#                                Si_hd_int ...|......    0.93342 in [0.8, 1.2]
#                            Si_gmo_dd_bkg |......... 6.75344e-06 in [1e-10, 0.0001]
#                            Si_gmo_dd_int ....|.....   0.968491 in [0.8, 1.2]
#                                   gmo_vf .........|   0.900957 in [0, 1]
#                           gmo_solv_rough ...|......    3.73956 in [1, 10]
#                                gmo_thick ......|...    18.5716 in [1, 30]
#                            Si_gmo_hd_bkg |......... 5.41388e-06 in [1e-10, 0.0001]
#                            Si_gmo_hd_int |.........   0.835028 in [0.8, 1.2]
# step 917 cost 1.516(28)
# step 918 cost 1.516(28)
# step 919 cost 1.516(28)
# step 920 cost 1.516(28)
# step 921 cost 1.516(28)
# step 922 cost 1.516(28)
# step 923 cost 1.516(28)
# step 924 cost 1.516(28)
# step 925 cost 1.516(28)
# step 926 cost 1.516(28)
# step 927 cost 1.516(28)
# step 928 cost 1.516(28)
# step 929 cost 1.516(28)
# step 930 cost 1.516(28)
# step 931 cost 1.516(28)
# step 932 cost 1.516(28)
# step 933 cost 1.516(28)
# step 934 cost 1.516(28)
# step 935 cost 1.516(28)
# step 936 cost 1.516(28)
# step 937 cost 1.516(28)
# step 938 cost 1.516(28)
# step 939 cost 1.516(28)
# step 940 cost 1.516(28)
# step 941 cost 1.516(28)
#                                Si_dd_bkg |......... 8.42925e-06 in [1e-10, 0.0001]
#                                Si_dd_int .....|....    1.03439 in [0.8, 1.2]
#                                 ddod rho .......|..    6.50679 in [6, 6.7]
#                            Si_SiO2_rough ..|.......    3.50161 in [1, 10]
#                          SiO2_solv_rough ........|.    8.33413 in [1, 10]
#                               SiO2_thick ....|.....      13.01 in [1, 30]
#                                Si_hd_bkg |......... 6.28897e-06 in [1e-10, 0.0001]
#                                Si_hd_int ...|......   0.933423 in [0.8, 1.2]
#                            Si_gmo_dd_bkg |......... 6.75338e-06 in [1e-10, 0.0001]
#                            Si_gmo_dd_int ....|.....   0.968491 in [0.8, 1.2]
#                                   gmo_vf .........|   0.900963 in [0, 1]
#                           gmo_solv_rough ...|......    3.73953 in [1, 10]
#                                gmo_thick ......|...    18.5714 in [1, 30]
#                            Si_gmo_hd_bkg |......... 5.41372e-06 in [1e-10, 0.0001]
#                            Si_gmo_hd_int |.........   0.835031 in [0.8, 1.2]
# step 942 cost 1.516(28)
# step 943 cost 1.516(28)
# step 944 cost 1.516(28)
# step 945 cost 1.516(28)
# step 946 cost 1.516(28)
# step 947 cost 1.516(28)
# step 948 cost 1.516(28)
# step 949 cost 1.516(28)
# step 950 cost 1.516(28)
# step 951 cost 1.516(28)
# step 952 cost 1.516(28)
# step 953 cost 1.516(28)
# step 954 cost 1.516(28)
# step 955 cost 1.516(28)
# step 956 cost 1.516(28)
# step 957 cost 1.516(28)
# step 958 cost 1.516(28)
# step 959 cost 1.516(28)
# step 960 cost 1.516(28)
# step 961 cost 1.516(28)
# step 962 cost 1.516(28)
# step 963 cost 1.516(28)
# step 964 cost 1.516(28)
# step 965 cost 1.516(28)
# step 966 cost 1.516(28)
# step 967 cost 1.516(28)
#                                Si_dd_bkg |......... 8.42936e-06 in [1e-10, 0.0001]
#                                Si_dd_int .....|....    1.03439 in [0.8, 1.2]
#                                 ddod rho .......|..    6.50679 in [6, 6.7]
#                            Si_SiO2_rough ..|.......    3.50105 in [1, 10]
#                          SiO2_solv_rough ........|.    8.33425 in [1, 10]
#                               SiO2_thick ....|.....    13.0102 in [1, 30]
#                                Si_hd_bkg |......... 6.28891e-06 in [1e-10, 0.0001]
#                                Si_hd_int ...|......   0.933427 in [0.8, 1.2]
#                            Si_gmo_dd_bkg |......... 6.75358e-06 in [1e-10, 0.0001]
#                            Si_gmo_dd_int ....|.....   0.968491 in [0.8, 1.2]
#                                   gmo_vf .........|   0.900962 in [0, 1]
#                           gmo_solv_rough ...|......    3.73972 in [1, 10]
#                                gmo_thick ......|...    18.5717 in [1, 30]
#                            Si_gmo_hd_bkg |......... 5.41371e-06 in [1e-10, 0.0001]
#                            Si_gmo_hd_int |.........   0.835033 in [0.8, 1.2]
# step 968 cost 1.516(28)
# step 969 cost 1.516(28)
# step 970 cost 1.516(28)
# step 971 cost 1.516(28)
# step 972 cost 1.516(28)
# step 973 cost 1.516(28)
# step 974 cost 1.516(28)
# step 975 cost 1.516(28)
# step 976 cost 1.516(28)
# step 977 cost 1.516(28)
# step 978 cost 1.516(28)
# step 979 cost 1.516(28)
# step 980 cost 1.516(28)
# step 981 cost 1.516(28)
# step 982 cost 1.516(28)
# step 983 cost 1.516(28)
# step 984 cost 1.516(28)
# step 985 cost 1.516(28)
# step 986 cost 1.516(28)
# step 987 cost 1.516(28)
# step 988 cost 1.516(28)
# step 989 cost 1.516(28)
#                                Si_dd_bkg |......... 8.42927e-06 in [1e-10, 0.0001]
#                                Si_dd_int .....|....    1.03439 in [0.8, 1.2]
#                                 ddod rho .......|..    6.50679 in [6, 6.7]
#                            Si_SiO2_rough ..|.......    3.50151 in [1, 10]
#                          SiO2_solv_rough ........|.    8.33419 in [1, 10]
#                               SiO2_thick ....|.....    13.0101 in [1, 30]
#                                Si_hd_bkg |......... 6.28889e-06 in [1e-10, 0.0001]
#                                Si_hd_int ...|......   0.933424 in [0.8, 1.2]
#                            Si_gmo_dd_bkg |......... 6.75363e-06 in [1e-10, 0.0001]
#                            Si_gmo_dd_int ....|.....   0.968491 in [0.8, 1.2]
#                                   gmo_vf .........|   0.900963 in [0, 1]
#                           gmo_solv_rough ...|......     3.7398 in [1, 10]
#                                gmo_thick ......|...    18.5716 in [1, 30]
#                            Si_gmo_hd_bkg |......... 5.41374e-06 in [1e-10, 0.0001]
#                            Si_gmo_hd_int |.........   0.835031 in [0.8, 1.2]
# step 990 cost 1.516(28)
# step 991 cost 1.516(28)
# step 992 cost 1.516(28)
# step 993 cost 1.516(28)
# step 994 cost 1.516(28)
# step 995 cost 1.516(28)
# step 996 cost 1.516(28)
# step 997 cost 1.516(28)
# step 998 cost 1.516(28)
# step 999 cost 1.516(28)
# step 1000 cost 1.516(28)
# step 1000 cost 1.516(28) [final]
#                                Si_dd_bkg |......... 8.4293e-06 in [1e-10, 0.0001]
#                                Si_dd_int .....|....    1.03439 in [0.8, 1.2]
#                                 ddod rho .......|..    6.50679 in [6, 6.7]
#                            Si_SiO2_rough ..|.......    3.50087 in [1, 10]
#                          SiO2_solv_rough ........|.    8.33422 in [1, 10]
#                               SiO2_thick ....|.....    13.0103 in [1, 30]
#                                Si_hd_bkg |......... 6.2889e-06 in [1e-10, 0.0001]
#                                Si_hd_int ...|......   0.933424 in [0.8, 1.2]
#                            Si_gmo_dd_bkg |......... 6.7539e-06 in [1e-10, 0.0001]
#                            Si_gmo_dd_int ....|.....   0.968491 in [0.8, 1.2]
#                                   gmo_vf .........|    0.90097 in [0, 1]
#                           gmo_solv_rough ...|......    3.74026 in [1, 10]
#                                gmo_thick ......|...    18.5717 in [1, 30]
#                            Si_gmo_hd_bkg |......... 5.41371e-06 in [1e-10, 0.0001]
#                            Si_gmo_hd_int |.........   0.835032 in [0.8, 1.2]
# time 20 minutes
# final chisq 1.516(28)
# === Uncertainty from curvature:     name   value(unc.) ===
#                                Si_dd_bkg   8.43(26)e-6
#                                Si_dd_int   1.0344(31)
#                                 ddod rho   6.5068(41)
#                            Si_SiO2_rough   3.5(42)
#                          SiO2_solv_rough   8.33(26)
#                               SiO2_thick   13.0(11)
#                                Si_hd_bkg   6.29(35)e-6
#                                Si_hd_int   0.933(11)
#                            Si_gmo_dd_bkg   6.8(11)e-6
#                            Si_gmo_dd_int   0.9685(31)
#                                   gmo_vf   0.901(39)
#                           gmo_solv_rough   3.7(23)
#                                gmo_thick   18.57(100)
#                            Si_gmo_hd_bkg   5.41(28)e-6
#                            Si_gmo_hd_int   0.835(11)
# ==========================================================

# %%
{k: v for k, v in zip(problem.labels(), problem.getp())}
# Out:
# {'Si_dd_bkg': np.float64(8.429299201352554e-06),
#  'Si_dd_int': np.float64(1.0343872702848582),
#  'ddod rho': np.float64(6.506785339609216),
#  'Si_SiO2_rough': np.float64(3.500874798175271),
#  'SiO2_solv_rough': np.float64(8.334222929858855),
#  'SiO2_thick': np.float64(13.010299882306441),
#  'Si_hd_bkg': np.float64(6.288898811742217e-06),
#  'Si_hd_int': np.float64(0.9334241671398132),
#  'Si_gmo_dd_bkg': np.float64(6.753901949368904e-06),
#  'Si_gmo_dd_int': np.float64(0.9684912834609203),
#  'gmo_vf': np.float64(0.900970322318832),
#  'gmo_solv_rough': np.float64(3.7402640678238774),
#  'gmo_thick': np.float64(18.5716786732019),
#  'Si_gmo_hd_bkg': np.float64(5.413708684812817e-06),
#  'Si_gmo_hd_int': np.float64(0.8350318960360433)}

# %%
# the parameters are updated in the problem
np.testing.assert_allclose(problem.getp(), result.x)

# %% [markdown]
# ## Plot the data & model

# %%
# %matplotlib inline
for mod in problem.models:
    plt.errorbar(x=mod.probe.Q, y=mod.probe.R, yerr=mod.probe.dR, linestyle='None', marker='.')
    plt.plot(*mod.reflectivity(), color='k', zorder=10)
plt.xscale('log')
plt.yscale('log')

# %% [markdown]
# ## Plot the structure of the vfp
#
# Use the vfp's plot method to plot the SLD, volume fraction profile and a stochastic simulation of the interface.
#
# In the current implementation, there is no way to plot the posterior, but this will be added.

# %%
dd_vfp_bare.plot(plots_required=["sld", "vfp", "surfaces"]) # equivalent to glob_obj.objectives[0].model.structure.components[1].plot()
plt.show()

# %%
dd_vfp_gmo.plot() # equivalent to glob_obj.objectives[2].model.structure.components[1].plot()
plt.show()
