# %% [markdown]
# # Example usage of `vfp` with refl1d
#
# To demonstrate the `vfp` we'll model some NR data taken with a Si substrate.
#
# Two NR contrasts were taken in a solid-liquid cell with dodecane ($\mathrm{C}_{12}\mathrm{H}_{26}$ \& $\mathrm{C}_{12}\mathrm{D}_{26}$).
#
# Two other contrasts were taken with the same substrate with solutions of glycerol monooleate, a surfactant, in $\mathrm{C}_{12}\mathrm{H}_{26}$ \& $\mathrm{C}_{12}\mathrm{D}_{26}$.

# %%
import pathlib
import os
import matplotlib.pyplot as plt
import numpy as np
from functools import partial

from bumps.parameter import Parameter
import refl1d
from bumps.parameter import Parameter
from bumps.fitproblem import FitProblem 

from refl1d.experiment import Experiment
from refl1d.probe.resolution import sigma2FWHM
from refl1d.sample.material import SLD, Material
from refl1d.sample.layers import Slab, Stack
from refl1d.probe import NeutronProbe

import vfp

# %%
def qt2l(q: np.ndarray, t: float) -> np.ndarray:
    """
    Get wavelength from q and theta.
    """
    return 4 * np.pi * np.sin(np.radians(t)) / q

def tof_loader(filename: str | pathlib.Path,
               t: float = 0.7, 
               dqoq: float = 0.03, 
               delimiter: str = "\t", 
               **kw) -> NeutronProbe:
    """
    Create `NeutronProbe.refl1d.probe` for each file, with given parameters.
    
    Parameters
    ----------
    filename: str | pathlib.Path
        Name of data file to load.
    t: float
        Incident angle data was collected with.
    dqoq: float
        Resolution data was collected with (sigma not FWHM).
    delimiter: str
        The delimiter between data entries in data file.
    """
    q, r, dr = np.loadtxt(filename, delimiter=delimiter).T
    data_in = (r, dr)
    
    l = qt2l(q, t)
    # Convert the dq/q resolution into a dq value for each Q point
    dq = q * dqoq # refl1d works in sigma, not FWHM.

    probe_out = NeutronProbe(
        T=t, 
        dT=0, 
        L=l, 
        dL=0, 
        data=data_in, 
        dQo=dq, 
        resolution='normal',
        **kw 
    )

    return probe_out

# %%
dataset_dir = pathlib.Path(vfp.__path__[0]).parents[1] / 'docs'
with os.scandir(dataset_dir) as files:
    nr_data_fps = [file.name for file in files if file.name.startswith('IvsQ')]
    data_fp_dict = {'ddod' : nr_data_fps[0],
                    'hdod' : nr_data_fps[1],
                    'hdod_gmo' : nr_data_fps[2],
                    'ddod_gmo' : nr_data_fps[3]}

# %%
tof_loader_partial = partial(tof_loader, t=0.7, delimiter=',')
probes = map(tof_loader_partial, (dataset_dir / file_name for file_name in data_fp_dict.values()))

# %%
si_dd_probe, si_hd_probe, si_hd_gmo_probe, si_dd_gmo_probe = probes

# %%
plt.errorbar(x=si_dd_probe.Q, 
             y=si_dd_probe.R, 
             yerr=si_dd_probe.dR, 
             marker='.', 
             linestyle='None',
             label=r'Si dd')
plt.errorbar(x=si_dd_gmo_probe.Q, 
             y=si_dd_gmo_probe.R, 
             yerr=si_dd_gmo_probe.dR, 
             marker='.', 
             linestyle='None',
             label=r'Si dd gmo')
plt.errorbar(x=si_hd_probe.Q, 
             y=si_hd_probe.R, 
             yerr=si_hd_probe.dR, 
             marker='.', 
             linestyle='None',
             label=r'Si hd')
plt.errorbar(x=si_hd_gmo_probe.Q, 
             y=si_hd_gmo_probe.R, 
             yerr=si_hd_gmo_probe.dR, 
             marker='.', 
             linestyle='None',
             label=r'Si hd gmo')
plt.legend(frameon=False)
plt.xscale('log') 
plt.yscale('log')
plt.xlabel(r'$Q$ / $\mathrm{\AA{}}^{-1}$')
plt.ylabel(r'$R\left(Q\right)$')
plt.show()

# %% [markdown]
# ## The model
# We'll model the bare Si data with a fronting of Si, and layer of $\mathrm{SiO}_{2}$ and a solvent backing.
#
# The SLDs of the materials will be fixed but we'll model the thickness of the $\mathrm{SiO}_{2}$ and the roughness of the interfaces between the materials.
#
# For those contrasts with GMO, we'll model a GMO layer with a fixed SLD of GMO = $0.21 \times 10^{-6} \mathrm{\AA}^{-2}$, a varying solvation, thickness and roughness.
#
# There will be the same interface width between $\mathrm{SiO}_{2}$ and the solvent and between $\mathrm{SiO}_{2}$ and GMO.

# %%
Si = SLD(rho=2.07, name='Si')
SiO2 = SLD(rho=3.47, name='SiO2')
gmo = SLD(rho=0.21, name='gmo')

hdod = SLD(rho=-0.46, name='hdod')
ddod = SLD(rho=6.7, name='ddod')

# lets vary the ddod but not the hdod.
ddod.rho.range(6, 6.7)
# Out:
# Parameter(ddod rho)

# %%
# define thickness and roughness parameters.
SiO2_thick = Parameter(value=20, name='SiO2_thick', vary=True, bounds=(1, 30))
gmo_thick = Parameter(value=20, name='gmo_thick', vary=True, bounds=(1, 30))

Si_SiO2_rough = Parameter(value=3, name='Si_SiO2_rough', vary=True, bounds=(1, 10))
SiO2_solv_rough = Parameter(5, name='SiO2_solv_rough', vary=True, bounds=(1, 10))

SiO2_gmo_rough = SiO2_solv_rough # Parameter(name='SiO2_gmo_rough', constraint=SiO2_solv_rough)
gmo_solv_rough = Parameter(5, name='gmo_solv_rough', vary=True, bounds=(1, 10))

gmo_vf = Parameter(value=1, name='gmo_vf', vary=True, bounds=(0, 1))

# %% [markdown]
# ## refl1d works from backing to fronting...

# %%
# define the SLDs of the materials in two lists for the two contrasts.
dd_nslds = [Si.rho,
            SiO2.rho,
            ddod.rho]

hd_nslds = [Si.rho,
            SiO2.rho,
            hdod.rho]

dd_gmo_nslds = [Si.rho,
                SiO2.rho,
                gmo.rho * gmo_vf + ddod.rho * (1-gmo_vf),
                ddod.rho]

hd_gmo_nslds = [Si.rho,
                SiO2.rho,
                gmo.rho * gmo_vf + hdod.rho * (1-gmo_vf),
                hdod.rho]

# define the thicknesses of the all layers, including the fronting but not the backing.
list_of_thicknesses_bare = [0, SiO2_thick]
list_of_thicknesses_gmo = [0, SiO2_thick, gmo_thick]
# define the width the of the interfaces between the materials.
list_of_roughnesses_bare = [Si_SiO2_rough, SiO2_solv_rough]
list_of_roughnesses_gmo = [Si_SiO2_rough, SiO2_gmo_rough, gmo_solv_rough]

# use the list of SLDs, thicknesses and roughnesses to define refnxVFP objects.
dd_vfp_bare = vfp.refl1dVFP(nslds=dd_nslds,
                            thicknesses=list_of_thicknesses_bare,
                            roughnesses=list_of_roughnesses_bare,
                            orientation='back')

hd_vfp_bare = vfp.refl1dVFP(nslds=hd_nslds,
                            thicknesses=list_of_thicknesses_bare,
                            roughnesses=list_of_roughnesses_bare,
                            orientation='back')

dd_vfp_gmo = vfp.refl1dVFP(nslds=dd_gmo_nslds,
                           thicknesses=list_of_thicknesses_gmo,
                           roughnesses=list_of_roughnesses_gmo,
                           orientation='back')

hd_vfp_gmo = vfp.refl1dVFP(nslds=hd_gmo_nslds,
                           thicknesses=list_of_thicknesses_gmo,
                           roughnesses=list_of_roughnesses_gmo,
                           orientation='back')
# Out:
# C:\Users\sandy\OneDrive\PDRA - Job 2021-2024\VFP\src\vfp\vfp.py:962: UserWarning: If msld / isld parameters are part of a function (i.e f(p1, p2) = p1 + p2), they must be of type bumps.parameter.Parameter. Do not use material or SLD objects.
#   warnings.warn(

# %%
# see the parameters in the refnxVFP
# these contain non varying parameters.
print(dd_vfp_gmo.layer_parameters())
# Out:
# {'nslds': [Parameter(Si rho), Parameter(SiO2 rho), Parameter(gmo rho), Parameter(gmo_vf), Parameter(ddod rho)], 'thicknesses': [Parameter(refl1dVFP - thicknesses - fronting), Parameter(SiO2_thick), Parameter(gmo_thick)], 'roughnesses': [Parameter(Si_SiO2_rough), Parameter(SiO2_solv_rough), Parameter(gmo_solv_rough)], 'islds': [Parameter(refl1dVFP - isld - fronting), Parameter(refl1dVFP - isld - layer 1), Parameter(refl1dVFP - isld - layer 2), Parameter(refl1dVFP - isld - backing)], 'mslds': [Parameter(refl1dVFP - msld - fronting), Parameter(refl1dVFP - msld - layer 1), Parameter(refl1dVFP - msld - layer 2), Parameter(refl1dVFP - msld - backing)]}

# %%
# the refnxVFP objects are refnx Component objects so can be placed in a refnx structure.
# place vfps between SLD objects.
dd_struc = ddod | dd_vfp_bare | Si
hd_struc = hdod | hd_vfp_bare | Si
dd_GMO_struc = ddod | dd_vfp_gmo | Si
hd_GMO_struc = hdod | hd_vfp_gmo | Si

# %%
# define instrument / nuisance parameters
si_dd_probe.intensity.range(0.8, 1.2)
si_dd_probe.intensity.name = "Si_dd_int"
si_hd_probe.intensity.range(0.8, 1.2)
si_hd_probe.intensity.name = "Si_hd_int"
si_dd_gmo_probe.intensity.range(0.8, 1.2)
si_dd_gmo_probe.intensity.name = "Si_gmo_dd_int"
si_hd_gmo_probe.intensity.range(0.8, 1.2)
si_hd_gmo_probe.intensity.name = "Si_gmo_hd_int"

si_dd_probe.background.value = 1e-6
si_dd_probe.background.range(1e-10, 1e-4)
si_dd_probe.background.name = "Si_dd_bkg"
si_hd_probe.background.value = 1e-6
si_hd_probe.background.range(1e-10, 1e-4)
si_hd_probe.background.name = "Si_hd_bkg"
si_dd_gmo_probe.background.range(1e-10, 1e-4)
si_dd_gmo_probe.background.value = 1e-6
si_dd_gmo_probe.background.name = "Si_gmo_dd_bkg"
si_hd_gmo_probe.background.range(1e-10, 1e-4)
si_hd_gmo_probe.background.value = 1e-6
si_hd_gmo_probe.background.name = "Si_gmo_hd_bkg"

# %%
exp_si_dd = Experiment(probe=si_dd_probe, sample=dd_struc)
exp_si_hd = Experiment(probe=si_hd_probe, sample=hd_struc)
exp_si_dd_gmo = Experiment(probe=si_dd_gmo_probe, sample=dd_GMO_struc)
exp_si_hd_gmo = Experiment(probe=si_hd_gmo_probe, sample=hd_GMO_struc)

# %%
problem = FitProblem([exp_si_dd, exp_si_hd, exp_si_dd_gmo, exp_si_hd_gmo])

# %%
# check model looks reasonable with starting parameters

# %matplotlib inline
for mod in problem.models:
    plt.errorbar(x=mod.probe.Q, y=mod.probe.R, yerr=mod.probe.dR, linestyle='None', marker='.')
    plt.plot(*mod.reflectivity(), color='k', zorder=10)
plt.xscale('log')
plt.yscale('log')

# %% [markdown]
# ## Fit via `bumps.fitters.fit`.
#
# It's more common to write a `refl1d` script and use the cli or the GUI.
# But we can do it interactively...

# %%
from bumps.mapper import MPMapper
from bumps.fitters import fit
mapper = MPMapper.start_mapper(problem, None, cpus=0) # cpu=0 for all CPUs
result = fit(problem, method="de", mapper=mapper, verbose=True, options=dict(steps=200, pop=160)) # only run for 200 iterations.
# Out:
# step 1 cost 30.967(28)
#                                Si_dd_bkg .|........ 1.83167e-05 in (1e-10, 0.0001)
#                                Si_dd_int .....|....    1.01118 in (0.8, 1.2)
#                                 ddod rho .........|    6.63411 in (6, 6.7)
#                            Si_SiO2_rough .......|..    8.07664 in (1.0, 10.0)
#                          SiO2_solv_rough ....|.....    5.00242 in (1.0, 10.0)
#                               SiO2_thick |.........    2.29584 in (1.0, 30.0)
#                                Si_hd_bkg ..|....... 2.46623e-05 in (1e-10, 0.0001)
#                                Si_hd_int .|........   0.840807 in (0.8, 1.2)
#                            Si_gmo_dd_bkg ..|....... 2.93906e-05 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ....|.....   0.967266 in (0.8, 1.2)
#                                   gmo_vf .....|....   0.578268 in (0.0, 1.0)
#                           gmo_solv_rough ........|.    8.45727 in (1.0, 10.0)
#                                gmo_thick ...|......    12.2951 in (1.0, 30.0)
#                            Si_gmo_hd_bkg .|........ 1.04372e-05 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.820973 in (0.8, 1.2)
# step 5 cost 30.967(28)
# step 9 cost 30.967(28)
# step 13 cost 29.826(28)
# step 18 cost 22.163(28)
# step 21 cost 20.955(28)
# step 25 cost 20.955(28)
# step 27 cost 20.955(28)
# step 31 cost 20.558(28)
# step 34 cost 17.543(28)
# step 36 cost 17.543(28)
# step 39 cost 17.543(28)
# step 42 cost 9.719(28)
# step 44 cost 9.719(28)
# step 46 cost 9.719(28)
# step 49 cost 9.719(28)
# step 52 cost 9.470(28)
# step 54 cost 9.470(28)
# step 57 cost 8.270(28)
# step 60 cost 5.196(28)
# step 63 cost 5.196(28)
# step 65 cost 3.657(28)
# step 67 cost 3.657(28)
# step 68 cost 3.657(28)
#                                Si_dd_bkg |......... 8.06428e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.965072 in (0.8, 1.2)
#                                 ddod rho .......|..     6.5265 in (6, 6.7)
#                            Si_SiO2_rough ......|...    7.22833 in (1.0, 10.0)
#                          SiO2_solv_rough .....|....    5.93309 in (1.0, 10.0)
#                               SiO2_thick .|........    5.04998 in (1.0, 30.0)
#                                Si_hd_bkg |......... 7.11352e-06 in (1e-10, 0.0001)
#                                Si_hd_int ..|.......   0.910987 in (0.8, 1.2)
#                            Si_gmo_dd_bkg .|........ 1.40228e-05 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ....|.....   0.971314 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.877232 in (0.0, 1.0)
#                           gmo_solv_rough ........|.    8.92775 in (1.0, 10.0)
#                                gmo_thick .....|....    17.4358 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.04384e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int ...|......    0.95377 in (0.8, 1.2)
# step 70 cost 3.657(28)
# step 72 cost 3.657(28)
# step 75 cost 3.475(28)
# step 77 cost 3.475(28)
# step 79 cost 3.475(28)
# step 81 cost 3.475(28)
# step 84 cost 3.475(28)
# step 87 cost 2.766(28)
# step 90 cost 2.766(28)
# step 92 cost 2.766(28)
# step 93 cost 2.754(28)
# step 95 cost 2.754(28)
# step 96 cost 2.754(28)
# step 97 cost 2.754(28)
# step 98 cost 2.754(28)
# step 100 cost 2.754(28)
# step 102 cost 2.735(28)
# step 104 cost 2.607(28)
# step 105 cost 2.607(28)
# step 107 cost 2.607(28)
# step 109 cost 2.607(28)
#                                Si_dd_bkg |......... 7.83402e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....     0.9986 in (0.8, 1.2)
#                                 ddod rho .......|..    6.51087 in (6, 6.7)
#                            Si_SiO2_rough ......|...    6.57693 in (1.0, 10.0)
#                          SiO2_solv_rough .....|....    6.05811 in (1.0, 10.0)
#                               SiO2_thick .|........    6.39838 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.48296e-06 in (1e-10, 0.0001)
#                                Si_hd_int ....|.....   0.973995 in (0.8, 1.2)
#                            Si_gmo_dd_bkg .|........ 1.31219e-05 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ....|.....   0.974718 in (0.8, 1.2)
#                                   gmo_vf .........|   0.918939 in (0.0, 1.0)
#                           gmo_solv_rough ......|...    7.16642 in (1.0, 10.0)
#                                gmo_thick ....|.....    14.9351 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 4.47931e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int ..|.......   0.902501 in (0.8, 1.2)
# step 111 cost 2.560(28)
# step 113 cost 2.560(28)
# step 115 cost 2.426(28)
# step 118 cost 2.148(28)
# step 120 cost 2.148(28)
# step 122 cost 2.148(28)
# step 124 cost 2.148(28)
# step 126 cost 2.148(28)
# step 128 cost 2.128(28)
# step 130 cost 2.055(28)
# step 132 cost 2.054(28)
# step 134 cost 1.936(28)
# step 136 cost 1.936(28)
# step 138 cost 1.936(28)
# step 140 cost 1.936(28)
# step 142 cost 1.895(28)
# step 144 cost 1.895(28)
# step 146 cost 1.895(28)
# step 148 cost 1.895(28)
# step 150 cost 1.895(28)
# step 152 cost 1.895(28)
# step 154 cost 1.895(28)
#                                Si_dd_bkg |......... 7.7651e-06 in (1e-10, 0.0001)
#                                Si_dd_int .....|....    1.00802 in (0.8, 1.2)
#                                 ddod rho .......|..    6.53551 in (6, 6.7)
#                            Si_SiO2_rough ........|.    9.06424 in (1.0, 10.0)
#                          SiO2_solv_rough ....|.....    5.33923 in (1.0, 10.0)
#                               SiO2_thick ..|.......    8.57927 in (1.0, 30.0)
#                                Si_hd_bkg |......... 4.97649e-06 in (1e-10, 0.0001)
#                                Si_hd_int ..|.......   0.907798 in (0.8, 1.2)
#                            Si_gmo_dd_bkg .|........ 1.00915e-05 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......   0.949898 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.827316 in (0.0, 1.0)
#                           gmo_solv_rough ....|.....    5.45265 in (1.0, 10.0)
#                                gmo_thick .......|..     22.908 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.41201e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int .|........   0.843071 in (0.8, 1.2)
# step 156 cost 1.888(28)
# step 158 cost 1.888(28)
# step 160 cost 1.868(28)
# step 162 cost 1.802(28)
# step 164 cost 1.777(28)
# step 166 cost 1.777(28)
# step 168 cost 1.693(28)
# step 170 cost 1.693(28)
# step 172 cost 1.693(28)
# step 174 cost 1.693(28)
# step 176 cost 1.693(28)
# step 178 cost 1.693(28)
# step 180 cost 1.693(28)
# step 182 cost 1.629(28)
# step 184 cost 1.629(28)
# step 186 cost 1.626(28)
# step 188 cost 1.626(28)
# step 190 cost 1.626(28)
# step 191 cost 1.626(28)
#                                Si_dd_bkg |......... 8.97643e-06 in (1e-10, 0.0001)
#                                Si_dd_int .....|....    1.03236 in (0.8, 1.2)
#                                 ddod rho .......|..    6.51117 in (6, 6.7)
#                            Si_SiO2_rough .......|..    8.09554 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.85588 in (1.0, 10.0)
#                               SiO2_thick ...|......    10.5206 in (1.0, 30.0)
#                                Si_hd_bkg |......... 7.33457e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.952355 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 9.92192e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ....|.....   0.962924 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.894058 in (0.0, 1.0)
#                           gmo_solv_rough ....|.....     5.1023 in (1.0, 10.0)
#                                gmo_thick ......|...    18.6439 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.80807e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int .|........   0.861879 in (0.8, 1.2)
# step 193 cost 1.626(28)
# step 195 cost 1.626(28)
# step 197 cost 1.626(28)
# step 199 cost 1.626(28)
# step 201 cost 1.626(28)
# step 202 cost 1.626(28)
# step 203 cost 1.606(28)
# step 204 cost 1.606(28)
# step 206 cost 1.606(28)
# step 207 cost 1.606(28)
# step 208 cost 1.606(28)
# step 210 cost 1.599(28)
# step 211 cost 1.576(28)
# step 213 cost 1.576(28)
# step 215 cost 1.576(28)
# step 216 cost 1.576(28)
# step 217 cost 1.571(28)
# step 218 cost 1.571(28)
# step 219 cost 1.571(28)
# step 220 cost 1.571(28)
# step 221 cost 1.571(28)
#                                Si_dd_bkg |......... 7.72015e-06 in (1e-10, 0.0001)
#                                Si_dd_int .....|....    1.03034 in (0.8, 1.2)
#                                 ddod rho .......|..    6.51351 in (6, 6.7)
#                            Si_SiO2_rough ........|.    8.59658 in (1.0, 10.0)
#                          SiO2_solv_rough ......|...    6.87826 in (1.0, 10.0)
#                               SiO2_thick ...|......    10.0152 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.00527e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.927775 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 7.50265e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ....|.....   0.967454 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.860574 in (0.0, 1.0)
#                           gmo_solv_rough .|........    2.06335 in (1.0, 10.0)
#                                gmo_thick .....|....    17.9074 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.23712e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.833843 in (0.8, 1.2)
# step 222 cost 1.571(28)
# step 223 cost 1.571(28)
# step 224 cost 1.571(28)
# step 225 cost 1.571(28)
# step 226 cost 1.571(28)
# step 227 cost 1.571(28)
# step 229 cost 1.565(28)
# step 230 cost 1.565(28)
# step 231 cost 1.565(28)
# step 232 cost 1.565(28)
# step 233 cost 1.563(28)
# step 234 cost 1.563(28)
# step 236 cost 1.563(28)
# step 237 cost 1.558(28)
# step 238 cost 1.558(28)
# step 240 cost 1.558(28)
# step 242 cost 1.558(28)
# step 243 cost 1.558(28)
# step 245 cost 1.558(28)
# step 246 cost 1.558(28)
# step 248 cost 1.554(28)
#                                Si_dd_bkg |......... 7.98726e-06 in (1e-10, 0.0001)
#                                Si_dd_int .....|....    1.03747 in (0.8, 1.2)
#                                 ddod rho .......|..    6.50478 in (6, 6.7)
#                            Si_SiO2_rough .......|..    8.10712 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.37005 in (1.0, 10.0)
#                               SiO2_thick ...|......    11.0285 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.5712e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.937979 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 7.79058e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ....|.....   0.969679 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.887857 in (0.0, 1.0)
#                           gmo_solv_rough ...|......    4.10498 in (1.0, 10.0)
#                                gmo_thick ......|...    18.8195 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.46907e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.832812 in (0.8, 1.2)
# step 250 cost 1.554(28)
# step 252 cost 1.554(28)
# step 253 cost 1.546(28)
# step 254 cost 1.537(28)
# step 256 cost 1.537(28)
# step 257 cost 1.537(28)
# step 259 cost 1.537(28)
# step 261 cost 1.537(28)
# step 262 cost 1.537(28)
# step 263 cost 1.537(28)
# step 265 cost 1.537(28)
# step 266 cost 1.537(28)
# step 267 cost 1.537(28)
# step 269 cost 1.537(28)
# step 270 cost 1.536(28)
# step 271 cost 1.536(28)
# step 273 cost 1.536(28)
# step 274 cost 1.536(28)
# step 276 cost 1.536(28)
#                                Si_dd_bkg |......... 8.4892e-06 in (1e-10, 0.0001)
#                                Si_dd_int .....|....    1.03735 in (0.8, 1.2)
#                                 ddod rho .......|..    6.50241 in (6, 6.7)
#                            Si_SiO2_rough .....|....    6.01542 in (1.0, 10.0)
#                          SiO2_solv_rough .......|..    7.86882 in (1.0, 10.0)
#                               SiO2_thick ...|......    12.1818 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.08635e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.927162 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.93698e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ....|.....    0.97303 in (0.8, 1.2)
#                                   gmo_vf .........|   0.900991 in (0.0, 1.0)
#                           gmo_solv_rough ...|......     3.7558 in (1.0, 10.0)
#                                gmo_thick .....|....    17.7757 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.46273e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int .|........   0.841429 in (0.8, 1.2)
# step 278 cost 1.534(28)
# step 279 cost 1.530(28)
# step 280 cost 1.530(28)
# step 282 cost 1.530(28)
# step 284 cost 1.530(28)
# step 285 cost 1.530(28)
# step 286 cost 1.530(28)
# step 288 cost 1.530(28)
# step 289 cost 1.527(28)
# step 290 cost 1.527(28)
# step 291 cost 1.527(28)
# step 292 cost 1.527(28)
# step 294 cost 1.527(28)
# step 295 cost 1.527(28)
# step 296 cost 1.520(28)
# step 297 cost 1.520(28)
# step 298 cost 1.520(28)
# step 299 cost 1.520(28)
# step 300 cost 1.520(28)
# step 301 cost 1.520(28)
# step 302 cost 1.520(28)
# step 303 cost 1.520(28)
# step 304 cost 1.520(28)
# step 305 cost 1.520(28)
#                                Si_dd_bkg |......... 8.24108e-06 in (1e-10, 0.0001)
#                                Si_dd_int .....|....     1.0337 in (0.8, 1.2)
#                                 ddod rho .......|..    6.50813 in (6, 6.7)
#                            Si_SiO2_rough ......|...    7.10097 in (1.0, 10.0)
#                          SiO2_solv_rough .......|..    7.94542 in (1.0, 10.0)
#                               SiO2_thick ...|......    11.3672 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.39884e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.925082 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.85726e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ....|.....   0.969253 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.863959 in (0.0, 1.0)
#                           gmo_solv_rough .|........    2.41905 in (1.0, 10.0)
#                                gmo_thick ......|...    18.4801 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.55918e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........    0.83183 in (0.8, 1.2)
# step 306 cost 1.520(28)
# step 307 cost 1.520(28)
# step 308 cost 1.520(28)
# step 309 cost 1.520(28)
# step 310 cost 1.520(28)
# step 311 cost 1.520(28)
# step 312 cost 1.520(28)
# step 313 cost 1.520(28)
# step 315 cost 1.520(28)
# step 316 cost 1.520(28)
# step 317 cost 1.520(28)
# step 318 cost 1.520(28)
# step 319 cost 1.520(28)
# step 320 cost 1.520(28)
# step 321 cost 1.520(28)
# step 322 cost 1.520(28)
# step 323 cost 1.520(28)
# step 324 cost 1.520(28)
# step 325 cost 1.520(28)
# step 326 cost 1.520(28)
# step 327 cost 1.520(28)
# step 328 cost 1.520(28)
# step 329 cost 1.520(28)
# step 330 cost 1.520(28)
#                                Si_dd_bkg |......... 8.24108e-06 in (1e-10, 0.0001)
#                                Si_dd_int .....|....     1.0337 in (0.8, 1.2)
#                                 ddod rho .......|..    6.50813 in (6, 6.7)
#                            Si_SiO2_rough ......|...    7.10097 in (1.0, 10.0)
#                          SiO2_solv_rough .......|..    7.94542 in (1.0, 10.0)
#                               SiO2_thick ...|......    11.3672 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.39884e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.925082 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.85726e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ....|.....   0.969253 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.863959 in (0.0, 1.0)
#                           gmo_solv_rough .|........    2.41905 in (1.0, 10.0)
#                                gmo_thick ......|...    18.4801 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.55918e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........    0.83183 in (0.8, 1.2)
# step 331 cost 1.520(28)
# step 332 cost 1.520(28)
# step 333 cost 1.520(28)
# step 334 cost 1.520(28)
# step 335 cost 1.520(28)
# step 336 cost 1.520(28)
# step 337 cost 1.520(28)
# step 338 cost 1.520(28)
# step 339 cost 1.519(28)
# step 340 cost 1.519(28)
# step 341 cost 1.519(28)
# step 342 cost 1.519(28)
# step 343 cost 1.519(28)
# step 344 cost 1.519(28)
# step 345 cost 1.519(28)
# step 346 cost 1.519(28)
# step 347 cost 1.519(28)
# step 348 cost 1.519(28)
# step 349 cost 1.519(28)
# step 350 cost 1.519(28)
# step 351 cost 1.519(28)
# step 352 cost 1.519(28)
# step 353 cost 1.519(28)
#                                Si_dd_bkg |......... 8.30457e-06 in (1e-10, 0.0001)
#                                Si_dd_int .....|....    1.03435 in (0.8, 1.2)
#                                 ddod rho .......|..    6.50552 in (6, 6.7)
#                            Si_SiO2_rough ......|...    6.52851 in (1.0, 10.0)
#                          SiO2_solv_rough .......|..    8.06792 in (1.0, 10.0)
#                               SiO2_thick ...|......    11.7308 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.40715e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.932709 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.52173e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ....|.....   0.967986 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.882132 in (0.0, 1.0)
#                           gmo_solv_rough .|........    2.62298 in (1.0, 10.0)
#                                gmo_thick .....|....    18.0082 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.44804e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.832859 in (0.8, 1.2)
# step 354 cost 1.519(28)
# step 355 cost 1.519(28)
# step 356 cost 1.519(28)
# step 357 cost 1.519(28)
# step 358 cost 1.519(28)
# step 359 cost 1.518(28)
# step 360 cost 1.518(28)
# step 361 cost 1.518(28)
# step 362 cost 1.518(28)
# step 363 cost 1.518(28)
# step 364 cost 1.518(28)
# step 365 cost 1.518(28)
# step 366 cost 1.518(28)
# step 367 cost 1.518(28)
# step 368 cost 1.518(28)
# step 369 cost 1.518(28)
# step 370 cost 1.518(28)
#                                Si_dd_bkg |......... 8.31856e-06 in (1e-10, 0.0001)
#                                Si_dd_int .....|....    1.03385 in (0.8, 1.2)
#                                 ddod rho .......|..    6.50708 in (6, 6.7)
#                            Si_SiO2_rough .....|....    5.88255 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.20205 in (1.0, 10.0)
#                               SiO2_thick ...|......    12.0568 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.41206e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.930962 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.60909e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ....|.....   0.968368 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.878808 in (0.0, 1.0)
#                           gmo_solv_rough .|........    2.72783 in (1.0, 10.0)
#                                gmo_thick .....|....    18.2663 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.49769e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.831578 in (0.8, 1.2)
# step 371 cost 1.518(28)
# step 372 cost 1.518(28)
# step 373 cost 1.518(28)
# step 374 cost 1.518(28)
# step 375 cost 1.518(28)
# step 376 cost 1.518(28)
# step 377 cost 1.518(28)
# step 378 cost 1.518(28)
# step 379 cost 1.518(28)
# step 380 cost 1.518(28)
# step 381 cost 1.518(28)
# step 382 cost 1.518(28)
# step 383 cost 1.517(28)
# step 384 cost 1.517(28)
# step 385 cost 1.517(28)
# step 386 cost 1.517(28)
# step 387 cost 1.517(28)
# step 388 cost 1.517(28)
# step 389 cost 1.517(28)
#                                Si_dd_bkg |......... 8.3248e-06 in (1e-10, 0.0001)
#                                Si_dd_int .....|....    1.03519 in (0.8, 1.2)
#                                 ddod rho .......|..    6.50697 in (6, 6.7)
#                            Si_SiO2_rough .....|....    5.58937 in (1.0, 10.0)
#                          SiO2_solv_rough .......|..    8.17541 in (1.0, 10.0)
#                               SiO2_thick ...|......    12.2279 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.36548e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.930859 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.49924e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ....|.....   0.968997 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.881078 in (0.0, 1.0)
#                           gmo_solv_rough .|........    2.74749 in (1.0, 10.0)
#                                gmo_thick ......|...    18.4362 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.46855e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.836003 in (0.8, 1.2)
# step 390 cost 1.517(28)
# step 391 cost 1.517(28)
# step 392 cost 1.517(28)
# step 393 cost 1.517(28)
# step 394 cost 1.517(28)
# step 395 cost 1.517(28)
# step 396 cost 1.517(28)
# step 397 cost 1.517(28)
# step 398 cost 1.517(28)
# step 399 cost 1.517(28)
# step 400 cost 1.517(28)
# step 401 cost 1.517(28)
# step 402 cost 1.517(28)
# step 403 cost 1.517(28)
# step 404 cost 1.517(28)
# step 405 cost 1.517(28)
# step 406 cost 1.517(28)
# step 407 cost 1.517(28)
# step 408 cost 1.517(28)
# step 409 cost 1.517(28)
# step 410 cost 1.517(28)
# step 411 cost 1.517(28)
# step 412 cost 1.517(28)
#                                Si_dd_bkg |......... 8.32851e-06 in (1e-10, 0.0001)
#                                Si_dd_int .....|....    1.03458 in (0.8, 1.2)
#                                 ddod rho .......|..    6.50645 in (6, 6.7)
#                            Si_SiO2_rough ....|.....    5.10028 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.26542 in (1.0, 10.0)
#                               SiO2_thick ...|......    12.4371 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.39971e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.931875 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.30823e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ....|.....   0.968738 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.883305 in (0.0, 1.0)
#                           gmo_solv_rough .|........    2.71965 in (1.0, 10.0)
#                                gmo_thick ......|...    18.4268 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.44871e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.836118 in (0.8, 1.2)
# step 413 cost 1.517(28)
# step 414 cost 1.517(28)
# step 415 cost 1.517(28)
# step 416 cost 1.517(28)
# step 417 cost 1.517(28)
# step 418 cost 1.517(28)
# step 419 cost 1.517(28)
# step 420 cost 1.517(28)
# step 421 cost 1.517(28)
# step 422 cost 1.517(28)
# step 423 cost 1.517(28)
# step 424 cost 1.517(28)
# step 425 cost 1.517(28)
# step 426 cost 1.517(28)
# step 427 cost 1.517(28)
# step 428 cost 1.517(28)
# step 429 cost 1.517(28)
# step 430 cost 1.517(28)
# step 431 cost 1.517(28)
# step 432 cost 1.517(28)
# step 433 cost 1.517(28)
#                                Si_dd_bkg |......... 8.38673e-06 in (1e-10, 0.0001)
#                                Si_dd_int .....|....    1.03451 in (0.8, 1.2)
#                                 ddod rho .......|..    6.50633 in (6, 6.7)
#                            Si_SiO2_rough ....|.....    5.28124 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.24422 in (1.0, 10.0)
#                               SiO2_thick ...|......    12.4139 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.36739e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.930125 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.23062e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ....|.....   0.968516 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.880149 in (0.0, 1.0)
#                           gmo_solv_rough .|........    2.45327 in (1.0, 10.0)
#                                gmo_thick ......|...    18.4086 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.52165e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.833198 in (0.8, 1.2)
# step 434 cost 1.517(28)
# step 435 cost 1.517(28)
# step 436 cost 1.517(28)
# step 437 cost 1.517(28)
# step 438 cost 1.517(28)
# step 439 cost 1.517(28)
# step 440 cost 1.517(28)
# step 441 cost 1.517(28)
# step 442 cost 1.517(28)
# step 443 cost 1.517(28)
# step 444 cost 1.517(28)
# step 445 cost 1.517(28)
# step 446 cost 1.517(28)
# step 447 cost 1.517(28)
# step 448 cost 1.517(28)
# step 449 cost 1.517(28)
#                                Si_dd_bkg |......... 8.39037e-06 in (1e-10, 0.0001)
#                                Si_dd_int .....|....    1.03433 in (0.8, 1.2)
#                                 ddod rho .......|..    6.50666 in (6, 6.7)
#                            Si_SiO2_rough ....|.....    5.31516 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.24027 in (1.0, 10.0)
#                               SiO2_thick ...|......    12.3859 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.36235e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.930585 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.27874e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ....|.....    0.96859 in (0.8, 1.2)
#                                   gmo_vf ........|.    0.87879 in (0.0, 1.0)
#                           gmo_solv_rough .|........     2.4294 in (1.0, 10.0)
#                                gmo_thick ......|...    18.4127 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.52754e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.833316 in (0.8, 1.2)
# step 450 cost 1.517(28)
# step 451 cost 1.517(28)
# step 452 cost 1.517(28)
# step 453 cost 1.517(28)
# step 454 cost 1.517(28)
# step 455 cost 1.516(28)
# step 456 cost 1.516(28)
# step 457 cost 1.516(28)
# step 458 cost 1.516(28)
# step 459 cost 1.516(28)
# step 460 cost 1.516(28)
# step 461 cost 1.516(28)
# step 462 cost 1.516(28)
# step 463 cost 1.516(28)
# step 464 cost 1.516(28)
#                                Si_dd_bkg |......... 8.39327e-06 in (1e-10, 0.0001)
#                                Si_dd_int .....|....    1.03443 in (0.8, 1.2)
#                                 ddod rho .......|..    6.50664 in (6, 6.7)
#                            Si_SiO2_rough ....|.....    5.29844 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.22189 in (1.0, 10.0)
#                               SiO2_thick ...|......    12.3869 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.37167e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.930836 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.38367e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ....|.....   0.968938 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.882698 in (0.0, 1.0)
#                           gmo_solv_rough .|........    2.61155 in (1.0, 10.0)
#                                gmo_thick .....|....    18.2925 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.49992e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.832878 in (0.8, 1.2)
# step 465 cost 1.516(28)
# step 466 cost 1.516(28)
# step 467 cost 1.516(28)
# step 468 cost 1.516(28)
# step 469 cost 1.516(28)
# step 470 cost 1.516(28)
# step 471 cost 1.516(28)
# step 472 cost 1.516(28)
# step 473 cost 1.516(28)
# step 474 cost 1.516(28)
# step 475 cost 1.516(28)
# step 476 cost 1.516(28)
# step 477 cost 1.516(28)
# step 478 cost 1.516(28)
# step 479 cost 1.516(28)
# step 480 cost 1.516(28)
# step 481 cost 1.516(28)
# step 482 cost 1.516(28)
# step 483 cost 1.516(28)
# step 484 cost 1.516(28)
# step 485 cost 1.516(28)
# step 486 cost 1.516(28)
#                                Si_dd_bkg |......... 8.40051e-06 in (1e-10, 0.0001)
#                                Si_dd_int .....|....    1.03424 in (0.8, 1.2)
#                                 ddod rho .......|..    6.50686 in (6, 6.7)
#                            Si_SiO2_rough ....|.....    5.19814 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.24435 in (1.0, 10.0)
#                               SiO2_thick ...|......    12.4517 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.37644e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.931531 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.36954e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ....|.....   0.968675 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.883889 in (0.0, 1.0)
#                           gmo_solv_rough .|........    2.62896 in (1.0, 10.0)
#                                gmo_thick .....|....    18.2937 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.51086e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.832835 in (0.8, 1.2)
# step 487 cost 1.516(28)
# step 488 cost 1.516(28)
# step 489 cost 1.516(28)
# step 490 cost 1.516(28)
# step 491 cost 1.516(28)
# step 492 cost 1.516(28)
# step 493 cost 1.516(28)
# step 494 cost 1.516(28)
# step 495 cost 1.516(28)
# step 496 cost 1.516(28)
# step 497 cost 1.516(28)
# step 498 cost 1.516(28)
# step 499 cost 1.516(28)
# step 500 cost 1.516(28)
# step 501 cost 1.516(28)
# step 502 cost 1.516(28)
#                                Si_dd_bkg |......... 8.40728e-06 in (1e-10, 0.0001)
#                                Si_dd_int .....|....     1.0346 in (0.8, 1.2)
#                                 ddod rho .......|..    6.50677 in (6, 6.7)
#                            Si_SiO2_rough ....|.....    4.90515 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.27432 in (1.0, 10.0)
#                               SiO2_thick ...|......    12.5547 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.36456e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.931679 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.41609e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ....|.....   0.968487 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.888018 in (0.0, 1.0)
#                           gmo_solv_rough ..|.......    2.86909 in (1.0, 10.0)
#                                gmo_thick .....|....    18.2965 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.49954e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.832647 in (0.8, 1.2)
# step 503 cost 1.516(28)
# step 504 cost 1.516(28)
# step 505 cost 1.516(28)
# step 506 cost 1.516(28)
# step 507 cost 1.516(28)
# step 508 cost 1.516(28)
# step 509 cost 1.516(28)
# step 510 cost 1.516(28)
# step 511 cost 1.516(28)
# step 512 cost 1.516(28)
# step 513 cost 1.516(28)
# step 514 cost 1.516(28)
# step 515 cost 1.516(28)
# step 516 cost 1.516(28)
# step 517 cost 1.516(28)
# step 518 cost 1.516(28)
# step 519 cost 1.516(28)
# step 520 cost 1.516(28)
# step 521 cost 1.516(28)
# step 522 cost 1.516(28)
# step 523 cost 1.516(28)
# step 524 cost 1.516(28)
# step 525 cost 1.516(28)
#                                Si_dd_bkg |......... 8.41793e-06 in (1e-10, 0.0001)
#                                Si_dd_int .....|....    1.03449 in (0.8, 1.2)
#                                 ddod rho .......|..     6.5069 in (6, 6.7)
#                            Si_SiO2_rough ....|.....     4.6363 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.30829 in (1.0, 10.0)
#                               SiO2_thick ....|.....    12.6459 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.39343e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.932599 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.53648e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ....|.....   0.968282 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.889558 in (0.0, 1.0)
#                           gmo_solv_rough ..|.......    3.00848 in (1.0, 10.0)
#                                gmo_thick .....|....    18.3484 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.47273e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.833866 in (0.8, 1.2)
# step 526 cost 1.516(28)
# step 527 cost 1.516(28)
# step 528 cost 1.516(28)
# step 529 cost 1.516(28)
# step 530 cost 1.516(28)
# step 531 cost 1.516(28)
# step 532 cost 1.516(28)
# step 533 cost 1.516(28)
# step 534 cost 1.516(28)
# step 535 cost 1.516(28)
# step 536 cost 1.516(28)
# step 537 cost 1.516(28)
# step 538 cost 1.516(28)
# step 539 cost 1.516(28)
# step 540 cost 1.516(28)
# step 541 cost 1.516(28)
# step 542 cost 1.516(28)
# step 543 cost 1.516(28)
# step 544 cost 1.516(28)
# step 545 cost 1.516(28)
# step 546 cost 1.516(28)
# step 547 cost 1.516(28)
# step 548 cost 1.516(28)
# step 549 cost 1.516(28)
#                                Si_dd_bkg |......... 8.41125e-06 in (1e-10, 0.0001)
#                                Si_dd_int .....|....    1.03463 in (0.8, 1.2)
#                                 ddod rho .......|..    6.50689 in (6, 6.7)
#                            Si_SiO2_rough ....|.....    4.68292 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.29413 in (1.0, 10.0)
#                               SiO2_thick ....|.....    12.6553 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.3651e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.932157 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.48161e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ....|.....    0.96846 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.890275 in (0.0, 1.0)
#                           gmo_solv_rough ..|.......      3.009 in (1.0, 10.0)
#                                gmo_thick .....|....    18.3199 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.46765e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.832746 in (0.8, 1.2)
# step 550 cost 1.516(28)
# step 551 cost 1.516(28)
# step 552 cost 1.516(28)
# step 553 cost 1.516(28)
# step 554 cost 1.516(28)
# step 555 cost 1.516(28)
# step 556 cost 1.516(28)
# step 557 cost 1.516(28)
# step 558 cost 1.516(28)
# step 559 cost 1.516(28)
# step 560 cost 1.516(28)
# step 561 cost 1.516(28)
# step 562 cost 1.516(28)
# step 563 cost 1.516(28)
# step 564 cost 1.516(28)
# step 565 cost 1.516(28)
# step 566 cost 1.516(28)
# step 567 cost 1.516(28)
# step 568 cost 1.516(28)
# step 569 cost 1.516(28)
# step 570 cost 1.516(28)
# step 571 cost 1.516(28)
# step 572 cost 1.516(28)
# step 573 cost 1.516(28)
# step 574 cost 1.516(28)
#                                Si_dd_bkg |......... 8.40887e-06 in (1e-10, 0.0001)
#                                Si_dd_int .....|....     1.0345 in (0.8, 1.2)
#                                 ddod rho .......|..    6.50696 in (6, 6.7)
#                            Si_SiO2_rough ...|......    4.44488 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.30869 in (1.0, 10.0)
#                               SiO2_thick ....|.....    12.7274 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.3405e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.932655 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.54172e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ....|.....   0.968493 in (0.8, 1.2)
#                                   gmo_vf ........|.    0.89187 in (0.0, 1.0)
#                           gmo_solv_rough ..|.......    3.15518 in (1.0, 10.0)
#                                gmo_thick ......|...    18.4052 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.4544e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.833636 in (0.8, 1.2)
# step 575 cost 1.516(28)
# step 576 cost 1.516(28)
# step 577 cost 1.516(28)
# step 578 cost 1.516(28)
# step 579 cost 1.516(28)
# step 580 cost 1.516(28)
# step 581 cost 1.516(28)
# step 582 cost 1.516(28)
# step 583 cost 1.516(28)
# step 584 cost 1.516(28)
# step 585 cost 1.516(28)
# step 586 cost 1.516(28)
# step 587 cost 1.516(28)
# step 589 cost 1.516(28)
# step 591 cost 1.516(28)
# step 593 cost 1.516(28)
# step 595 cost 1.516(28)
# step 597 cost 1.516(28)
# step 599 cost 1.516(28)
#                                Si_dd_bkg |......... 8.42016e-06 in (1e-10, 0.0001)
#                                Si_dd_int .....|....    1.03459 in (0.8, 1.2)
#                                 ddod rho .......|..    6.50663 in (6, 6.7)
#                            Si_SiO2_rough ...|......     4.0597 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.     8.3275 in (1.0, 10.0)
#                               SiO2_thick ....|.....    12.8673 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.32117e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.932554 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.61509e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ....|.....   0.968476 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.896112 in (0.0, 1.0)
#                           gmo_solv_rough ..|.......    3.38873 in (1.0, 10.0)
#                                gmo_thick ......|...    18.4275 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.43797e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.834032 in (0.8, 1.2)
# step 601 cost 1.516(28)
# step 603 cost 1.516(28)
# step 605 cost 1.516(28)
# step 607 cost 1.516(28)
# step 609 cost 1.516(28)
# step 611 cost 1.516(28)
# step 613 cost 1.516(28)
# step 615 cost 1.516(28)
# step 616 cost 1.516(28)
# step 617 cost 1.516(28)
#                                Si_dd_bkg |......... 8.42325e-06 in (1e-10, 0.0001)
#                                Si_dd_int .....|....    1.03441 in (0.8, 1.2)
#                                 ddod rho .......|..    6.50676 in (6, 6.7)
#                            Si_SiO2_rough ...|......    4.06617 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.     8.3162 in (1.0, 10.0)
#                               SiO2_thick ....|.....    12.8573 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.32239e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.932608 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.62619e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ....|.....   0.968478 in (0.8, 1.2)
#                                   gmo_vf ........|.    0.89552 in (0.0, 1.0)
#                           gmo_solv_rough ..|.......    3.37108 in (1.0, 10.0)
#                                gmo_thick ......|...    18.4469 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.43888e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.833946 in (0.8, 1.2)
# step 618 cost 1.516(28)
# step 619 cost 1.516(28)
# step 620 cost 1.516(28)
# step 621 cost 1.516(28)
# step 622 cost 1.516(28)
# step 623 cost 1.516(28)
# step 624 cost 1.516(28)
# step 625 cost 1.516(28)
# step 626 cost 1.516(28)
# step 627 cost 1.516(28)
# step 628 cost 1.516(28)
# step 629 cost 1.516(28)
# step 630 cost 1.516(28)
# step 631 cost 1.516(28)
# step 632 cost 1.516(28)
# step 633 cost 1.516(28)
# step 634 cost 1.516(28)
#                                Si_dd_bkg |......... 8.43504e-06 in (1e-10, 0.0001)
#                                Si_dd_int .....|....     1.0344 in (0.8, 1.2)
#                                 ddod rho .......|..    6.50679 in (6, 6.7)
#                            Si_SiO2_rough ...|......     3.7879 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.32331 in (1.0, 10.0)
#                               SiO2_thick ....|.....    12.9291 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.31678e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......    0.93302 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.63947e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ....|.....   0.968346 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.897598 in (0.0, 1.0)
#                           gmo_solv_rough ..|.......    3.51913 in (1.0, 10.0)
#                                gmo_thick ......|...     18.527 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.42764e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.834609 in (0.8, 1.2)
# step 635 cost 1.516(28)
# step 636 cost 1.516(28)
# step 637 cost 1.516(28)
# step 638 cost 1.516(28)
# step 639 cost 1.516(28)
# step 640 cost 1.516(28)
# step 641 cost 1.516(28)
# step 642 cost 1.516(28)
# step 643 cost 1.516(28)
# step 644 cost 1.516(28)
# step 645 cost 1.516(28)
# step 646 cost 1.516(28)
# step 647 cost 1.516(28)
# step 648 cost 1.516(28)
# step 649 cost 1.516(28)
# step 650 cost 1.516(28)
# step 651 cost 1.516(28)
# step 652 cost 1.516(28)
# step 653 cost 1.516(28)
# step 654 cost 1.516(28)
#                                Si_dd_bkg |......... 8.42536e-06 in (1e-10, 0.0001)
#                                Si_dd_int .....|....    1.03433 in (0.8, 1.2)
#                                 ddod rho .......|..    6.50687 in (6, 6.7)
#                            Si_SiO2_rough ...|......    3.72288 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.     8.3336 in (1.0, 10.0)
#                               SiO2_thick ....|.....    12.9513 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.30931e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.933073 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.69679e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ....|.....   0.968366 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.898797 in (0.0, 1.0)
#                           gmo_solv_rough ..|.......    3.59312 in (1.0, 10.0)
#                                gmo_thick ......|...    18.5192 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.42196e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.834481 in (0.8, 1.2)
# step 655 cost 1.516(28)
# step 656 cost 1.516(28)
# step 657 cost 1.516(28)
# step 658 cost 1.516(28)
# step 659 cost 1.516(28)
# step 660 cost 1.516(28)
# step 661 cost 1.516(28)
# step 662 cost 1.516(28)
# step 663 cost 1.516(28)
# step 664 cost 1.516(28)
# step 665 cost 1.516(28)
# step 666 cost 1.516(28)
# step 667 cost 1.516(28)
# step 668 cost 1.516(28)
# step 669 cost 1.516(28)
# step 670 cost 1.516(28)
# step 671 cost 1.516(28)
# step 672 cost 1.516(28)
# step 673 cost 1.516(28)
# step 674 cost 1.516(28)
#                                Si_dd_bkg |......... 8.43165e-06 in (1e-10, 0.0001)
#                                Si_dd_int .....|....     1.0344 in (0.8, 1.2)
#                                 ddod rho .......|..    6.50689 in (6, 6.7)
#                            Si_SiO2_rough ..|.......    3.66399 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.33863 in (1.0, 10.0)
#                               SiO2_thick ....|.....    12.9752 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.29544e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.933225 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.7089e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ....|.....   0.968518 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.899424 in (0.0, 1.0)
#                           gmo_solv_rough ..|.......    3.62862 in (1.0, 10.0)
#                                gmo_thick ......|...    18.5275 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.41873e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........    0.83481 in (0.8, 1.2)
# step 675 cost 1.516(28)
# step 676 cost 1.516(28)
# step 677 cost 1.516(28)
# step 678 cost 1.516(28)
# step 679 cost 1.516(28)
# step 680 cost 1.516(28)
# step 681 cost 1.516(28)
# step 682 cost 1.516(28)
# step 683 cost 1.516(28)
# step 684 cost 1.516(28)
# step 685 cost 1.516(28)
# step 686 cost 1.516(28)
# step 687 cost 1.516(28)
# step 688 cost 1.516(28)
# step 689 cost 1.516(28)
# step 690 cost 1.516(28)
# step 691 cost 1.516(28)
# step 692 cost 1.516(28)
# step 693 cost 1.516(28)
# step 694 cost 1.516(28)
#                                Si_dd_bkg |......... 8.43031e-06 in (1e-10, 0.0001)
#                                Si_dd_int .....|....    1.03441 in (0.8, 1.2)
#                                 ddod rho .......|..    6.50687 in (6, 6.7)
#                            Si_SiO2_rough ..|.......    3.57645 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.33825 in (1.0, 10.0)
#                               SiO2_thick ....|.....    12.9931 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.29642e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.933306 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.72523e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ....|.....   0.968484 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.899678 in (0.0, 1.0)
#                           gmo_solv_rough ..|.......    3.67282 in (1.0, 10.0)
#                                gmo_thick ......|...    18.5694 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.42342e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.834972 in (0.8, 1.2)
# step 695 cost 1.516(28)
# step 696 cost 1.516(28)
# step 697 cost 1.516(28)
# step 698 cost 1.516(28)
# step 699 cost 1.516(28)
# step 700 cost 1.516(28)
# step 701 cost 1.516(28)
# step 702 cost 1.516(28)
# step 703 cost 1.516(28)
# step 704 cost 1.516(28)
# step 705 cost 1.516(28)
# step 706 cost 1.516(28)
# step 707 cost 1.516(28)
# step 708 cost 1.516(28)
# step 709 cost 1.516(28)
# step 710 cost 1.516(28)
# step 711 cost 1.516(28)
#                                Si_dd_bkg |......... 8.43031e-06 in (1e-10, 0.0001)
#                                Si_dd_int .....|....    1.03441 in (0.8, 1.2)
#                                 ddod rho .......|..    6.50687 in (6, 6.7)
#                            Si_SiO2_rough ..|.......    3.57645 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.33825 in (1.0, 10.0)
#                               SiO2_thick ....|.....    12.9931 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.29642e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.933306 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.72523e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ....|.....   0.968484 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.899678 in (0.0, 1.0)
#                           gmo_solv_rough ..|.......    3.67282 in (1.0, 10.0)
#                                gmo_thick ......|...    18.5694 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.42342e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.834972 in (0.8, 1.2)
# step 712 cost 1.516(28)
# step 713 cost 1.516(28)
# step 714 cost 1.516(28)
# step 715 cost 1.516(28)
# step 716 cost 1.516(28)
# step 717 cost 1.516(28)
# step 718 cost 1.516(28)
# step 719 cost 1.516(28)
# step 720 cost 1.516(28)
# step 721 cost 1.516(28)
# step 722 cost 1.516(28)
# ...
#                            Si_gmo_dd_bkg |......... 6.75119e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ....|.....   0.968478 in (0.8, 1.2)
#                                   gmo_vf .........|   0.900781 in (0.0, 1.0)
#                           gmo_solv_rough ...|......    3.72804 in (1.0, 10.0)
#                                gmo_thick ......|...    18.5663 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.41468e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........    0.83498 in (0.8, 1.2)
# step 835 cost 1.516(28)
# step 836 cost 1.516(28)
# step 837 cost 1.516(28)
# step 838 cost 1.516(28)
# step 839 cost 1.516(28)
# step 840 cost 1.516(28)
# step 841 cost 1.516(28)
# step 842 cost 1.516(28)
# step 843 cost 1.516(28)
# step 844 cost 1.516(28)
# step 845 cost 1.516(28)
# step 846 cost 1.516(28)
#                                Si_dd_bkg |......... 8.42775e-06 in (1e-10, 0.0001)
#                                Si_dd_int .....|....    1.03437 in (0.8, 1.2)
#                                 ddod rho .......|..    6.50679 in (6, 6.7)
#                            Si_SiO2_rough ..|.......    3.51277 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.33445 in (1.0, 10.0)
#                               SiO2_thick ....|.....    13.0075 in (1.0, 30.0)
#                                Si_hd_bkg |.........   6.29e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.933423 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.75225e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ....|.....   0.968489 in (0.8, 1.2)
#                                   gmo_vf .........|   0.900829 in (0.0, 1.0)
#                           gmo_solv_rough ...|......    3.73207 in (1.0, 10.0)
#                                gmo_thick ......|...    18.5698 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.41507e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.835018 in (0.8, 1.2)
# step 847 cost 1.516(28)
# step 848 cost 1.516(28)
# step 849 cost 1.516(28)
# step 850 cost 1.516(28)
# step 851 cost 1.516(28)
# step 852 cost 1.516(28)
# step 853 cost 1.516(28)
# step 854 cost 1.516(28)
# step 855 cost 1.516(28)
# step 856 cost 1.516(28)
# step 857 cost 1.516(28)
# step 858 cost 1.516(28)
#                                Si_dd_bkg |......... 8.42832e-06 in (1e-10, 0.0001)
#                                Si_dd_int .....|....    1.03439 in (0.8, 1.2)
#                                 ddod rho .......|..    6.50678 in (6, 6.7)
#                            Si_SiO2_rough ..|.......    3.50483 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.     8.3348 in (1.0, 10.0)
#                               SiO2_thick ....|.....    13.0098 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.28847e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.933407 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.75211e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ....|.....   0.968478 in (0.8, 1.2)
#                                   gmo_vf .........|   0.900948 in (0.0, 1.0)
#                           gmo_solv_rough ...|......    3.73831 in (1.0, 10.0)
#                                gmo_thick ......|...    18.5713 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.41377e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.835029 in (0.8, 1.2)
# step 859 cost 1.516(28)
# step 860 cost 1.516(28)
# step 861 cost 1.516(28)
# step 862 cost 1.516(28)
# step 863 cost 1.516(28)
# step 864 cost 1.516(28)
# step 865 cost 1.516(28)
# step 866 cost 1.516(28)
# step 867 cost 1.516(28)
# step 868 cost 1.516(28)
# step 869 cost 1.516(28)
# step 870 cost 1.516(28)
# step 871 cost 1.516(28)
# step 872 cost 1.516(28)
# step 873 cost 1.516(28)
# step 874 cost 1.516(28)
# step 875 cost 1.516(28)
# step 876 cost 1.516(28)
#                                Si_dd_bkg |......... 8.42868e-06 in (1e-10, 0.0001)
#                                Si_dd_int .....|....    1.03439 in (0.8, 1.2)
#                                 ddod rho .......|..    6.50678 in (6, 6.7)
#                            Si_SiO2_rough ..|.......    3.51546 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.33368 in (1.0, 10.0)
#                               SiO2_thick ....|.....    13.0058 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.2895e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.933408 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.75121e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ....|.....   0.968489 in (0.8, 1.2)
#                                   gmo_vf .........|   0.900864 in (0.0, 1.0)
#                           gmo_solv_rough ...|......    3.73344 in (1.0, 10.0)
#                                gmo_thick ......|...    18.5688 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.41504e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.835007 in (0.8, 1.2)
# step 877 cost 1.516(28)
# step 878 cost 1.516(28)
# step 879 cost 1.516(28)
# step 880 cost 1.516(28)
# step 881 cost 1.516(28)
# step 882 cost 1.516(28)
# step 883 cost 1.516(28)
# step 884 cost 1.516(28)
# step 885 cost 1.516(28)
# step 886 cost 1.516(28)
# step 887 cost 1.516(28)
# step 888 cost 1.516(28)
# step 889 cost 1.516(28)
# step 890 cost 1.516(28)
# step 891 cost 1.516(28)
# step 892 cost 1.516(28)
# step 893 cost 1.516(28)
# step 894 cost 1.516(28)
# step 895 cost 1.516(28)
# step 896 cost 1.516(28)
#                                Si_dd_bkg |......... 8.42899e-06 in (1e-10, 0.0001)
#                                Si_dd_int .....|....    1.03439 in (0.8, 1.2)
#                                 ddod rho .......|..    6.50678 in (6, 6.7)
#                            Si_SiO2_rough ..|.......    3.51233 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.33407 in (1.0, 10.0)
#                               SiO2_thick ....|.....     13.007 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.28919e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.933422 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.75298e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ....|.....   0.968491 in (0.8, 1.2)
#                                   gmo_vf .........|   0.900911 in (0.0, 1.0)
#                           gmo_solv_rough ...|......    3.73612 in (1.0, 10.0)
#                                gmo_thick ......|...    18.5688 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.41501e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........    0.83501 in (0.8, 1.2)
# step 897 cost 1.516(28)
# step 898 cost 1.516(28)
# step 899 cost 1.516(28)
# step 900 cost 1.516(28)
# step 901 cost 1.516(28)
# step 902 cost 1.516(28)
# step 903 cost 1.516(28)
# step 904 cost 1.516(28)
# step 905 cost 1.516(28)
# step 906 cost 1.516(28)
# step 907 cost 1.516(28)
# step 908 cost 1.516(28)
# step 909 cost 1.516(28)
# step 910 cost 1.516(28)
# step 911 cost 1.516(28)
#                                Si_dd_bkg |......... 8.42887e-06 in (1e-10, 0.0001)
#                                Si_dd_int .....|....    1.03439 in (0.8, 1.2)
#                                 ddod rho .......|..    6.50678 in (6, 6.7)
#                            Si_SiO2_rough ..|.......    3.51409 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.33366 in (1.0, 10.0)
#                               SiO2_thick ....|.....    13.0063 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.29008e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.933403 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.75161e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ....|.....   0.968487 in (0.8, 1.2)
#                                   gmo_vf .........|   0.900847 in (0.0, 1.0)
#                           gmo_solv_rough ...|......    3.73255 in (1.0, 10.0)
#                                gmo_thick ......|...    18.5693 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.41481e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.835017 in (0.8, 1.2)
# step 912 cost 1.516(28)
# step 913 cost 1.516(28)
# step 914 cost 1.516(28)
# step 915 cost 1.516(28)
# step 916 cost 1.516(28)
#                                Si_dd_bkg |......... 8.42866e-06 in (1e-10, 0.0001)
#                                Si_dd_int .....|....    1.03439 in (0.8, 1.2)
#                                 ddod rho .......|..    6.50678 in (6, 6.7)
#                            Si_SiO2_rough ..|.......    3.51418 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.33387 in (1.0, 10.0)
#                               SiO2_thick ....|.....    13.0068 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.28985e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.933398 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.75228e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ....|.....   0.968487 in (0.8, 1.2)
#                                   gmo_vf .........|   0.900866 in (0.0, 1.0)
#                           gmo_solv_rough ...|......    3.73515 in (1.0, 10.0)
#                                gmo_thick ......|...    18.5705 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.41442e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........    0.83501 in (0.8, 1.2)
# step 917 cost 1.516(28)
# step 918 cost 1.516(28)
# step 919 cost 1.516(28)
# step 920 cost 1.516(28)
# step 921 cost 1.516(28)
# step 922 cost 1.516(28)
# step 923 cost 1.516(28)
# step 924 cost 1.516(28)
# step 925 cost 1.516(28)
# step 926 cost 1.516(28)
# step 927 cost 1.516(28)
# step 928 cost 1.516(28)
# step 929 cost 1.516(28)
# step 930 cost 1.516(28)
# step 931 cost 1.516(28)
# step 932 cost 1.516(28)
# step 933 cost 1.516(28)
# step 934 cost 1.516(28)
# step 935 cost 1.516(28)
# step 936 cost 1.516(28)
# step 937 cost 1.516(28)
# step 938 cost 1.516(28)
#                                Si_dd_bkg |......... 8.42906e-06 in (1e-10, 0.0001)
#                                Si_dd_int .....|....    1.03439 in (0.8, 1.2)
#                                 ddod rho .......|..    6.50678 in (6, 6.7)
#                            Si_SiO2_rough ..|.......    3.51355 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.33369 in (1.0, 10.0)
#                               SiO2_thick ....|.....     13.007 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.28954e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.933401 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |.........  6.753e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ....|.....   0.968493 in (0.8, 1.2)
#                                   gmo_vf .........|   0.900883 in (0.0, 1.0)
#                           gmo_solv_rough ...|......    3.73545 in (1.0, 10.0)
#                                gmo_thick ......|...    18.5695 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.41449e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.835012 in (0.8, 1.2)
# step 939 cost 1.516(28)
# step 940 cost 1.516(28)
# step 941 cost 1.516(28)
# step 942 cost 1.516(28)
# step 943 cost 1.516(28)
# step 944 cost 1.516(28)
# step 945 cost 1.516(28)
# step 946 cost 1.516(28)
# step 947 cost 1.516(28)
# step 948 cost 1.516(28)
# step 949 cost 1.516(28)
# step 950 cost 1.516(28)
# step 951 cost 1.516(28)
# step 952 cost 1.516(28)
# step 953 cost 1.516(28)
# step 954 cost 1.516(28)
# step 955 cost 1.516(28)
# step 956 cost 1.516(28)
# step 957 cost 1.516(28)
# step 958 cost 1.516(28)
#                                Si_dd_bkg |......... 8.42907e-06 in (1e-10, 0.0001)
#                                Si_dd_int .....|....    1.03439 in (0.8, 1.2)
#                                 ddod rho .......|..    6.50678 in (6, 6.7)
#                            Si_SiO2_rough ..|.......    3.51018 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.33388 in (1.0, 10.0)
#                               SiO2_thick ....|.....    13.0082 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.28968e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.933399 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.75448e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ....|.....   0.968493 in (0.8, 1.2)
#                                   gmo_vf .........|   0.900938 in (0.0, 1.0)
#                           gmo_solv_rough ...|......    3.73886 in (1.0, 10.0)
#                                gmo_thick ......|...    18.5705 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.41412e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.835017 in (0.8, 1.2)
# step 959 cost 1.516(28)
# step 960 cost 1.516(28)
# step 961 cost 1.516(28)
# step 962 cost 1.516(28)
# step 963 cost 1.516(28)
# step 964 cost 1.516(28)
# step 965 cost 1.516(28)
# step 966 cost 1.516(28)
# step 967 cost 1.516(28)
# step 968 cost 1.516(28)
# step 969 cost 1.516(28)
# step 970 cost 1.516(28)
# step 971 cost 1.516(28)
# step 972 cost 1.516(28)
# step 973 cost 1.516(28)
# step 974 cost 1.516(28)
# step 975 cost 1.516(28)
# step 977 cost 1.516(28)
# step 978 cost 1.516(28)
# step 979 cost 1.516(28)
# step 980 cost 1.516(28)
# step 981 cost 1.516(28)
#                                Si_dd_bkg |......... 8.42925e-06 in (1e-10, 0.0001)
#                                Si_dd_int .....|....    1.03438 in (0.8, 1.2)
#                                 ddod rho .......|..    6.50679 in (6, 6.7)
#                            Si_SiO2_rough ..|.......     3.5013 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.33429 in (1.0, 10.0)
#                               SiO2_thick ....|.....      13.01 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.28904e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.933433 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.75487e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ....|.....    0.96849 in (0.8, 1.2)
#                                   gmo_vf .........|   0.900989 in (0.0, 1.0)
#                           gmo_solv_rough ...|......    3.74133 in (1.0, 10.0)
#                                gmo_thick ......|...    18.5714 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.41387e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.835041 in (0.8, 1.2)
# step 983 cost 1.516(28)
# step 984 cost 1.516(28)
# step 986 cost 1.516(28)
# step 988 cost 1.516(28)
# step 990 cost 1.516(28)
# step 992 cost 1.516(28)
# step 994 cost 1.516(28)
# step 995 cost 1.516(28)
# step 997 cost 1.516(28)
# step 999 cost 1.516(28)
# final chisq 1.516(28)
# === Uncertainty from curvature:     name   value(unc.) ===
#                                Si_dd_bkg   8.43(26)e-6
#                                Si_dd_int   1.0344(31)
#                                 ddod rho   6.5068(41)
#                            Si_SiO2_rough   3.5(42)
#                          SiO2_solv_rough   8.33(26)
#                               SiO2_thick   13.0(11)
#                                Si_hd_bkg   6.29(35)e-6
#                                Si_hd_int   0.933(11)
#                            Si_gmo_dd_bkg   6.8(11)e-6
#                            Si_gmo_dd_int   0.9685(31)
#                                   gmo_vf   0.901(39)
#                           gmo_solv_rough   3.7(23)
#                                gmo_thick   18.57(100)
#                            Si_gmo_hd_bkg   5.41(28)e-6
#                            Si_gmo_hd_int   0.835(11)
# ==========================================================

# %%
{k: v for k, v in zip(problem.labels(), problem.getp())}
# Out:
# {'Si_dd_bkg': np.float64(8.429094835706572e-06),
#  'Si_dd_int': np.float64(1.0343878785960876),
#  'ddod rho': np.float64(6.506783950682584),
#  'Si_SiO2_rough': np.float64(3.50083065064776),
#  'SiO2_solv_rough': np.float64(8.334098286610107),
#  'SiO2_thick': np.float64(13.01007750123238),
#  'Si_hd_bkg': np.float64(6.288966656944409e-06),
#  'Si_hd_int': np.float64(0.9334367861134208),
#  'Si_gmo_dd_bkg': np.float64(6.753469362673305e-06),
#  'Si_gmo_dd_int': np.float64(0.9684931812674907),
#  'gmo_vf': np.float64(0.9009567988136133),
#  'gmo_solv_rough': np.float64(3.7397850616851995),
#  'gmo_thick': np.float64(18.57178469167569),
#  'Si_gmo_hd_bkg': np.float64(5.413780279611777e-06),
#  'Si_gmo_hd_int': np.float64(0.8350259721144856)}

# %%
# the parameters are updated in the problem
np.testing.assert_allclose(problem.getp(), result.x)

# %% [markdown]
# ## Plot the data & model

# %%
# %matplotlib inline
for mod in problem.models:
    plt.errorbar(x=mod.probe.Q, y=mod.probe.R, yerr=mod.probe.dR, linestyle='None', marker='.')
    plt.plot(*mod.reflectivity(), color='k', zorder=10)
plt.xscale('log')
plt.yscale('log')

# %% [markdown]
# ## Plot the structure of the vfp
#
# Use the vfp's plot method to plot the SLD, volume fraction profile and a stochastic simulation of the interface.
#
# In the current implementation, there is no way to plot the posterior, but this will be added.

# %%
dd_vfp_bare.plot() # equivalent to glob_obj.objectives[0].model.structure.components[1].plot()
plt.show()

# %%
dd_vfp_gmo.plot() # equivalent to glob_obj.objectives[2].model.structure.components[1].plot()
plt.show()
