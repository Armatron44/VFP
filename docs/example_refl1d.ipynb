# %% [markdown]
# # Example usage of `vfp` with refl1d
#
# To demonstrate the `vfp` we'll model some NR data taken with a Si substrate.
#
# Two NR contrasts were taken in a solid-liquid cell with dodecane ($\mathrm{C}_{12}\mathrm{H}_{26}$ \& $\mathrm{C}_{12}\mathrm{D}_{26}$).
#
# Two other contrasts were taken with the same substrate with solutions of glycerol monooleate, a surfactant, in $\mathrm{C}_{12}\mathrm{H}_{26}$ \& $\mathrm{C}_{12}\mathrm{D}_{26}$.

# %%
import pathlib
import os
import matplotlib.pyplot as plt
import numpy as np
from functools import partial

from bumps.parameter import Parameter
import refl1d
from bumps.parameter import Parameter
from bumps.fitproblem import FitProblem 

from refl1d.experiment import Experiment
from refl1d.probe.resolution import sigma2FWHM
from refl1d.sample.material import SLD, Material
from refl1d.sample.layers import Slab, Stack
from refl1d.probe import NeutronProbe

import vfp

# %%
def qt2l(q,t):
    """
    Get wavelength from q and theta.
    """
    return 4 * np.pi * np.sin(np.radians(t)) / q

def tof_loader(filename,
               t=0.25, 
               dqoq=0.03, 
               delimiter="\t", 
               **kw):
    """
    Loads and creates NeutronProbe objects for TOF stitched datasets
    I.e. from multiple angles. In the case of ISIS NR instruments we 
    typically have a constant dq/q resolution which the data is binned to at
    the end of the reduction.

    T incident theta for the lowest angle
    dQoQ dq/q resolution data has been binned to
    filename filename of the data set to be loaded
    kw keyword arguments (kwargs) to be passed to NeutronProbe()
    """
    q, r, dr = np.loadtxt(filename, delimiter=delimiter).T
    data_in = (r, dr)
    
    l = qt2l(q, t)
    # Converting the dq/q resolution into a dq value for each Q point
    
    #dq = sigma2FWHM(q*dqoq)

    probe_out = NeutronProbe(
        T=t, 
        dT=0, 
        L=l, 
        dL=0, 
        data=data_in, 
        #dQo=dq, 
        resolution='normal',
        **kw 
    )

    return probe_out

# %%
dataset_dir = pathlib.Path(vfp.__path__[0]).parents[1] / 'docs'
with os.scandir(dataset_dir) as files:
    nr_data_fps = [file.name for file in files if file.name.startswith('IvsQ')]
    data_fp_dict = {'ddod' : nr_data_fps[0],
                    'hdod' : nr_data_fps[1],
                    'hdod_gmo' : nr_data_fps[2],
                    'ddod_gmo' : nr_data_fps[3]}

# %%
tof_loader_partial = partial(tof_loader, t=0.7, delimiter=',')
probes = map(tof_loader_partial, (dataset_dir /file_name for file_name in data_fp_dict.values()))

# %%
si_dd_probe, si_hd_probe, si_hd_gmo_probe, si_dd_gmo_probe = probes

# %%
plt.errorbar(x=si_dd_probe.Q, 
             y=si_dd_probe.R, 
             yerr=si_dd_probe.dR, 
             marker='.', 
             linestyle='None',
             label=r'Si dd')
plt.errorbar(x=si_dd_gmo_probe.Q, 
             y=si_dd_gmo_probe.R, 
             yerr=si_dd_gmo_probe.dR, 
             marker='.', 
             linestyle='None',
             label=r'Si dd gmo')
plt.errorbar(x=si_hd_probe.Q, 
             y=si_hd_probe.R, 
             yerr=si_hd_probe.dR, 
             marker='.', 
             linestyle='None',
             label=r'Si hd')
plt.errorbar(x=si_hd_gmo_probe.Q, 
             y=si_hd_gmo_probe.R, 
             yerr=si_hd_gmo_probe.dR, 
             marker='.', 
             linestyle='None',
             label=r'Si hd gmo')
plt.legend(frameon=False)
plt.xscale('log') 
plt.yscale('log')
plt.xlabel(r'$Q$ / $\mathrm{\AA{}}^{-1}$')
plt.ylabel(r'$R\left(Q\right)$')
plt.show()

# %% [markdown]
# # The model
# We'll model the bare Si data with a fronting of Si, and layer of $\mathrm{SiO}_{2}$ and a solvent backing.
#
# The SLDs of the materials will be fixed but we'll model the thickness of the $\mathrm{SiO}_{2}$ and the roughness of the interfaces between the materials.
#
# For those contrasts with GMO, we'll model a GMO layer with a fixed SLD of GMO = $0.21 \times 10^{-6} \mathrm{\AA}^{-2}$, a varying solvation, thickness and roughness.
#
# There will be the same interface width between $\mathrm{SiO}_{2}$ and the solvent and between $\mathrm{SiO}_{2}$ and GMO.

# %%
Si = SLD(rho=2.07, name='Si')
SiO2 = SLD(rho=3.47, name='SiO2')
gmo = SLD(rho=0.21, name='gmo')

hdod = SLD(rho=-0.46, name='hdod')
ddod = SLD(rho=6.7, name='ddod')

# lets vary the ddod but not the hdod.
ddod.rho.range(6, 6.7)
# Out:
# Parameter(ddod rho)

# %%
# define thickness and roughness parameters.
SiO2_thick = Parameter(value=20, name='SiO2_thick', vary=True, bounds=(1, 30))
gmo_thick = Parameter(value=20, name='gmo_thick', vary=True, bounds=(1, 30))

Si_SiO2_rough = Parameter(value=3, name='Si_SiO2_rough', vary=True, bounds=(1, 10))
SiO2_solv_rough = Parameter(5, name='SiO2_solv_rough', vary=True, bounds=(1, 10))

SiO2_gmo_rough = SiO2_solv_rough # Parameter(name='SiO2_gmo_rough', constraint=SiO2_solv_rough)
gmo_solv_rough = Parameter(5, name='gmo_solv_rough', vary=True, bounds=(1, 10))

gmo_vf = Parameter(value=1, name='gmo_vf', vary=True, bounds=(0, 1))

# %% [markdown]
# # refl1d works from backing to fronting...

# %%
# define the SLDs of the materials in two lists for the two contrasts.
dd_nslds = [Si.rho,
            SiO2.rho,
            ddod.rho]

hd_nslds = [Si.rho,
            SiO2.rho,
            hdod.rho]

dd_gmo_nslds = [Si.rho,
                SiO2.rho,
                gmo.rho * gmo_vf + ddod.rho * (1-gmo_vf),
                ddod.rho]

hd_gmo_nslds = [Si.rho,
                SiO2.rho,
                gmo.rho * gmo_vf + hdod.rho * (1-gmo_vf),
                hdod.rho]

# define the thicknesses of the all layers, including the fronting but not the backing.
list_of_thicknesses_bare = [0, SiO2_thick]
list_of_thicknesses_gmo = [0, SiO2_thick, gmo_thick]
# define the width the of the interfaces between the materials.
list_of_roughnesses_bare = [Si_SiO2_rough, SiO2_solv_rough]
list_of_roughnesses_gmo = [Si_SiO2_rough, SiO2_gmo_rough, gmo_solv_rough]

# use the list of SLDs, thicknesses and roughnesses to define refnxVFP objects.
dd_vfp_bare = vfp.refl1dVFP(nslds=dd_nslds,
                            thicknesses=list_of_thicknesses_bare,
                            roughnesses=list_of_roughnesses_bare,
                            orientation='back')

hd_vfp_bare = vfp.refl1dVFP(nslds=hd_nslds,
                            thicknesses=list_of_thicknesses_bare,
                            roughnesses=list_of_roughnesses_bare,
                            orientation='back')

dd_vfp_gmo = vfp.refl1dVFP(nslds=dd_gmo_nslds,
                           thicknesses=list_of_thicknesses_gmo,
                           roughnesses=list_of_roughnesses_gmo,
                           orientation='back')

hd_vfp_gmo = vfp.refl1dVFP(nslds=hd_gmo_nslds,
                           thicknesses=list_of_thicknesses_gmo,
                           roughnesses=list_of_roughnesses_gmo,
                           orientation='back')
# Out:
# C:\Users\sandy\OneDrive\PDRA - Job 2021-2024\VFP\src\vfp\vfp.py:962: UserWarning: If msld / isld parameters are part of a function (i.e f(p1, p2) = p1 + p2), they must be of type bumps.parameter.Parameter. Do not use material or SLD objects.
#   warnings.warn(

# %%
# see the parameters in the refnxVFP
# these contain non varying parameters.
print(dd_vfp_gmo.layer_parameters())
# Out:
# {'nslds': [Parameter(Si rho), Parameter(SiO2 rho), Parameter(gmo rho), Parameter(gmo_vf), Parameter(ddod rho)], 'thicknesses': [Parameter(refl1dVFP - thicknesses - fronting), Parameter(SiO2_thick), Parameter(gmo_thick)], 'roughnesses': [Parameter(Si_SiO2_rough), Parameter(SiO2_solv_rough), Parameter(gmo_solv_rough)], 'islds': [Parameter(refl1dVFP - isld - fronting), Parameter(refl1dVFP - isld - layer 1), Parameter(refl1dVFP - isld - layer 2), Parameter(refl1dVFP - isld - backing)], 'mslds': [Parameter(refl1dVFP - msld - fronting), Parameter(refl1dVFP - msld - layer 1), Parameter(refl1dVFP - msld - layer 2), Parameter(refl1dVFP - msld - backing)]}

# %%
# the refnxVFP objects are refnx Component objects so can be placed in a refnx structure.
# place vfps between SLD objects.
dd_struc = ddod | dd_vfp_bare | Si
hd_struc = hdod | hd_vfp_bare | Si
dd_GMO_struc = ddod | dd_vfp_gmo | Si
hd_GMO_struc = hdod | hd_vfp_gmo | Si

# %%
# define instrument / nuisance parameters
si_dd_probe.intensity.range(0.8, 1.2)
si_dd_probe.intensity.name = "Si_dd_int"
si_hd_probe.intensity.range(0.8, 1.2)
si_hd_probe.intensity.name = "Si_hd_int"
si_dd_gmo_probe.intensity.range(0.8, 1.2)
si_dd_gmo_probe.intensity.name = "Si_gmo_dd_int"
si_hd_gmo_probe.intensity.range(0.8, 1.2)
si_hd_gmo_probe.intensity.name = "Si_gmo_hd_int"

si_dd_probe.background.value = 1e-6
si_dd_probe.background.range(1e-10, 1e-4)
si_dd_probe.background.name = "Si_dd_bkg"
si_hd_probe.background.value = 1e-6
si_hd_probe.background.range(1e-10, 1e-4)
si_hd_probe.background.name = "Si_hd_bkg"
si_dd_gmo_probe.background.range(1e-10, 1e-4)
si_dd_gmo_probe.background.value = 1e-6
si_dd_gmo_probe.background.name = "Si_gmo_dd_bkg"
si_hd_gmo_probe.background.range(1e-10, 1e-4)
si_hd_gmo_probe.background.value = 1e-6
si_hd_gmo_probe.background.name = "Si_gmo_hd_bkg"

# %%
exp_si_dd = Experiment(probe=si_dd_probe, sample=dd_struc)
exp_si_hd = Experiment(probe=si_hd_probe, sample=hd_struc)
exp_si_dd_gmo = Experiment(probe=si_dd_gmo_probe, sample=dd_GMO_struc)
exp_si_hd_gmo = Experiment(probe=si_hd_gmo_probe, sample=hd_GMO_struc)

# %%
problem = FitProblem([exp_si_dd, exp_si_hd, exp_si_dd_gmo, exp_si_hd_gmo])

# %%
problem.labels()
# Out:
# ['Si_dd_bkg',
#  'Si_dd_int',
#  'ddod rho',
#  'Si_SiO2_rough',
#  'SiO2_solv_rough',
#  'SiO2_thick',
#  'Si_hd_bkg',
#  'Si_hd_int',
#  'Si_gmo_dd_bkg',
#  'Si_gmo_dd_int',
#  'gmo_vf',
#  'gmo_solv_rough',
#  'gmo_thick',
#  'Si_gmo_hd_bkg',
#  'Si_gmo_hd_int']

# %% [markdown]
# # fit via `bumps.fitters.fit`.
#
# It's more common to write a `refl1d` script and use the cli or the GUI.
# But we can do it interactively...

# %%
from bumps.mapper import MPMapper
from bumps.fitters import fit
mapper = MPMapper.start_mapper(problem, None, cpus=0) #cpu=0 for all CPUs
result = fit(problem, method="de", mapper=mapper, verbose=True, options=dict(steps=1000, pop=160))
# Out:
# step 1 cost 33.778(28)
#                                Si_dd_bkg |.........      1e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....          1 in (0.8, 1.2)
#                                 ddod rho .........|        6.7 in (6, 6.7)
#                            Si_SiO2_rough ..|.......          3 in (1.0, 10.0)
#                          SiO2_solv_rough ....|.....          5 in (1.0, 10.0)
#                               SiO2_thick ......|...         20 in (1.0, 30.0)
#                                Si_hd_bkg |.........      1e-06 in (1e-10, 0.0001)
#                                Si_hd_int ....|.....          1 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |.........      1e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ....|.....          1 in (0.8, 1.2)
#                                   gmo_vf .........|          1 in (0.0, 1.0)
#                           gmo_solv_rough ....|.....          5 in (1.0, 10.0)
#                                gmo_thick ......|...         20 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |.........      1e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int ....|.....          1 in (0.8, 1.2)
# step 6 cost 33.778(28)
# step 10 cost 33.778(28)
# step 15 cost 33.778(28)
# step 19 cost 33.778(28)
# step 24 cost 33.778(28)
# step 29 cost 33.778(28)
# step 33 cost 33.778(28)
# step 37 cost 33.778(28)
# step 40 cost 33.778(28)
# step 43 cost 33.778(28)
# step 47 cost 18.008(28)
# step 50 cost 18.008(28)
# step 53 cost 18.008(28)
# step 56 cost 18.008(28)
# step 59 cost 18.008(28)
# step 62 cost 17.866(28)
# step 64 cost 17.866(28)
# step 66 cost 12.779(28)
# step 69 cost 12.329(28)
# step 72 cost 12.148(28)
# step 74 cost 12.148(28)
# step 76 cost 10.593(28)
# step 78 cost 9.606(28)
# step 80 cost 9.606(28)
#                                Si_dd_bkg .|........  1.036e-05 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.960636 in (0.8, 1.2)
#                                 ddod rho .........|    6.65711 in (6, 6.7)
#                            Si_SiO2_rough ..|.......    3.53238 in (1.0, 10.0)
#                          SiO2_solv_rough ...|......    4.15355 in (1.0, 10.0)
#                               SiO2_thick ...|......    11.6208 in (1.0, 30.0)
#                                Si_hd_bkg |......... 8.75133e-06 in (1e-10, 0.0001)
#                                Si_hd_int ....|.....   0.974785 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 5.25079e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ..|.......   0.912981 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.874527 in (0.0, 1.0)
#                           gmo_solv_rough ...|......    4.29799 in (1.0, 10.0)
#                                gmo_thick .....|....    16.2756 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 6.07747e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int .....|....    1.02894 in (0.8, 1.2)
# step 83 cost 7.954(28)
# step 86 cost 7.954(28)
# step 88 cost 7.931(28)
# step 91 cost 7.003(28)
# step 94 cost 7.003(28)
# step 96 cost 6.426(28)
# step 98 cost 6.426(28)
# step 100 cost 6.426(28)
# step 102 cost 6.426(28)
# step 104 cost 6.002(28)
# step 106 cost 6.002(28)
# step 108 cost 5.291(28)
# step 110 cost 5.291(28)
# step 112 cost 5.002(28)
# step 114 cost 4.819(28)
# step 116 cost 4.819(28)
# step 118 cost 4.819(28)
# step 120 cost 4.680(28)
# step 122 cost 4.127(28)
# step 124 cost 4.127(28)
# step 126 cost 4.127(28)
# step 128 cost 4.127(28)
# step 130 cost 4.127(28)
# step 132 cost 4.127(28)
# step 134 cost 4.042(28)
#                                Si_dd_bkg |......... 9.15991e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.971391 in (0.8, 1.2)
#                                 ddod rho ........|.    6.62146 in (6, 6.7)
#                            Si_SiO2_rough ..|.......    3.37524 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.48014 in (1.0, 10.0)
#                               SiO2_thick ....|.....    12.9776 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.4016e-06 in (1e-10, 0.0001)
#                                Si_hd_int ......|...    1.04571 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 9.12405e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......   0.950196 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.823514 in (0.0, 1.0)
#                           gmo_solv_rough .|........    2.47034 in (1.0, 10.0)
#                                gmo_thick ......|...    20.7213 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.18037e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int .|........   0.875871 in (0.8, 1.2)
# step 136 cost 4.042(28)
# step 138 cost 4.011(28)
# step 140 cost 4.011(28)
# step 142 cost 4.011(28)
# step 144 cost 3.948(28)
# step 146 cost 3.948(28)
# step 148 cost 3.948(28)
# step 150 cost 3.774(28)
# step 152 cost 3.774(28)
# step 154 cost 3.774(28)
# step 156 cost 3.774(28)
# step 158 cost 3.774(28)
# step 160 cost 3.774(28)
# step 162 cost 3.774(28)
# step 164 cost 3.635(28)
# step 166 cost 3.617(28)
# step 168 cost 3.617(28)
# step 170 cost 3.614(28)
# step 171 cost 3.601(28)
# step 173 cost 3.601(28)
#                                Si_dd_bkg |......... 7.47197e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.977603 in (0.8, 1.2)
#                                 ddod rho ........|.     6.6221 in (6, 6.7)
#                            Si_SiO2_rough .|........    2.07155 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.73267 in (1.0, 10.0)
#                               SiO2_thick ....|.....    13.3347 in (1.0, 30.0)
#                                Si_hd_bkg |......... 7.41247e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.942285 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.36001e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ..|.......   0.915202 in (0.8, 1.2)
#                                   gmo_vf .........|   0.934421 in (0.0, 1.0)
#                           gmo_solv_rough ..|.......    3.04117 in (1.0, 10.0)
#                                gmo_thick ......|...    18.6451 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 6.12134e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........    0.83046 in (0.8, 1.2)
# step 175 cost 3.601(28)
# step 177 cost 3.516(28)
# step 179 cost 3.516(28)
# step 181 cost 3.476(28)
# step 183 cost 3.476(28)
# step 185 cost 3.476(28)
# step 187 cost 3.434(28)
# step 189 cost 3.434(28)
# step 190 cost 3.434(28)
# step 191 cost 3.434(28)
# step 193 cost 3.394(28)
# step 195 cost 3.394(28)
# step 197 cost 3.394(28)
# step 199 cost 3.394(28)
# step 200 cost 3.394(28)
# step 201 cost 3.394(28)
# step 202 cost 3.394(28)
# step 203 cost 3.394(28)
# step 204 cost 3.394(28)
# step 205 cost 3.394(28)
#                                Si_dd_bkg |......... 8.38745e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.982755 in (0.8, 1.2)
#                                 ddod rho ........|.    6.62153 in (6, 6.7)
#                            Si_SiO2_rough |.........    1.31427 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.68797 in (1.0, 10.0)
#                               SiO2_thick ....|.....    12.9878 in (1.0, 30.0)
#                                Si_hd_bkg |......... 7.09558e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.933961 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 7.75435e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ..|.......   0.916329 in (0.8, 1.2)
#                                   gmo_vf .........|   0.930503 in (0.0, 1.0)
#                           gmo_solv_rough ....|.....    4.71932 in (1.0, 10.0)
#                                gmo_thick .....|....      18.28 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.05754e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.838104 in (0.8, 1.2)
# step 207 cost 3.394(28)
# step 208 cost 3.394(28)
# step 209 cost 3.394(28)
# step 211 cost 3.373(28)
# step 213 cost 3.358(28)
# step 214 cost 3.358(28)
# step 215 cost 3.358(28)
# step 216 cost 3.358(28)
# step 217 cost 3.356(28)
# step 218 cost 3.353(28)
# step 220 cost 3.353(28)
# step 221 cost 3.351(28)
# step 223 cost 3.351(28)
# step 224 cost 3.351(28)
# step 225 cost 3.316(28)
# step 226 cost 3.316(28)
# step 227 cost 3.316(28)
# step 228 cost 3.316(28)
# step 229 cost 3.316(28)
# step 230 cost 3.316(28)
# step 231 cost 3.316(28)
# step 232 cost 3.316(28)
# step 233 cost 3.316(28)
#                                Si_dd_bkg |......... 8.68163e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.991535 in (0.8, 1.2)
#                                 ddod rho ........|.    6.61989 in (6, 6.7)
#                            Si_SiO2_rough .|........    2.65384 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.52361 in (1.0, 10.0)
#                               SiO2_thick ....|.....    13.1909 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.09213e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.942252 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.35185e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......   0.926192 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.869354 in (0.0, 1.0)
#                           gmo_solv_rough |.........    1.76695 in (1.0, 10.0)
#                                gmo_thick ......|...    18.9269 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.63821e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.834026 in (0.8, 1.2)
# step 234 cost 3.313(28)
# step 235 cost 3.313(28)
# step 236 cost 3.313(28)
# step 237 cost 3.313(28)
# step 238 cost 3.313(28)
# step 239 cost 3.313(28)
# step 240 cost 3.313(28)
# step 241 cost 3.313(28)
# step 243 cost 3.313(28)
# step 244 cost 3.308(28)
# step 245 cost 3.308(28)
# step 246 cost 3.308(28)
# step 247 cost 3.308(28)
# step 249 cost 3.308(28)
# step 250 cost 3.308(28)
# step 251 cost 3.303(28)
# step 252 cost 3.303(28)
# step 253 cost 3.303(28)
# step 254 cost 3.303(28)
# step 255 cost 3.303(28)
# step 256 cost 3.303(28)
# step 257 cost 3.302(28)
# step 258 cost 3.302(28)
# step 259 cost 3.302(28)
#                                Si_dd_bkg |......... 8.58821e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.992525 in (0.8, 1.2)
#                                 ddod rho ........|.    6.62113 in (6, 6.7)
#                            Si_SiO2_rough ...|......    4.24963 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.34511 in (1.0, 10.0)
#                               SiO2_thick ....|.....    12.7594 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.50179e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.939416 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.44204e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......   0.925951 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.868626 in (0.0, 1.0)
#                           gmo_solv_rough .|........    1.90194 in (1.0, 10.0)
#                                gmo_thick ......|...    19.1708 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.40563e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int .|........   0.842637 in (0.8, 1.2)
# step 260 cost 3.302(28)
# step 261 cost 3.302(28)
# step 262 cost 3.302(28)
# step 263 cost 3.302(28)
# step 264 cost 3.302(28)
# step 265 cost 3.302(28)
# step 266 cost 3.302(28)
# step 267 cost 3.302(28)
# step 268 cost 3.301(28)
# step 269 cost 3.301(28)
# step 270 cost 3.301(28)
# step 271 cost 3.301(28)
# step 272 cost 3.301(28)
# step 273 cost 3.298(28)
# step 274 cost 3.297(28)
# step 275 cost 3.297(28)
# step 276 cost 3.297(28)
# step 277 cost 3.297(28)
# step 278 cost 3.297(28)
# step 279 cost 3.297(28)
# step 280 cost 3.297(28)
# step 281 cost 3.297(28)
# step 282 cost 3.297(28)
#                                Si_dd_bkg |......... 8.43647e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.992149 in (0.8, 1.2)
#                                 ddod rho ........|.    6.62019 in (6, 6.7)
#                            Si_SiO2_rough ...|......    4.46694 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.45703 in (1.0, 10.0)
#                               SiO2_thick ....|.....    12.8998 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.38438e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.936501 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 5.92706e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......   0.924882 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.885495 in (0.0, 1.0)
#                           gmo_solv_rough .|........    2.11009 in (1.0, 10.0)
#                                gmo_thick ......|...    18.4908 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.53536e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.833156 in (0.8, 1.2)
# step 283 cost 3.297(28)
# step 284 cost 3.297(28)
# step 285 cost 3.297(28)
# step 286 cost 3.297(28)
# step 287 cost 3.297(28)
# step 288 cost 3.297(28)
# step 289 cost 3.297(28)
# step 290 cost 3.297(28)
# step 291 cost 3.297(28)
# step 292 cost 3.297(28)
# step 293 cost 3.297(28)
# step 294 cost 3.297(28)
# step 295 cost 3.296(28)
# step 296 cost 3.296(28)
# step 297 cost 3.296(28)
# step 298 cost 3.296(28)
# step 299 cost 3.296(28)
# step 300 cost 3.296(28)
# step 301 cost 3.296(28)
# step 302 cost 3.296(28)
# step 303 cost 3.296(28)
#                                Si_dd_bkg |......... 8.48306e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.992962 in (0.8, 1.2)
#                                 ddod rho ........|.    6.62059 in (6, 6.7)
#                            Si_SiO2_rough ....|.....    5.40424 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.29627 in (1.0, 10.0)
#                               SiO2_thick ....|.....    12.6419 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.41138e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.931979 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 5.91104e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......     0.9245 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.887194 in (0.0, 1.0)
#                           gmo_solv_rough .|........    1.96595 in (1.0, 10.0)
#                                gmo_thick .....|....     18.154 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.58091e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.830729 in (0.8, 1.2)
# step 305 cost 3.296(28)
# step 307 cost 3.295(28)
# step 308 cost 3.295(28)
# step 309 cost 3.295(28)
# step 310 cost 3.295(28)
# step 311 cost 3.295(28)
# step 312 cost 3.295(28)
# step 314 cost 3.295(28)
# step 316 cost 3.295(28)
# step 318 cost 3.295(28)
# step 320 cost 3.295(28)
# step 321 cost 3.295(28)
# step 323 cost 3.295(28)
# step 325 cost 3.295(28)
# step 327 cost 3.295(28)
# step 328 cost 3.295(28)
# step 329 cost 3.295(28)
# step 330 cost 3.295(28)
# step 331 cost 3.295(28)
#                                Si_dd_bkg |......... 8.46535e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.991357 in (0.8, 1.2)
#                                 ddod rho ........|.     6.6211 in (6, 6.7)
#                            Si_SiO2_rough ...|......    3.74531 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.33705 in (1.0, 10.0)
#                               SiO2_thick ....|.....    12.9766 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.32251e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......    0.93625 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.49518e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......   0.924601 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.896418 in (0.0, 1.0)
#                           gmo_solv_rough ..|.......     3.2019 in (1.0, 10.0)
#                                gmo_thick ......|...    18.5221 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.55387e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.838498 in (0.8, 1.2)
# step 332 cost 3.295(28)
# step 333 cost 3.294(28)
# step 334 cost 3.294(28)
# step 335 cost 3.294(28)
# step 336 cost 3.294(28)
# step 337 cost 3.294(28)
# step 338 cost 3.294(28)
# step 339 cost 3.294(28)
# step 341 cost 3.294(28)
# step 342 cost 3.294(28)
# step 344 cost 3.294(28)
# step 345 cost 3.294(28)
# step 346 cost 3.294(28)
# step 347 cost 3.294(28)
# step 348 cost 3.294(28)
# step 349 cost 3.294(28)
# step 350 cost 3.294(28)
# step 351 cost 3.294(28)
# step 352 cost 3.294(28)
#                                Si_dd_bkg |......... 8.48273e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.992203 in (0.8, 1.2)
#                                 ddod rho ........|.    6.62054 in (6, 6.7)
#                            Si_SiO2_rough ....|.....    5.19374 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.26954 in (1.0, 10.0)
#                               SiO2_thick ...|......    12.5349 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.4632e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.935682 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.35976e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......    0.92581 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.886238 in (0.0, 1.0)
#                           gmo_solv_rough .|........    2.30861 in (1.0, 10.0)
#                                gmo_thick .....|....     18.164 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.49163e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.838945 in (0.8, 1.2)
# step 353 cost 3.294(28)
# step 354 cost 3.294(28)
# step 355 cost 3.294(28)
# step 356 cost 3.294(28)
# step 357 cost 3.294(28)
# step 358 cost 3.294(28)
# step 359 cost 3.294(28)
# step 360 cost 3.294(28)
# step 361 cost 3.294(28)
# step 362 cost 3.294(28)
# step 363 cost 3.294(28)
# step 364 cost 3.294(28)
# step 365 cost 3.294(28)
# step 366 cost 3.294(28)
# step 367 cost 3.294(28)
# step 368 cost 3.294(28)
# step 369 cost 3.294(28)
# step 370 cost 3.294(28)
# step 371 cost 3.294(28)
# step 372 cost 3.293(28)
# step 373 cost 3.293(28)
# step 374 cost 3.293(28)
# step 375 cost 3.293(28)
# step 376 cost 3.293(28)
#                                Si_dd_bkg |......... 8.42729e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.991883 in (0.8, 1.2)
#                                 ddod rho ........|.    6.62125 in (6, 6.7)
#                            Si_SiO2_rough ....|.....    4.98627 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.31325 in (1.0, 10.0)
#                               SiO2_thick ....|.....    12.6147 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.39262e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.938365 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.48931e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......   0.925447 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.886903 in (0.0, 1.0)
#                           gmo_solv_rough .|........    2.68606 in (1.0, 10.0)
#                                gmo_thick ......|...    18.4344 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.50394e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.838314 in (0.8, 1.2)
# step 378 cost 3.293(28)
# step 379 cost 3.293(28)
# step 380 cost 3.293(28)
# step 381 cost 3.293(28)
# step 382 cost 3.293(28)
# step 383 cost 3.293(28)
# step 384 cost 3.293(28)
# step 385 cost 3.293(28)
# step 386 cost 3.293(28)
# step 387 cost 3.293(28)
# step 388 cost 3.293(28)
# step 389 cost 3.293(28)
# step 390 cost 3.293(28)
# step 391 cost 3.293(28)
# step 392 cost 3.293(28)
# step 393 cost 3.293(28)
# step 394 cost 3.293(28)
# step 395 cost 3.293(28)
# step 396 cost 3.293(28)
# step 397 cost 3.293(28)
# step 398 cost 3.293(28)
# step 399 cost 3.293(28)
# step 400 cost 3.293(28)
# step 401 cost 3.293(28)
# step 402 cost 3.293(28)
# step 403 cost 3.293(28)
# step 404 cost 3.293(28)
#                                Si_dd_bkg |......... 8.43617e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.991794 in (0.8, 1.2)
#                                 ddod rho ........|.    6.62123 in (6, 6.7)
#                            Si_SiO2_rough ....|.....    5.03086 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.30999 in (1.0, 10.0)
#                               SiO2_thick ...|......    12.5992 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.38791e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.937894 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.51879e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......   0.925536 in (0.8, 1.2)
#                                   gmo_vf ........|.    0.88702 in (0.0, 1.0)
#                           gmo_solv_rough .|........    2.69958 in (1.0, 10.0)
#                                gmo_thick ......|...    18.4112 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.51128e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.839009 in (0.8, 1.2)
# step 405 cost 3.293(28)
# step 406 cost 3.293(28)
# step 407 cost 3.293(28)
# step 408 cost 3.293(28)
# step 409 cost 3.293(28)
# step 410 cost 3.293(28)
# step 411 cost 3.293(28)
# step 412 cost 3.293(28)
# step 413 cost 3.293(28)
# step 414 cost 3.293(28)
# step 415 cost 3.293(28)
# step 416 cost 3.293(28)
# step 417 cost 3.293(28)
# step 418 cost 3.293(28)
# step 419 cost 3.293(28)
# step 420 cost 3.293(28)
# step 421 cost 3.293(28)
# step 422 cost 3.293(28)
# step 423 cost 3.293(28)
# step 424 cost 3.293(28)
# step 425 cost 3.293(28)
# step 426 cost 3.293(28)
# step 427 cost 3.293(28)
# step 428 cost 3.293(28)
# step 429 cost 3.293(28)
# step 430 cost 3.293(28)
#                                Si_dd_bkg |......... 8.44313e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.991804 in (0.8, 1.2)
#                                 ddod rho ........|.    6.62102 in (6, 6.7)
#                            Si_SiO2_rough ....|.....    5.21499 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.27272 in (1.0, 10.0)
#                               SiO2_thick ...|......    12.5375 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.3976e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......    0.93685 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.50883e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......   0.925636 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.886407 in (0.0, 1.0)
#                           gmo_solv_rough .|........     2.6412 in (1.0, 10.0)
#                                gmo_thick .....|....    18.3705 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.50487e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.837923 in (0.8, 1.2)
# step 431 cost 3.293(28)
# step 432 cost 3.293(28)
# step 433 cost 3.293(28)
# step 434 cost 3.293(28)
# step 435 cost 3.293(28)
# step 436 cost 3.293(28)
# step 437 cost 3.293(28)
# step 438 cost 3.293(28)
# step 439 cost 3.293(28)
# step 440 cost 3.293(28)
# step 441 cost 3.293(28)
# step 442 cost 3.293(28)
# step 443 cost 3.293(28)
# step 444 cost 3.293(28)
# step 445 cost 3.293(28)
# step 446 cost 3.293(28)
# step 447 cost 3.293(28)
# step 448 cost 3.293(28)
# step 449 cost 3.293(28)
# step 450 cost 3.293(28)
# step 451 cost 3.293(28)
# step 452 cost 3.293(28)
# step 453 cost 3.293(28)
# step 454 cost 3.293(28)
# step 455 cost 3.293(28)
# step 456 cost 3.293(28)
# step 457 cost 3.293(28)
# step 458 cost 3.293(28)
#                                Si_dd_bkg |......... 8.43085e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.991801 in (0.8, 1.2)
#                                 ddod rho ........|.    6.62097 in (6, 6.7)
#                            Si_SiO2_rough ....|.....    5.21453 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.27275 in (1.0, 10.0)
#                               SiO2_thick ...|......    12.5122 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.3844e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.936586 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.49733e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......   0.925499 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.886944 in (0.0, 1.0)
#                           gmo_solv_rough .|........    2.62252 in (1.0, 10.0)
#                                gmo_thick .....|....    18.3103 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.51386e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.837594 in (0.8, 1.2)
# step 459 cost 3.293(28)
# step 460 cost 3.293(28)
# step 461 cost 3.293(28)
# step 462 cost 3.293(28)
# step 463 cost 3.293(28)
# step 464 cost 3.293(28)
# step 465 cost 3.293(28)
# step 466 cost 3.293(28)
# step 467 cost 3.293(28)
# step 468 cost 3.293(28)
# step 469 cost 3.293(28)
# step 470 cost 3.293(28)
# step 471 cost 3.293(28)
# step 472 cost 3.293(28)
# step 473 cost 3.293(28)
# step 474 cost 3.293(28)
# step 475 cost 3.293(28)
# step 476 cost 3.293(28)
# step 477 cost 3.293(28)
# step 478 cost 3.293(28)
# step 479 cost 3.293(28)
# step 480 cost 3.293(28)
# step 481 cost 3.293(28)
# step 482 cost 3.293(28)
# step 483 cost 3.293(28)
# step 484 cost 3.293(28)
# step 485 cost 3.293(28)
# step 486 cost 3.293(28)
#                                Si_dd_bkg |......... 8.43561e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.991761 in (0.8, 1.2)
#                                 ddod rho ........|.    6.62101 in (6, 6.7)
#                            Si_SiO2_rough ....|.....    5.20461 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.26628 in (1.0, 10.0)
#                               SiO2_thick ...|......    12.5167 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.39272e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.936703 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.50649e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......   0.925452 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.886908 in (0.0, 1.0)
#                           gmo_solv_rough .|........     2.6369 in (1.0, 10.0)
#                                gmo_thick .....|....    18.3203 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.50832e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.837611 in (0.8, 1.2)
# step 487 cost 3.293(28)
# step 488 cost 3.293(28)
# step 489 cost 3.293(28)
# step 490 cost 3.293(28)
# step 491 cost 3.293(28)
# step 492 cost 3.293(28)
# step 493 cost 3.293(28)
# step 494 cost 3.293(28)
# step 495 cost 3.293(28)
# step 496 cost 3.293(28)
# step 497 cost 3.293(28)
# step 498 cost 3.293(28)
# step 499 cost 3.293(28)
# step 500 cost 3.293(28)
# step 501 cost 3.293(28)
# step 502 cost 3.293(28)
# step 503 cost 3.293(28)
# step 504 cost 3.293(28)
# step 505 cost 3.293(28)
# step 506 cost 3.293(28)
# step 507 cost 3.293(28)
# step 508 cost 3.293(28)
# step 509 cost 3.293(28)
# step 510 cost 3.293(28)
# step 511 cost 3.293(28)
# step 512 cost 3.293(28)
# step 513 cost 3.293(28)
# step 514 cost 3.293(28)
#                                Si_dd_bkg |......... 8.44443e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.991653 in (0.8, 1.2)
#                                 ddod rho ........|.    6.62107 in (6, 6.7)
#                            Si_SiO2_rough ....|.....    4.93583 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.26552 in (1.0, 10.0)
#                               SiO2_thick ....|.....    12.6296 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.37236e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......    0.93638 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.56775e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......   0.925358 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.890364 in (0.0, 1.0)
#                           gmo_solv_rough ..|.......     2.8813 in (1.0, 10.0)
#                                gmo_thick .....|....    18.3613 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.48592e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.837729 in (0.8, 1.2)
# step 515 cost 3.293(28)
# step 516 cost 3.293(28)
# step 517 cost 3.293(28)
# step 518 cost 3.293(28)
# step 519 cost 3.293(28)
# step 520 cost 3.293(28)
# step 521 cost 3.293(28)
# step 522 cost 3.293(28)
# step 523 cost 3.293(28)
# step 524 cost 3.293(28)
# step 525 cost 3.293(28)
# step 526 cost 3.293(28)
# step 527 cost 3.293(28)
# step 528 cost 3.293(28)
# step 529 cost 3.293(28)
# step 530 cost 3.293(28)
# step 531 cost 3.293(28)
# step 532 cost 3.293(28)
# step 533 cost 3.293(28)
# step 534 cost 3.293(28)
# step 535 cost 3.293(28)
# step 536 cost 3.293(28)
# step 537 cost 3.293(28)
# step 538 cost 3.293(28)
# step 539 cost 3.293(28)
# step 540 cost 3.293(28)
# step 541 cost 3.293(28)
# step 542 cost 3.293(28)
#                                Si_dd_bkg |......... 8.4406e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.991692 in (0.8, 1.2)
#                                 ddod rho ........|.    6.62106 in (6, 6.7)
#                            Si_SiO2_rough ....|.....     5.0006 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.26125 in (1.0, 10.0)
#                               SiO2_thick ....|.....    12.6115 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.38032e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.936124 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.58791e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......   0.925414 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.890229 in (0.0, 1.0)
#                           gmo_solv_rough ..|.......    2.86681 in (1.0, 10.0)
#                                gmo_thick .....|....    18.3379 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.49489e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.837651 in (0.8, 1.2)
# step 543 cost 3.293(28)
# step 544 cost 3.293(28)
# step 545 cost 3.293(28)
# step 546 cost 3.293(28)
# step 547 cost 3.293(28)
# step 548 cost 3.293(28)
# step 549 cost 3.293(28)
# step 550 cost 3.293(28)
# step 551 cost 3.293(28)
# step 552 cost 3.293(28)
# step 553 cost 3.293(28)
# step 554 cost 3.293(28)
# step 555 cost 3.293(28)
# step 556 cost 3.293(28)
# step 557 cost 3.293(28)
# step 558 cost 3.293(28)
# step 559 cost 3.293(28)
# step 560 cost 3.293(28)
# step 561 cost 3.293(28)
# step 562 cost 3.293(28)
# step 563 cost 3.293(28)
# step 564 cost 3.293(28)
# step 565 cost 3.293(28)
# step 566 cost 3.293(28)
# step 567 cost 3.293(28)
# step 568 cost 3.293(28)
# step 569 cost 3.293(28)
# step 570 cost 3.293(28)
#                                Si_dd_bkg |......... 8.44929e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.991656 in (0.8, 1.2)
#                                 ddod rho ........|.    6.62105 in (6, 6.7)
#                            Si_SiO2_rough ....|.....    4.80772 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.26974 in (1.0, 10.0)
#                               SiO2_thick ....|.....    12.6905 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.36544e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.936376 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.63045e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......   0.925395 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.892468 in (0.0, 1.0)
#                           gmo_solv_rough ..|.......    3.01103 in (1.0, 10.0)
#                                gmo_thick .....|....    18.3655 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.48545e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.837752 in (0.8, 1.2)
# step 571 cost 3.293(28)
# step 572 cost 3.293(28)
# step 573 cost 3.293(28)
# step 574 cost 3.293(28)
# step 575 cost 3.293(28)
# step 576 cost 3.293(28)
# step 577 cost 3.293(28)
# step 578 cost 3.293(28)
# step 579 cost 3.293(28)
# step 580 cost 3.293(28)
# step 581 cost 3.293(28)
# step 582 cost 3.293(28)
# step 583 cost 3.293(28)
# step 584 cost 3.293(28)
# step 585 cost 3.293(28)
# step 586 cost 3.293(28)
# step 587 cost 3.293(28)
# step 588 cost 3.293(28)
# step 589 cost 3.293(28)
# step 590 cost 3.293(28)
# step 591 cost 3.293(28)
# step 592 cost 3.293(28)
# step 593 cost 3.293(28)
#                                Si_dd_bkg |......... 8.44929e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.991656 in (0.8, 1.2)
#                                 ddod rho ........|.    6.62105 in (6, 6.7)
#                            Si_SiO2_rough ....|.....    4.80772 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.26974 in (1.0, 10.0)
#                               SiO2_thick ....|.....    12.6905 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.36544e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.936376 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.63045e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......   0.925395 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.892468 in (0.0, 1.0)
#                           gmo_solv_rough ..|.......    3.01103 in (1.0, 10.0)
#                                gmo_thick .....|....    18.3655 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.48545e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.837752 in (0.8, 1.2)
# step 594 cost 3.293(28)
# step 595 cost 3.293(28)
# step 596 cost 3.293(28)
# step 597 cost 3.293(28)
# step 598 cost 3.293(28)
# step 599 cost 3.293(28)
# step 600 cost 3.293(28)
# step 601 cost 3.293(28)
# step 602 cost 3.293(28)
# step 603 cost 3.293(28)
# step 604 cost 3.293(28)
# step 605 cost 3.293(28)
# step 606 cost 3.293(28)
# step 607 cost 3.293(28)
# step 608 cost 3.293(28)
# step 609 cost 3.293(28)
# step 610 cost 3.293(28)
# step 611 cost 3.293(28)
# step 612 cost 3.293(28)
# step 613 cost 3.293(28)
# step 614 cost 3.293(28)
#                                Si_dd_bkg |......... 8.45051e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.991717 in (0.8, 1.2)
#                                 ddod rho ........|.    6.62103 in (6, 6.7)
#                            Si_SiO2_rough ....|.....    4.84853 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.26956 in (1.0, 10.0)
#                               SiO2_thick ....|.....    12.6713 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.36626e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......    0.93633 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.62119e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......   0.925386 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.892127 in (0.0, 1.0)
#                           gmo_solv_rough ..|.......    2.98859 in (1.0, 10.0)
#                                gmo_thick .....|....     18.366 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.49036e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.837716 in (0.8, 1.2)
# step 615 cost 3.293(28)
# step 616 cost 3.293(28)
# step 617 cost 3.293(28)
# step 618 cost 3.293(28)
# step 619 cost 3.293(28)
# step 620 cost 3.293(28)
# step 621 cost 3.293(28)
# step 622 cost 3.293(28)
# step 623 cost 3.293(28)
# step 624 cost 3.293(28)
# step 625 cost 3.293(28)
# step 626 cost 3.293(28)
# step 627 cost 3.293(28)
# step 628 cost 3.293(28)
#                                Si_dd_bkg |......... 8.44865e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.991726 in (0.8, 1.2)
#                                 ddod rho ........|.    6.62101 in (6, 6.7)
#                            Si_SiO2_rough ....|.....    4.83053 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.27161 in (1.0, 10.0)
#                               SiO2_thick ....|.....    12.6804 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.36098e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.936384 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.60065e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......   0.925416 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.891923 in (0.0, 1.0)
#                           gmo_solv_rough ..|.......    2.96852 in (1.0, 10.0)
#                                gmo_thick .....|....    18.3714 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.48793e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.837661 in (0.8, 1.2)
# step 629 cost 3.293(28)
# step 630 cost 3.293(28)
# step 631 cost 3.293(28)
# step 632 cost 3.293(28)
# step 633 cost 3.293(28)
# step 634 cost 3.293(28)
# step 635 cost 3.293(28)
#                                Si_dd_bkg |......... 8.44642e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.991718 in (0.8, 1.2)
#                                 ddod rho ........|.    6.62101 in (6, 6.7)
#                            Si_SiO2_rough ....|.....    4.82706 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.     8.2686 in (1.0, 10.0)
#                               SiO2_thick ....|.....    12.6829 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.36236e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.936328 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.61613e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......   0.925401 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.892353 in (0.0, 1.0)
#                           gmo_solv_rough ..|.......    2.99748 in (1.0, 10.0)
#                                gmo_thick .....|....    18.3669 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.48844e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.837634 in (0.8, 1.2)
# step 636 cost 3.293(28)
# step 637 cost 3.293(28)
# step 638 cost 3.293(28)
# step 639 cost 3.293(28)
# step 640 cost 3.293(28)
# step 641 cost 3.293(28)
# step 642 cost 3.293(28)
# step 643 cost 3.293(28)
# step 644 cost 3.293(28)
#                                Si_dd_bkg |......... 8.44933e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.991728 in (0.8, 1.2)
#                                 ddod rho ........|.    6.62101 in (6, 6.7)
#                            Si_SiO2_rough ....|.....    4.82227 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.27021 in (1.0, 10.0)
#                               SiO2_thick ....|.....    12.6848 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.36241e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.936359 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.61829e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......   0.925414 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.892434 in (0.0, 1.0)
#                           gmo_solv_rough ..|.......    2.99983 in (1.0, 10.0)
#                                gmo_thick .....|....    18.3621 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.48821e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.837698 in (0.8, 1.2)
# step 645 cost 3.293(28)
# step 646 cost 3.293(28)
# step 647 cost 3.293(28)
# step 648 cost 3.293(28)
# step 649 cost 3.293(28)
# step 650 cost 3.293(28)
# step 651 cost 3.293(28)
# step 652 cost 3.293(28)
# step 653 cost 3.293(28)
#                                Si_dd_bkg |......... 8.45179e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.991727 in (0.8, 1.2)
#                                 ddod rho ........|.    6.62101 in (6, 6.7)
#                            Si_SiO2_rough ....|.....     4.8235 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.27195 in (1.0, 10.0)
#                               SiO2_thick ....|.....    12.6853 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.36249e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.936401 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.61473e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......   0.925414 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.892218 in (0.0, 1.0)
#                           gmo_solv_rough ..|.......    2.98819 in (1.0, 10.0)
#                                gmo_thick .....|....    18.3678 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.48468e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........    0.83768 in (0.8, 1.2)
# step 654 cost 3.293(28)
# step 655 cost 3.293(28)
# step 656 cost 3.293(28)
# step 657 cost 3.293(28)
# step 658 cost 3.293(28)
# step 659 cost 3.293(28)
# step 660 cost 3.293(28)
# step 661 cost 3.293(28)
# step 662 cost 3.293(28)
#                                Si_dd_bkg |......... 8.44861e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.991725 in (0.8, 1.2)
#                                 ddod rho ........|.    6.62101 in (6, 6.7)
#                            Si_SiO2_rough ....|.....    4.81491 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.27149 in (1.0, 10.0)
#                               SiO2_thick ....|.....    12.6853 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.36361e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.936445 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.61793e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......   0.925431 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.892214 in (0.0, 1.0)
#                           gmo_solv_rough ..|.......    2.99502 in (1.0, 10.0)
#                                gmo_thick .....|....    18.3738 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.48571e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.837796 in (0.8, 1.2)
# step 663 cost 3.293(28)
# step 664 cost 3.293(28)
# step 665 cost 3.293(28)
# step 666 cost 3.293(28)
# step 667 cost 3.293(28)
# step 668 cost 3.293(28)
# step 669 cost 3.293(28)
# step 670 cost 3.293(28)
# step 671 cost 3.293(28)
# step 672 cost 3.293(28)
# step 673 cost 3.293(28)
# step 674 cost 3.293(28)
# step 675 cost 3.293(28)
# step 676 cost 3.293(28)
#                                Si_dd_bkg |......... 8.45009e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.991721 in (0.8, 1.2)
#                                 ddod rho ........|.    6.62102 in (6, 6.7)
#                            Si_SiO2_rough ....|.....    4.82141 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.27028 in (1.0, 10.0)
#                               SiO2_thick ....|.....    12.6843 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.36288e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.936401 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.61515e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......    0.92541 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.892268 in (0.0, 1.0)
#                           gmo_solv_rough ..|.......    2.99512 in (1.0, 10.0)
#                                gmo_thick .....|....    18.3684 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.48746e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.837755 in (0.8, 1.2)
# step 677 cost 3.293(28)
# step 678 cost 3.293(28)
# step 679 cost 3.293(28)
# step 680 cost 3.293(28)
# step 681 cost 3.293(28)
# step 682 cost 3.293(28)
# step 683 cost 3.293(28)
# step 684 cost 3.293(28)
# step 685 cost 3.293(28)
# step 686 cost 3.293(28)
# step 687 cost 3.293(28)
# step 688 cost 3.293(28)
# step 689 cost 3.293(28)
# step 690 cost 3.293(28)
#                                Si_dd_bkg |......... 8.4513e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.991725 in (0.8, 1.2)
#                                 ddod rho ........|.    6.62103 in (6, 6.7)
#                            Si_SiO2_rough ....|.....    4.81721 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.27119 in (1.0, 10.0)
#                               SiO2_thick ....|.....    12.6851 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.36283e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.936451 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.61537e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......   0.925405 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.892302 in (0.0, 1.0)
#                           gmo_solv_rough ..|.......     2.9964 in (1.0, 10.0)
#                                gmo_thick .....|....    18.3701 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.4869e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.837742 in (0.8, 1.2)
# step 691 cost 3.293(28)
# step 692 cost 3.293(28)
# step 693 cost 3.293(28)
# step 694 cost 3.293(28)
# step 695 cost 3.293(28)
# step 696 cost 3.293(28)
# step 697 cost 3.293(28)
# step 698 cost 3.293(28)
# step 699 cost 3.293(28)
# step 700 cost 3.293(28)
# step 701 cost 3.293(28)
# step 702 cost 3.293(28)
# step 703 cost 3.293(28)
# step 704 cost 3.293(28)
#                                Si_dd_bkg |......... 8.4513e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.991725 in (0.8, 1.2)
#                                 ddod rho ........|.    6.62103 in (6, 6.7)
#                            Si_SiO2_rough ....|.....    4.81721 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.27119 in (1.0, 10.0)
#                               SiO2_thick ....|.....    12.6851 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.36283e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.936451 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.61537e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......   0.925405 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.892302 in (0.0, 1.0)
#                           gmo_solv_rough ..|.......     2.9964 in (1.0, 10.0)
#                                gmo_thick .....|....    18.3701 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.4869e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.837742 in (0.8, 1.2)
# step 705 cost 3.293(28)
# step 706 cost 3.293(28)
# ...
#                            Si_gmo_dd_int ...|......   0.925407 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.892283 in (0.0, 1.0)
#                           gmo_solv_rough ..|.......    2.99402 in (1.0, 10.0)
#                                gmo_thick .....|....    18.3661 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.48681e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.837711 in (0.8, 1.2)
# step 791 cost 3.293(28)
# step 792 cost 3.293(28)
# step 793 cost 3.293(28)
# step 794 cost 3.293(28)
# step 795 cost 3.293(28)
# step 796 cost 3.293(28)
# step 797 cost 3.293(28)
# step 798 cost 3.293(28)
# step 799 cost 3.293(28)
# step 800 cost 3.293(28)
# step 801 cost 3.293(28)
# step 802 cost 3.293(28)
# step 803 cost 3.293(28)
# step 804 cost 3.293(28)
# step 805 cost 3.293(28)
# step 806 cost 3.293(28)
# step 807 cost 3.293(28)
# step 808 cost 3.293(28)
# step 809 cost 3.293(28)
# step 810 cost 3.293(28)
# step 811 cost 3.293(28)
# step 812 cost 3.293(28)
# step 813 cost 3.293(28)
# step 814 cost 3.293(28)
# step 815 cost 3.293(28)
# step 816 cost 3.293(28)
# step 817 cost 3.293(28)
# step 818 cost 3.293(28)
#                                Si_dd_bkg |......... 8.45056e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.991721 in (0.8, 1.2)
#                                 ddod rho ........|.    6.62102 in (6, 6.7)
#                            Si_SiO2_rough ....|.....    4.83444 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.27056 in (1.0, 10.0)
#                               SiO2_thick ....|.....      12.68 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.36472e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......     0.9364 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.61637e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......   0.925412 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.892248 in (0.0, 1.0)
#                           gmo_solv_rough ..|.......    2.99161 in (1.0, 10.0)
#                                gmo_thick .....|....    18.3655 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.48684e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.837703 in (0.8, 1.2)
# step 819 cost 3.293(28)
# step 820 cost 3.293(28)
# step 821 cost 3.293(28)
# step 822 cost 3.293(28)
# step 823 cost 3.293(28)
# step 824 cost 3.293(28)
# step 825 cost 3.293(28)
# step 826 cost 3.293(28)
# step 827 cost 3.293(28)
# step 828 cost 3.293(28)
# step 829 cost 3.293(28)
# step 830 cost 3.293(28)
# step 831 cost 3.293(28)
# step 832 cost 3.293(28)
# step 833 cost 3.293(28)
# step 834 cost 3.293(28)
# step 835 cost 3.293(28)
# step 836 cost 3.293(28)
# step 837 cost 3.293(28)
# step 838 cost 3.293(28)
# step 839 cost 3.293(28)
# step 840 cost 3.293(28)
# step 841 cost 3.293(28)
# step 842 cost 3.293(28)
# step 843 cost 3.293(28)
# step 844 cost 3.293(28)
# step 845 cost 3.293(28)
# step 846 cost 3.293(28)
#                                Si_dd_bkg |......... 8.45064e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.991725 in (0.8, 1.2)
#                                 ddod rho ........|.    6.62102 in (6, 6.7)
#                            Si_SiO2_rough ....|.....    4.83756 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.27065 in (1.0, 10.0)
#                               SiO2_thick ....|.....     12.679 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.36509e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.936387 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.61652e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......   0.925411 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.892233 in (0.0, 1.0)
#                           gmo_solv_rough ..|.......    2.99071 in (1.0, 10.0)
#                                gmo_thick .....|....    18.3648 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.48683e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.837694 in (0.8, 1.2)
# step 847 cost 3.293(28)
# step 848 cost 3.293(28)
# step 849 cost 3.293(28)
# step 850 cost 3.293(28)
# step 851 cost 3.293(28)
# step 852 cost 3.293(28)
# step 853 cost 3.293(28)
# step 854 cost 3.293(28)
# step 855 cost 3.293(28)
# step 856 cost 3.293(28)
# step 857 cost 3.293(28)
# step 858 cost 3.293(28)
# step 859 cost 3.293(28)
# step 860 cost 3.293(28)
# step 861 cost 3.293(28)
# step 862 cost 3.293(28)
# step 863 cost 3.293(28)
# step 864 cost 3.293(28)
# step 865 cost 3.293(28)
# step 866 cost 3.293(28)
# step 867 cost 3.293(28)
# step 868 cost 3.293(28)
# step 869 cost 3.293(28)
# step 870 cost 3.293(28)
# step 871 cost 3.293(28)
# step 872 cost 3.293(28)
# step 873 cost 3.293(28)
# step 874 cost 3.293(28)
#                                Si_dd_bkg |......... 8.45072e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.991725 in (0.8, 1.2)
#                                 ddod rho ........|.    6.62102 in (6, 6.7)
#                            Si_SiO2_rough ....|.....    4.83774 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.27052 in (1.0, 10.0)
#                               SiO2_thick ....|.....    12.6789 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.36514e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.936387 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.61634e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......    0.92541 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.892227 in (0.0, 1.0)
#                           gmo_solv_rough ..|.......    2.99048 in (1.0, 10.0)
#                                gmo_thick .....|....     18.365 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.48695e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.837696 in (0.8, 1.2)
# step 875 cost 3.293(28)
# step 876 cost 3.293(28)
# step 877 cost 3.293(28)
# step 878 cost 3.293(28)
# step 879 cost 3.293(28)
# step 880 cost 3.293(28)
# step 881 cost 3.293(28)
# step 882 cost 3.293(28)
# step 883 cost 3.293(28)
# step 884 cost 3.293(28)
# step 885 cost 3.293(28)
# step 886 cost 3.293(28)
# step 887 cost 3.293(28)
# step 888 cost 3.293(28)
# step 889 cost 3.293(28)
# step 890 cost 3.293(28)
# step 891 cost 3.293(28)
# step 892 cost 3.293(28)
# step 893 cost 3.293(28)
# step 894 cost 3.293(28)
# step 895 cost 3.293(28)
# step 896 cost 3.293(28)
# step 897 cost 3.293(28)
# step 898 cost 3.293(28)
# step 899 cost 3.293(28)
# step 900 cost 3.293(28)
# step 901 cost 3.293(28)
# step 902 cost 3.293(28)
#                                Si_dd_bkg |......... 8.4508e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.991725 in (0.8, 1.2)
#                                 ddod rho ........|.    6.62102 in (6, 6.7)
#                            Si_SiO2_rough ....|.....    4.83776 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.27059 in (1.0, 10.0)
#                               SiO2_thick ....|.....    12.6787 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.36514e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......    0.93639 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.61592e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......   0.925409 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.892215 in (0.0, 1.0)
#                           gmo_solv_rough ..|.......    2.98943 in (1.0, 10.0)
#                                gmo_thick .....|....    18.3648 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.48711e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.837702 in (0.8, 1.2)
# step 903 cost 3.293(28)
# step 904 cost 3.293(28)
# step 905 cost 3.293(28)
# step 906 cost 3.293(28)
# step 907 cost 3.293(28)
# step 908 cost 3.293(28)
# step 909 cost 3.293(28)
# step 910 cost 3.293(28)
# step 911 cost 3.293(28)
# step 912 cost 3.293(28)
# step 913 cost 3.293(28)
# step 914 cost 3.293(28)
# step 915 cost 3.293(28)
# step 916 cost 3.293(28)
# step 917 cost 3.293(28)
# step 918 cost 3.293(28)
# step 919 cost 3.293(28)
# step 920 cost 3.293(28)
# step 921 cost 3.293(28)
# step 922 cost 3.293(28)
# step 923 cost 3.293(28)
# step 924 cost 3.293(28)
# step 925 cost 3.293(28)
# step 926 cost 3.293(28)
# step 927 cost 3.293(28)
# step 928 cost 3.293(28)
# step 929 cost 3.293(28)
#                                Si_dd_bkg |......... 8.45067e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.991726 in (0.8, 1.2)
#                                 ddod rho ........|.    6.62102 in (6, 6.7)
#                            Si_SiO2_rough ....|.....     4.8381 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.27053 in (1.0, 10.0)
#                               SiO2_thick ....|.....    12.6786 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.36523e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.936387 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.61574e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......   0.925409 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.892212 in (0.0, 1.0)
#                           gmo_solv_rough ..|.......    2.98925 in (1.0, 10.0)
#                                gmo_thick .....|....    18.3647 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.48724e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.837696 in (0.8, 1.2)
# step 930 cost 3.293(28)
# step 931 cost 3.293(28)
# step 932 cost 3.293(28)
# step 933 cost 3.293(28)
# step 934 cost 3.293(28)
# step 935 cost 3.293(28)
# step 936 cost 3.293(28)
# step 937 cost 3.293(28)
# step 938 cost 3.293(28)
# step 939 cost 3.293(28)
# step 940 cost 3.293(28)
# step 941 cost 3.293(28)
# step 942 cost 3.293(28)
# step 943 cost 3.293(28)
# step 944 cost 3.293(28)
# step 945 cost 3.293(28)
# step 946 cost 3.293(28)
# step 947 cost 3.293(28)
# step 948 cost 3.293(28)
# step 949 cost 3.293(28)
# step 950 cost 3.293(28)
# step 951 cost 3.293(28)
# step 952 cost 3.293(28)
#                                Si_dd_bkg |......... 8.45065e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.991725 in (0.8, 1.2)
#                                 ddod rho ........|.    6.62102 in (6, 6.7)
#                            Si_SiO2_rough ....|.....    4.83824 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.27052 in (1.0, 10.0)
#                               SiO2_thick ....|.....    12.6786 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.36525e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.936387 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.61579e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......    0.92541 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.892211 in (0.0, 1.0)
#                           gmo_solv_rough ..|.......    2.98928 in (1.0, 10.0)
#                                gmo_thick .....|....    18.3647 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.48723e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.837696 in (0.8, 1.2)
# step 953 cost 3.293(28)
# step 954 cost 3.293(28)
# step 955 cost 3.293(28)
# step 956 cost 3.293(28)
# step 957 cost 3.293(28)
# step 958 cost 3.293(28)
# step 959 cost 3.293(28)
# step 960 cost 3.293(28)
# step 961 cost 3.293(28)
# step 962 cost 3.293(28)
# step 963 cost 3.293(28)
# step 964 cost 3.293(28)
# step 965 cost 3.293(28)
# step 966 cost 3.293(28)
# step 967 cost 3.293(28)
# step 968 cost 3.293(28)
# step 969 cost 3.293(28)
# step 970 cost 3.293(28)
# step 971 cost 3.293(28)
# step 972 cost 3.293(28)
# step 973 cost 3.293(28)
# step 974 cost 3.293(28)
# step 975 cost 3.293(28)
#                                Si_dd_bkg |......... 8.45066e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.991725 in (0.8, 1.2)
#                                 ddod rho ........|.    6.62102 in (6, 6.7)
#                            Si_SiO2_rough ....|.....    4.83834 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.27052 in (1.0, 10.0)
#                               SiO2_thick ....|.....    12.6785 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.36521e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.936388 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.61581e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......    0.92541 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.892213 in (0.0, 1.0)
#                           gmo_solv_rough ..|.......    2.98921 in (1.0, 10.0)
#                                gmo_thick .....|....    18.3647 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.48721e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.837698 in (0.8, 1.2)
# step 976 cost 3.293(28)
# step 977 cost 3.293(28)
# step 978 cost 3.293(28)
# step 979 cost 3.293(28)
# step 980 cost 3.293(28)
# step 981 cost 3.293(28)
# step 982 cost 3.293(28)
# step 983 cost 3.293(28)
# step 984 cost 3.293(28)
# step 985 cost 3.293(28)
# step 986 cost 3.293(28)
# step 987 cost 3.293(28)
# step 988 cost 3.293(28)
# step 989 cost 3.293(28)
# step 990 cost 3.293(28)
# step 991 cost 3.293(28)
# step 992 cost 3.293(28)
# step 993 cost 3.293(28)
# step 994 cost 3.293(28)
# step 995 cost 3.293(28)
# step 996 cost 3.293(28)
# step 997 cost 3.293(28)
# step 998 cost 3.293(28)
#                                Si_dd_bkg |......... 8.45064e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.991725 in (0.8, 1.2)
#                                 ddod rho ........|.    6.62102 in (6, 6.7)
#                            Si_SiO2_rough ....|.....    4.83834 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.27051 in (1.0, 10.0)
#                               SiO2_thick ....|.....    12.6785 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.36523e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.936386 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.61584e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......    0.92541 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.892212 in (0.0, 1.0)
#                           gmo_solv_rough ..|.......    2.98928 in (1.0, 10.0)
#                                gmo_thick .....|....    18.3647 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.48718e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.837694 in (0.8, 1.2)
# step 999 cost 3.293(28)
# step 1000 cost 3.293(28)
# final chisq 3.293(28)
# === Uncertainty from curvature:     name   value(unc.) ===
#                                Si_dd_bkg   8.45(27)e-6
#                                Si_dd_int   0.9917(27)
#                                 ddod rho   6.6210(18)
#                            Si_SiO2_rough   4.8(15)
#                          SiO2_solv_rough   8.27(26)
#                               SiO2_thick   12.68(42)
#                                Si_hd_bkg   6.37(23)e-6
#                                Si_hd_int   0.936(10)
#                            Si_gmo_dd_bkg   6.6(11)e-6
#                            Si_gmo_dd_int   0.9254(27)
#                                   gmo_vf   0.892(25)
#                           gmo_solv_rough   3.0(17)
#                                gmo_thick   18.36(65)
#                            Si_gmo_hd_bkg   5.49(19)e-6
#                            Si_gmo_hd_int   0.838(11)
# ==========================================================

# %%
{k: v for k, v in zip(problem.labels(), problem.getp())}
# Out:
# {'Si_dd_bkg': np.float64(8.450628284513788e-06),
#  'Si_dd_int': np.float64(0.9917251216259073),
#  'ddod rho': np.float64(6.621018837415211),
#  'Si_SiO2_rough': np.float64(4.838340763196024),
#  'SiO2_solv_rough': np.float64(8.270503146365527),
#  'SiO2_thick': np.float64(12.678522537907936),
#  'Si_hd_bkg': np.float64(6.365223888812154e-06),
#  'Si_hd_int': np.float64(0.9363859283378051),
#  'Si_gmo_dd_bkg': np.float64(6.615863388076958e-06),
#  'Si_gmo_dd_int': np.float64(0.9254103653038929),
#  'gmo_vf': np.float64(0.8922124200326479),
#  'gmo_solv_rough': np.float64(2.989307799284493),
#  'gmo_thick': np.float64(18.364673296902385),
#  'Si_gmo_hd_bkg': np.float64(5.487189068078614e-06),
#  'Si_gmo_hd_int': np.float64(0.8376945695795923)}

# %%
# the parameters are updated in the problem
np.testing.assert_allclose(problem.getp(), result.x)

# %% [markdown]
# # plot the data & model

# %%
# %matplotlib inline
for mod in problem.models:
    plt.errorbar(x=mod.probe.Q, y=mod.probe.R, yerr=mod.probe.dR, linestyle='None', marker='.')
    plt.plot(*mod.reflectivity(), color='k', zorder=10)
plt.xscale('log')
plt.yscale('log')

# %% [markdown]
# # Plot the structure of the vfp
#
# Use the vfp's plot method to plot the SLD, volume fraction profile and a stochastic simulation of the interface.
#
# In the current implementation, there is no way to plot the posterior, but this will be added.

# %%
dd_vfp_bare.plot() # equivalent to glob_obj.objectives[0].model.structure.components[1].plot()
plt.show()

# %%
dd_vfp_gmo.plot() # equivalent to glob_obj.objectives[2].model.structure.components[1].plot()
plt.show()
