# %% [markdown]
# # Example usage of `vfp` with refl1d
#
# To demonstrate the `vfp` we'll model some NR data taken with a Si substrate.
#
# Two NR contrasts were taken in a solid-liquid cell with dodecane ($\mathrm{C}_{12}\mathrm{H}_{26}$ \& $\mathrm{C}_{12}\mathrm{D}_{26}$).
#
# Two other contrasts were taken with the same substrate with solutions of glycerol monooleate, a surfactant, in $\mathrm{C}_{12}\mathrm{H}_{26}$ \& $\mathrm{C}_{12}\mathrm{D}_{26}$.

# %%
import pathlib
import os
import matplotlib.pyplot as plt
import numpy as np
from functools import partial

from bumps.parameter import Parameter
import refl1d
from bumps.parameter import Parameter
from bumps.fitproblem import FitProblem 

from refl1d.experiment import Experiment
from refl1d.probe.resolution import sigma2FWHM
from refl1d.sample.material import SLD, Material
from refl1d.sample.layers import Slab, Stack
from refl1d.probe import NeutronProbe

import vfp

# %%
def qt2l(q,t):
    """
    Get wavelength from q and theta.
    """
    return 4 * np.pi * np.sin(np.radians(t)) / q

def tof_loader(filename,
               t=0.25, 
               dqoq=0.03, 
               delimiter="\t", 
               **kw):
    """
    Loads and creates NeutronProbe objects for TOF stitched datasets
    I.e. from multiple angles. In the case of ISIS NR instruments we 
    typically have a constant dq/q resolution which the data is binned to at
    the end of the reduction.

    T incident theta for the lowest angle
    dQoQ dq/q resolution data has been binned to
    filename filename of the data set to be loaded
    kw keyword arguments (kwargs) to be passed to NeutronProbe()
    """
    q, r, dr = np.loadtxt(filename, delimiter=delimiter).T
    data_in = (r, dr)
    
    l = qt2l(q, t)
    # Converting the dq/q resolution into a dq value for each Q point
    
    #dq = sigma2FWHM(q*dqoq)

    probe_out = NeutronProbe(
        T=t, 
        dT=0, 
        L=l, 
        dL=0, 
        data=data_in, 
        #dQo=dq, 
        resolution='normal',
        **kw 
    )

    return probe_out

# %%
dataset_dir = pathlib.Path(vfp.__path__[0]).parents[1] / 'docs'
with os.scandir(dataset_dir) as files:
    nr_data_fps = [file.name for file in files if file.name.startswith('IvsQ')]
    data_fp_dict = {'ddod' : nr_data_fps[0],
                    'hdod' : nr_data_fps[1],
                    'hdod_gmo' : nr_data_fps[2],
                    'ddod_gmo' : nr_data_fps[3]}

# %%
tof_loader_partial = partial(tof_loader, t=0.7, delimiter=',')
probes = map(tof_loader_partial, (dataset_dir /file_name for file_name in data_fp_dict.values()))

# %%
si_dd_probe, si_hd_probe, si_hd_gmo_probe, si_dd_gmo_probe = probes

# %%
plt.errorbar(x=si_dd_probe.Q, 
             y=si_dd_probe.R, 
             yerr=si_dd_probe.dR, 
             marker='.', 
             linestyle='None',
             label=r'Si dd')
plt.errorbar(x=si_dd_gmo_probe.Q, 
             y=si_dd_gmo_probe.R, 
             yerr=si_dd_gmo_probe.dR, 
             marker='.', 
             linestyle='None',
             label=r'Si dd gmo')
plt.errorbar(x=si_hd_probe.Q, 
             y=si_hd_probe.R, 
             yerr=si_hd_probe.dR, 
             marker='.', 
             linestyle='None',
             label=r'Si hd')
plt.errorbar(x=si_hd_gmo_probe.Q, 
             y=si_hd_gmo_probe.R, 
             yerr=si_hd_gmo_probe.dR, 
             marker='.', 
             linestyle='None',
             label=r'Si hd gmo')
plt.legend(frameon=False)
plt.xscale('log') 
plt.yscale('log')
plt.xlabel(r'$Q$ / $\mathrm{\AA{}}^{-1}$')
plt.ylabel(r'$R\left(Q\right)$')
plt.show()

# %% [markdown]
# # The model
# We'll model the bare Si data with a fronting of Si, and layer of $\mathrm{SiO}_{2}$ and a solvent backing.
#
# The SLDs of the materials will be fixed but we'll model the thickness of the $\mathrm{SiO}_{2}$ and the roughness of the interfaces between the materials.
#
# For those contrasts with GMO, we'll model a GMO layer with a fixed SLD of GMO = $0.21 \times 10^{-6} \mathrm{\AA}^{-2}$, a varying solvation, thickness and roughness.
#
# There will be the same interface width between $\mathrm{SiO}_{2}$ and the solvent and between $\mathrm{SiO}_{2}$ and GMO.

# %%
Si = SLD(rho=2.07, name='Si')
SiO2 = SLD(rho=3.47, name='SiO2')
gmo = SLD(rho=0.21, name='gmo')

hdod = SLD(rho=-0.46, name='hdod')
ddod = SLD(rho=6.7, name='ddod')

# lets vary the ddod but not the hdod.
ddod.rho.range(6, 6.7)
# Out:
# Parameter(ddod rho)

# %%
# define thickness and roughness parameters.
SiO2_thick = Parameter(value=20, name='SiO2_thick', vary=True, bounds=(1, 30))
gmo_thick = Parameter(value=20, name='gmo_thick', vary=True, bounds=(1, 30))

Si_SiO2_rough = Parameter(value=3, name='Si_SiO2_rough', vary=True, bounds=(1, 10))
SiO2_solv_rough = Parameter(5, name='SiO2_solv_rough', vary=True, bounds=(1, 10))

SiO2_gmo_rough = SiO2_solv_rough # Parameter(name='SiO2_gmo_rough', constraint=SiO2_solv_rough)
gmo_solv_rough = Parameter(5, name='gmo_solv_rough', vary=True, bounds=(1, 10))

gmo_vf = Parameter(value=1, name='gmo_vf', vary=True, bounds=(0, 1))

# %% [markdown]
# # refl1d works from backing to fronting...

# %%
# define the SLDs of the materials in two lists for the two contrasts.
dd_nslds = [Si.rho,
            SiO2.rho,
            ddod.rho]

hd_nslds = [Si.rho,
            SiO2.rho,
            hdod.rho]

dd_gmo_nslds = [Si.rho,
                SiO2.rho,
                gmo.rho * gmo_vf + ddod.rho * (1-gmo_vf),
                ddod.rho]

hd_gmo_nslds = [Si.rho,
                SiO2.rho,
                gmo.rho * gmo_vf + hdod.rho * (1-gmo_vf),
                hdod.rho]

# define the thicknesses of the all layers, including the fronting but not the backing.
list_of_thicknesses_bare = [0, SiO2_thick]
list_of_thicknesses_gmo = [0, SiO2_thick, gmo_thick]
# define the width the of the interfaces between the materials.
list_of_roughnesses_bare = [Si_SiO2_rough, SiO2_solv_rough]
list_of_roughnesses_gmo = [Si_SiO2_rough, SiO2_gmo_rough, gmo_solv_rough]

# use the list of SLDs, thicknesses and roughnesses to define refnxVFP objects.
dd_vfp_bare = vfp.refl1dVFP(nslds=dd_nslds,
                            thicknesses=list_of_thicknesses_bare,
                            roughnesses=list_of_roughnesses_bare,
                            orientation='back')

hd_vfp_bare = vfp.refl1dVFP(nslds=hd_nslds,
                            thicknesses=list_of_thicknesses_bare,
                            roughnesses=list_of_roughnesses_bare,
                            orientation='back')

dd_vfp_gmo = vfp.refl1dVFP(nslds=dd_gmo_nslds,
                           thicknesses=list_of_thicknesses_gmo,
                           roughnesses=list_of_roughnesses_gmo,
                           orientation='back')

hd_vfp_gmo = vfp.refl1dVFP(nslds=hd_gmo_nslds,
                           thicknesses=list_of_thicknesses_gmo,
                           roughnesses=list_of_roughnesses_gmo,
                           orientation='back')
# Out:
# C:\Users\sandy\OneDrive\PDRA - Job 2021-2024\VFP\src\vfp\vfp.py:962: UserWarning: If msld / isld parameters are part of a function (i.e f(p1, p2) = p1 + p2), they must be of type bumps.parameter.Parameter. Do not use material or SLD objects.
#   warnings.warn(

# %%
# see the parameters in the refnxVFP
# these contain non varying parameters.
print(dd_vfp_gmo.layer_parameters())
# Out:
# {'nslds': [Parameter(Si rho), Parameter(SiO2 rho), Parameter(gmo rho), Parameter(gmo_vf), Parameter(ddod rho)], 'thicknesses': [Parameter(refl1dVFP - thicknesses - fronting), Parameter(SiO2_thick), Parameter(gmo_thick)], 'roughnesses': [Parameter(Si_SiO2_rough), Parameter(SiO2_solv_rough), Parameter(gmo_solv_rough)], 'islds': [Parameter(refl1dVFP - isld - fronting), Parameter(refl1dVFP - isld - layer 1), Parameter(refl1dVFP - isld - layer 2), Parameter(refl1dVFP - isld - backing)], 'mslds': [Parameter(refl1dVFP - msld - fronting), Parameter(refl1dVFP - msld - layer 1), Parameter(refl1dVFP - msld - layer 2), Parameter(refl1dVFP - msld - backing)]}

# %%
# the refnxVFP objects are refnx Component objects so can be placed in a refnx structure.
# place vfps between SLD objects.
dd_struc = ddod | dd_vfp_bare | Si
hd_struc = hdod | hd_vfp_bare | Si
dd_GMO_struc = ddod | dd_vfp_gmo | Si
hd_GMO_struc = hdod | hd_vfp_gmo | Si

# %%
# define instrument / nuisance parameters
si_dd_probe.intensity.range(0.8, 1.2)
si_dd_probe.intensity.name = "Si_dd_int"
si_hd_probe.intensity.range(0.8, 1.2)
si_hd_probe.intensity.name = "Si_hd_int"
si_dd_gmo_probe.intensity.range(0.8, 1.2)
si_dd_gmo_probe.intensity.name = "Si_gmo_dd_int"
si_hd_gmo_probe.intensity.range(0.8, 1.2)
si_hd_gmo_probe.intensity.name = "Si_gmo_hd_int"

si_dd_probe.background.value = 1e-6
si_dd_probe.background.range(1e-10, 1e-4)
si_dd_probe.background.name = "Si_dd_bkg"
si_hd_probe.background.value = 1e-6
si_hd_probe.background.range(1e-10, 1e-4)
si_hd_probe.background.name = "Si_hd_bkg"
si_dd_gmo_probe.background.range(1e-10, 1e-4)
si_dd_gmo_probe.background.value = 1e-6
si_dd_gmo_probe.background.name = "Si_gmo_dd_bkg"
si_hd_gmo_probe.background.range(1e-10, 1e-4)
si_hd_gmo_probe.background.value = 1e-6
si_hd_gmo_probe.background.name = "Si_gmo_hd_bkg"

# %%
exp_si_dd = Experiment(probe=si_dd_probe, sample=dd_struc)
exp_si_hd = Experiment(probe=si_hd_probe, sample=hd_struc)
exp_si_dd_gmo = Experiment(probe=si_dd_gmo_probe, sample=dd_GMO_struc)
exp_si_hd_gmo = Experiment(probe=si_hd_gmo_probe, sample=hd_GMO_struc)

# %%
problem = FitProblem([exp_si_dd, exp_si_hd, exp_si_dd_gmo, exp_si_hd_gmo])

# %%
problem.labels()
# Out:
# ['Si_dd_bkg',
#  'Si_dd_int',
#  'ddod rho',
#  'Si_SiO2_rough',
#  'SiO2_solv_rough',
#  'SiO2_thick',
#  'Si_hd_bkg',
#  'Si_hd_int',
#  'Si_gmo_dd_bkg',
#  'Si_gmo_dd_int',
#  'gmo_vf',
#  'gmo_solv_rough',
#  'gmo_thick',
#  'Si_gmo_hd_bkg',
#  'Si_gmo_hd_int']

# %% [markdown]
# # fit via `bumps.fitters.fit`.
#
# It's more common to write a `refl1d` script and use the cli or the GUI.
# But we can do it interactively...

# %%
from bumps.mapper import MPMapper
from bumps.fitters import fit
mapper = MPMapper.start_mapper(problem, None, cpus=0) #cpu=0 for all CPUs
result = fit(problem, method="de", mapper=mapper, verbose=True, options=dict(steps=1000, pop=160))
# Out:
# step 1 cost 33.778(28)
#                                Si_dd_bkg |.........      1e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....          1 in (0.8, 1.2)
#                                 ddod rho .........|        6.7 in (6, 6.7)
#                            Si_SiO2_rough ..|.......          3 in (1.0, 10.0)
#                          SiO2_solv_rough ....|.....          5 in (1.0, 10.0)
#                               SiO2_thick ......|...         20 in (1.0, 30.0)
#                                Si_hd_bkg |.........      1e-06 in (1e-10, 0.0001)
#                                Si_hd_int ....|.....          1 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |.........      1e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ....|.....          1 in (0.8, 1.2)
#                                   gmo_vf .........|          1 in (0.0, 1.0)
#                           gmo_solv_rough ....|.....          5 in (1.0, 10.0)
#                                gmo_thick ......|...         20 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |.........      1e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int ....|.....          1 in (0.8, 1.2)
# step 7 cost 33.778(28)
# step 15 cost 33.778(28)
# step 21 cost 33.778(28)
# step 27 cost 16.977(28)
# step 33 cost 16.977(28)
# step 34 cost 16.977(28)
# step 39 cost 16.977(28)
# step 44 cost 16.977(28)
# step 49 cost 16.977(28)
# step 53 cost 11.354(28)
# step 57 cost 11.354(28)
# step 60 cost 10.284(28)
# step 62 cost 8.872(28)
# step 63 cost 8.872(28)
# step 65 cost 8.872(28)
# step 68 cost 8.872(28)
# step 70 cost 8.872(28)
# step 73 cost 8.872(28)
# step 75 cost 8.872(28)
# step 78 cost 8.459(28)
# step 82 cost 6.734(28)
#                                Si_dd_bkg .|........ 1.08318e-05 in (1e-10, 0.0001)
#                                Si_dd_int .....|....    1.00904 in (0.8, 1.2)
#                                 ddod rho ........|.      6.598 in (6, 6.7)
#                            Si_SiO2_rough |.........    1.25475 in (1.0, 10.0)
#                          SiO2_solv_rough ......|...    6.91951 in (1.0, 10.0)
#                               SiO2_thick ..|.......    6.84289 in (1.0, 30.0)
#                                Si_hd_bkg |......... 7.4466e-06 in (1e-10, 0.0001)
#                                Si_hd_int .....|....      1.017 in (0.8, 1.2)
#                            Si_gmo_dd_bkg .|........ 1.4867e-05 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ....|.....   0.964095 in (0.8, 1.2)
#                                   gmo_vf .|........   0.140526 in (0.0, 1.0)
#                           gmo_solv_rough .....|....    5.94806 in (1.0, 10.0)
#                                gmo_thick ....|.....    14.5509 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 7.61177e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int ..|.......   0.880121 in (0.8, 1.2)
# step 86 cost 6.734(28)
# step 88 cost 6.734(28)
# step 90 cost 6.734(28)
# step 94 cost 6.282(28)
# step 98 cost 6.167(28)
# step 102 cost 5.972(28)
# step 105 cost 5.651(28)
# step 108 cost 5.569(28)
# step 111 cost 5.569(28)
# step 114 cost 5.500(28)
# step 118 cost 5.410(28)
# step 121 cost 5.178(28)
# step 124 cost 4.874(28)
# step 127 cost 4.874(28)
# step 130 cost 4.718(28)
# step 133 cost 4.402(28)
# step 136 cost 4.402(28)
# step 139 cost 4.402(28)
# step 142 cost 4.402(28)
# step 145 cost 4.170(28)
# step 147 cost 4.170(28)
# step 150 cost 4.170(28)
# step 153 cost 4.170(28)
# step 156 cost 4.170(28)
# step 159 cost 4.068(28)
#                                Si_dd_bkg |......... 8.04597e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.962652 in (0.8, 1.2)
#                                 ddod rho ........|.    6.62146 in (6, 6.7)
#                            Si_SiO2_rough .....|....    6.09882 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.73813 in (1.0, 10.0)
#                               SiO2_thick ..|.......    8.56754 in (1.0, 30.0)
#                                Si_hd_bkg |......... 7.61724e-06 in (1e-10, 0.0001)
#                                Si_hd_int ....|.....   0.996173 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 8.1902e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ..|.......   0.900053 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.859661 in (0.0, 1.0)
#                           gmo_solv_rough ..|.......    3.23808 in (1.0, 10.0)
#                                gmo_thick .....|....    18.1915 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 6.45425e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int ...|......   0.922126 in (0.8, 1.2)
# step 162 cost 3.959(28)
# step 165 cost 3.804(28)
# step 167 cost 3.804(28)
# step 169 cost 3.767(28)
# step 171 cost 3.767(28)
# step 173 cost 3.700(28)
# step 175 cost 3.700(28)
# step 177 cost 3.574(28)
# step 179 cost 3.574(28)
# step 181 cost 3.574(28)
# step 183 cost 3.574(28)
# step 185 cost 3.553(28)
# step 187 cost 3.553(28)
# step 189 cost 3.553(28)
# step 191 cost 3.539(28)
# step 192 cost 3.539(28)
# step 194 cost 3.515(28)
# step 196 cost 3.515(28)
# step 198 cost 3.487(28)
# step 200 cost 3.475(28)
# step 202 cost 3.475(28)
# step 204 cost 3.475(28)
#                                Si_dd_bkg |.........  7.506e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.981806 in (0.8, 1.2)
#                                 ddod rho ........|.     6.6244 in (6, 6.7)
#                            Si_SiO2_rough ........|.     8.5126 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.20669 in (1.0, 10.0)
#                               SiO2_thick ..|.......     8.3768 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.7519e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.953529 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 9.18711e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ..|.......   0.918795 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.883654 in (0.0, 1.0)
#                           gmo_solv_rough ..|.......    3.20975 in (1.0, 10.0)
#                                gmo_thick .....|....    17.0981 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.75303e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int ..|.......   0.895137 in (0.8, 1.2)
# step 206 cost 3.472(28)
# step 208 cost 3.472(28)
# step 210 cost 3.427(28)
# step 212 cost 3.427(28)
# step 214 cost 3.427(28)
# step 216 cost 3.415(28)
# step 218 cost 3.415(28)
# step 220 cost 3.402(28)
# step 222 cost 3.402(28)
# step 224 cost 3.402(28)
# step 226 cost 3.402(28)
# step 228 cost 3.398(28)
# step 230 cost 3.384(28)
# step 232 cost 3.384(28)
# step 234 cost 3.384(28)
# step 235 cost 3.383(28)
# step 236 cost 3.383(28)
# step 238 cost 3.383(28)
# step 239 cost 3.383(28)
# step 240 cost 3.383(28)
#                                Si_dd_bkg |......... 8.68176e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.997883 in (0.8, 1.2)
#                                 ddod rho ........|.    6.61879 in (6, 6.7)
#                            Si_SiO2_rough ........|.    8.98883 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.38322 in (1.0, 10.0)
#                               SiO2_thick ...|......    10.3214 in (1.0, 30.0)
#                                Si_hd_bkg |......... 7.07711e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.928109 in (0.8, 1.2)
#                            Si_gmo_dd_bkg .|........ 1.01043e-05 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......     0.9267 in (0.8, 1.2)
#                                   gmo_vf .........|   0.915077 in (0.0, 1.0)
#                           gmo_solv_rough .....|....    5.83034 in (1.0, 10.0)
#                                gmo_thick ......|...    18.5348 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.49448e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int .|........   0.865015 in (0.8, 1.2)
# step 241 cost 3.347(28)
# step 242 cost 3.347(28)
# step 244 cost 3.347(28)
# step 245 cost 3.347(28)
# step 246 cost 3.347(28)
# step 247 cost 3.347(28)
# step 248 cost 3.347(28)
# step 250 cost 3.347(28)
# step 251 cost 3.347(28)
# step 252 cost 3.347(28)
# step 254 cost 3.345(28)
# step 255 cost 3.338(28)
# step 256 cost 3.338(28)
# step 257 cost 3.338(28)
# step 258 cost 3.338(28)
# step 259 cost 3.338(28)
# step 261 cost 3.338(28)
# step 262 cost 3.334(28)
# step 263 cost 3.327(28)
# step 265 cost 3.312(28)
# step 267 cost 3.312(28)
# step 268 cost 3.312(28)
#                                Si_dd_bkg |......... 8.32657e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.990565 in (0.8, 1.2)
#                                 ddod rho ........|.     6.6235 in (6, 6.7)
#                            Si_SiO2_rough .......|..    8.03064 in (1.0, 10.0)
#                          SiO2_solv_rough .......|..    7.98469 in (1.0, 10.0)
#                               SiO2_thick ...|......    10.6443 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.49616e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.941422 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 7.07066e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......    0.92265 in (0.8, 1.2)
#                                   gmo_vf ........|.    0.85613 in (0.0, 1.0)
#                           gmo_solv_rough .|........    2.05862 in (1.0, 10.0)
#                                gmo_thick ......|...    18.6077 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.47303e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int .|........   0.854185 in (0.8, 1.2)
# step 270 cost 3.312(28)
# step 272 cost 3.312(28)
# step 274 cost 3.312(28)
# step 276 cost 3.312(28)
# step 278 cost 3.312(28)
# step 280 cost 3.312(28)
# step 282 cost 3.308(28)
# step 284 cost 3.308(28)
# step 286 cost 3.307(28)
# step 288 cost 3.307(28)
# step 290 cost 3.307(28)
# step 292 cost 3.304(28)
# step 294 cost 3.304(28)
# step 296 cost 3.304(28)
# step 298 cost 3.304(28)
# step 300 cost 3.304(28)
#                                Si_dd_bkg |......... 8.32544e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....      0.991 in (0.8, 1.2)
#                                 ddod rho ........|.    6.62187 in (6, 6.7)
#                            Si_SiO2_rough ......|...    7.20583 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.     8.3005 in (1.0, 10.0)
#                               SiO2_thick ...|......    11.3207 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.8503e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.934193 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.94943e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......   0.924346 in (0.8, 1.2)
#                                   gmo_vf ........|.    0.87459 in (0.0, 1.0)
#                           gmo_solv_rough .|........    2.23707 in (1.0, 10.0)
#                                gmo_thick ......|...    18.4382 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.71192e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int .|........   0.843194 in (0.8, 1.2)
# step 302 cost 3.304(28)
# step 304 cost 3.301(28)
# step 306 cost 3.301(28)
# step 307 cost 3.301(28)
# step 308 cost 3.301(28)
# step 309 cost 3.301(28)
# step 310 cost 3.301(28)
# step 311 cost 3.301(28)
# step 312 cost 3.301(28)
# step 313 cost 3.301(28)
# step 314 cost 3.301(28)
# step 315 cost 3.301(28)
# step 316 cost 3.301(28)
# step 317 cost 3.300(28)
# step 318 cost 3.300(28)
# step 319 cost 3.300(28)
# step 320 cost 3.300(28)
#                                Si_dd_bkg |......... 8.40734e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.991664 in (0.8, 1.2)
#                                 ddod rho ........|.    6.62241 in (6, 6.7)
#                            Si_SiO2_rough ........|.    8.44952 in (1.0, 10.0)
#                          SiO2_solv_rough .......|..    7.79604 in (1.0, 10.0)
#                               SiO2_thick ...|......    10.6929 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.47812e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.932507 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.98458e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......   0.927301 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.857443 in (0.0, 1.0)
#                           gmo_solv_rough |.........    1.70281 in (1.0, 10.0)
#                                gmo_thick ......|...    18.4003 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.58797e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.834814 in (0.8, 1.2)
# step 321 cost 3.300(28)
# step 322 cost 3.300(28)
# step 323 cost 3.300(28)
# step 324 cost 3.298(28)
# step 325 cost 3.298(28)
# step 326 cost 3.298(28)
# step 327 cost 3.298(28)
# step 329 cost 3.298(28)
# step 330 cost 3.298(28)
# step 331 cost 3.298(28)
# step 332 cost 3.298(28)
# step 333 cost 3.298(28)
# step 335 cost 3.298(28)
# step 336 cost 3.298(28)
# step 337 cost 3.298(28)
# step 338 cost 3.298(28)
# step 339 cost 3.298(28)
# step 340 cost 3.298(28)
# step 342 cost 3.297(28)
# step 343 cost 3.297(28)
# step 344 cost 3.297(28)
# step 345 cost 3.297(28)
# step 346 cost 3.297(28)
# step 347 cost 3.297(28)
#                                Si_dd_bkg |......... 8.38872e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.992385 in (0.8, 1.2)
#                                 ddod rho ........|.    6.62087 in (6, 6.7)
#                            Si_SiO2_rough ......|...    7.11426 in (1.0, 10.0)
#                          SiO2_solv_rough .......|..    8.10314 in (1.0, 10.0)
#                               SiO2_thick ...|......    11.4853 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.43051e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.927687 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.59349e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......    0.92514 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.863397 in (0.0, 1.0)
#                           gmo_solv_rough |.........    1.80874 in (1.0, 10.0)
#                                gmo_thick ......|...    18.6371 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.63296e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.838564 in (0.8, 1.2)
# step 348 cost 3.297(28)
# step 349 cost 3.297(28)
# step 350 cost 3.297(28)
# step 351 cost 3.297(28)
# step 352 cost 3.295(28)
# step 353 cost 3.295(28)
# step 354 cost 3.295(28)
# step 355 cost 3.295(28)
# step 356 cost 3.295(28)
# step 357 cost 3.295(28)
# step 358 cost 3.295(28)
# step 359 cost 3.295(28)
# step 360 cost 3.295(28)
# step 361 cost 3.295(28)
# step 362 cost 3.295(28)
# step 363 cost 3.295(28)
# step 364 cost 3.295(28)
# step 365 cost 3.295(28)
# step 366 cost 3.295(28)
# step 367 cost 3.295(28)
# step 368 cost 3.295(28)
# step 370 cost 3.295(28)
# step 372 cost 3.295(28)
#                                Si_dd_bkg |......... 8.32572e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.991956 in (0.8, 1.2)
#                                 ddod rho ........|.    6.62102 in (6, 6.7)
#                            Si_SiO2_rough ......|...    6.89817 in (1.0, 10.0)
#                          SiO2_solv_rough .......|..    8.07326 in (1.0, 10.0)
#                               SiO2_thick ...|......    11.6786 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.48415e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.936331 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.3586e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......   0.926579 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.872131 in (0.0, 1.0)
#                           gmo_solv_rough |.........    1.62497 in (1.0, 10.0)
#                                gmo_thick .....|....     18.026 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.62314e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.837108 in (0.8, 1.2)
# step 373 cost 3.295(28)
# step 374 cost 3.295(28)
# step 375 cost 3.295(28)
# step 377 cost 3.294(28)
# step 379 cost 3.294(28)
# step 380 cost 3.294(28)
# step 382 cost 3.294(28)
# step 383 cost 3.294(28)
# step 385 cost 3.294(28)
# step 387 cost 3.294(28)
# step 389 cost 3.294(28)
# step 390 cost 3.294(28)
# step 392 cost 3.294(28)
# step 394 cost 3.294(28)
# step 395 cost 3.294(28)
# step 397 cost 3.294(28)
# step 398 cost 3.294(28)
# step 400 cost 3.294(28)
#                                Si_dd_bkg |......... 8.4091e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.991372 in (0.8, 1.2)
#                                 ddod rho ........|.    6.62088 in (6, 6.7)
#                            Si_SiO2_rough ......|...    6.85594 in (1.0, 10.0)
#                          SiO2_solv_rough .......|..    8.11435 in (1.0, 10.0)
#                               SiO2_thick ...|......    11.7566 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.46166e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......    0.93337 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.4608e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......   0.926327 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.872687 in (0.0, 1.0)
#                           gmo_solv_rough |.........    1.80987 in (1.0, 10.0)
#                                gmo_thick .....|....    18.1315 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.56663e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.835452 in (0.8, 1.2)
# step 402 cost 3.294(28)
# step 404 cost 3.294(28)
# step 406 cost 3.294(28)
# step 408 cost 3.294(28)
# step 410 cost 3.294(28)
# step 412 cost 3.294(28)
# step 414 cost 3.294(28)
# step 416 cost 3.294(28)
# step 418 cost 3.294(28)
# step 420 cost 3.294(28)
# step 422 cost 3.294(28)
# step 424 cost 3.294(28)
# step 426 cost 3.294(28)
# step 428 cost 3.293(28)
# step 430 cost 3.293(28)
# step 432 cost 3.293(28)
# step 433 cost 3.293(28)
# step 435 cost 3.293(28)
#                                Si_dd_bkg |......... 8.39681e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.991559 in (0.8, 1.2)
#                                 ddod rho ........|.    6.62138 in (6, 6.7)
#                            Si_SiO2_rough ......|...    6.73888 in (1.0, 10.0)
#                          SiO2_solv_rough .......|..    8.12435 in (1.0, 10.0)
#                               SiO2_thick ...|......    11.8265 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.45012e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.933759 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.41799e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......   0.925319 in (0.8, 1.2)
#                                   gmo_vf ........|.    0.87535 in (0.0, 1.0)
#                           gmo_solv_rough |.........    1.76708 in (1.0, 10.0)
#                                gmo_thick .....|....    18.0659 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.5956e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.835134 in (0.8, 1.2)
# step 437 cost 3.293(28)
# step 439 cost 3.293(28)
# step 440 cost 3.293(28)
# step 441 cost 3.293(28)
# step 443 cost 3.293(28)
# step 444 cost 3.293(28)
# step 445 cost 3.293(28)
# step 447 cost 3.293(28)
# step 448 cost 3.293(28)
# step 449 cost 3.293(28)
# step 451 cost 3.293(28)
# step 452 cost 3.293(28)
# step 453 cost 3.293(28)
# step 454 cost 3.293(28)
# step 455 cost 3.293(28)
# step 456 cost 3.293(28)
# step 458 cost 3.293(28)
# step 459 cost 3.293(28)
#                                Si_dd_bkg |......... 8.3596e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.991634 in (0.8, 1.2)
#                                 ddod rho ........|.    6.62099 in (6, 6.7)
#                            Si_SiO2_rough ......|...    6.69213 in (1.0, 10.0)
#                          SiO2_solv_rough .......|..     8.1176 in (1.0, 10.0)
#                               SiO2_thick ...|......    11.8228 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.45029e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.932651 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.18737e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......   0.925516 in (0.8, 1.2)
#                                   gmo_vf ........|.    0.87269 in (0.0, 1.0)
#                           gmo_solv_rough |.........    1.34137 in (1.0, 10.0)
#                                gmo_thick .....|....    18.0829 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.54382e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.835244 in (0.8, 1.2)
# step 461 cost 3.293(28)
# step 462 cost 3.293(28)
# step 463 cost 3.293(28)
# step 464 cost 3.293(28)
# step 465 cost 3.293(28)
# step 466 cost 3.293(28)
# step 467 cost 3.293(28)
# step 468 cost 3.293(28)
# step 469 cost 3.293(28)
# step 470 cost 3.293(28)
# step 471 cost 3.293(28)
# step 472 cost 3.293(28)
# step 474 cost 3.293(28)
# step 476 cost 3.293(28)
# step 478 cost 3.293(28)
# step 479 cost 3.293(28)
# step 481 cost 3.293(28)
# step 483 cost 3.293(28)
# step 485 cost 3.293(28)
# step 487 cost 3.293(28)
#                                Si_dd_bkg |......... 8.38522e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.991918 in (0.8, 1.2)
#                                 ddod rho ........|.    6.62091 in (6, 6.7)
#                            Si_SiO2_rough ......|...    6.55801 in (1.0, 10.0)
#                          SiO2_solv_rough .......|..    8.14018 in (1.0, 10.0)
#                               SiO2_thick ...|......    11.8949 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.44285e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.933725 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.20366e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......   0.925387 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.872609 in (0.0, 1.0)
#                           gmo_solv_rough |.........    1.35298 in (1.0, 10.0)
#                                gmo_thick .....|....    18.1406 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.56545e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........    0.83618 in (0.8, 1.2)
# step 489 cost 3.293(28)
# step 491 cost 3.293(28)
# step 493 cost 3.293(28)
# step 495 cost 3.293(28)
# step 497 cost 3.293(28)
# step 499 cost 3.293(28)
# step 501 cost 3.293(28)
# step 503 cost 3.293(28)
# step 504 cost 3.293(28)
# step 505 cost 3.293(28)
# step 506 cost 3.293(28)
# step 507 cost 3.293(28)
# step 508 cost 3.293(28)
# step 509 cost 3.293(28)
# step 510 cost 3.293(28)
# step 511 cost 3.293(28)
# step 513 cost 3.293(28)
# step 515 cost 3.293(28)
#                                Si_dd_bkg |......... 8.37606e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.991783 in (0.8, 1.2)
#                                 ddod rho ........|.    6.62096 in (6, 6.7)
#                            Si_SiO2_rough ......|...     6.4067 in (1.0, 10.0)
#                          SiO2_solv_rough .......|..    8.15571 in (1.0, 10.0)
#                               SiO2_thick ...|......    11.9604 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.44558e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.933867 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.21997e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......   0.925387 in (0.8, 1.2)
#                                   gmo_vf ........|.    0.87403 in (0.0, 1.0)
#                           gmo_solv_rough |.........    1.44545 in (1.0, 10.0)
#                                gmo_thick .....|....    18.1181 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.5633e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.836067 in (0.8, 1.2)
# step 517 cost 3.293(28)
# step 519 cost 3.293(28)
# step 520 cost 3.293(28)
# step 522 cost 3.293(28)
# step 524 cost 3.293(28)
# step 526 cost 3.293(28)
# step 528 cost 3.293(28)
# step 530 cost 3.293(28)
# step 532 cost 3.293(28)
# step 534 cost 3.293(28)
# step 535 cost 3.293(28)
# step 536 cost 3.293(28)
# step 537 cost 3.293(28)
# step 538 cost 3.293(28)
# step 539 cost 3.293(28)
# step 540 cost 3.293(28)
# step 541 cost 3.293(28)
# step 542 cost 3.293(28)
# step 543 cost 3.293(28)
#                                Si_dd_bkg |......... 8.38907e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....    0.99172 in (0.8, 1.2)
#                                 ddod rho ........|.    6.62096 in (6, 6.7)
#                            Si_SiO2_rough .....|....    6.38521 in (1.0, 10.0)
#                          SiO2_solv_rough .......|..    8.15763 in (1.0, 10.0)
#                               SiO2_thick ...|......    11.9907 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.4548e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......    0.93351 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.19483e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......   0.925397 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.873661 in (0.0, 1.0)
#                           gmo_solv_rough |.........    1.43104 in (1.0, 10.0)
#                                gmo_thick .....|....    18.1272 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.56243e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.835784 in (0.8, 1.2)
# step 545 cost 3.293(28)
# step 546 cost 3.293(28)
# step 547 cost 3.293(28)
# step 548 cost 3.293(28)
# step 549 cost 3.293(28)
# step 550 cost 3.293(28)
# step 551 cost 3.293(28)
# step 552 cost 3.293(28)
# step 553 cost 3.293(28)
# step 554 cost 3.293(28)
# step 555 cost 3.293(28)
# step 556 cost 3.293(28)
# step 557 cost 3.293(28)
# step 558 cost 3.293(28)
# step 559 cost 3.293(28)
# step 560 cost 3.293(28)
# step 561 cost 3.293(28)
# step 562 cost 3.293(28)
# step 563 cost 3.293(28)
# step 564 cost 3.293(28)
# step 565 cost 3.293(28)
# step 566 cost 3.293(28)
#                                Si_dd_bkg |......... 8.42234e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.991832 in (0.8, 1.2)
#                                 ddod rho ........|.    6.62108 in (6, 6.7)
#                            Si_SiO2_rough .....|....    6.17889 in (1.0, 10.0)
#                          SiO2_solv_rough .......|..    8.18782 in (1.0, 10.0)
#                               SiO2_thick ...|......     12.109 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.44202e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.934121 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.28856e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......   0.925364 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.878325 in (0.0, 1.0)
#                           gmo_solv_rough |.........    1.87607 in (1.0, 10.0)
#                                gmo_thick .....|....     18.142 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.54688e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.835971 in (0.8, 1.2)
# step 567 cost 3.293(28)
# step 568 cost 3.293(28)
# step 569 cost 3.293(28)
# step 571 cost 3.293(28)
# step 572 cost 3.293(28)
# step 573 cost 3.293(28)
# step 574 cost 3.293(28)
# step 575 cost 3.293(28)
# step 576 cost 3.293(28)
# step 577 cost 3.293(28)
# step 578 cost 3.293(28)
# step 579 cost 3.293(28)
# step 580 cost 3.293(28)
# step 582 cost 3.293(28)
# step 584 cost 3.293(28)
# step 586 cost 3.293(28)
# step 587 cost 3.293(28)
# step 588 cost 3.293(28)
# step 589 cost 3.293(28)
# step 591 cost 3.293(28)
# step 593 cost 3.293(28)
#                                Si_dd_bkg |......... 8.41849e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.991868 in (0.8, 1.2)
#                                 ddod rho ........|.      6.621 in (6, 6.7)
#                            Si_SiO2_rough .....|....     6.1327 in (1.0, 10.0)
#                          SiO2_solv_rough .......|..    8.18921 in (1.0, 10.0)
#                               SiO2_thick ...|......     12.126 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.43042e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.934028 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.28635e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......   0.925265 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.878536 in (0.0, 1.0)
#                           gmo_solv_rough |.........    1.88689 in (1.0, 10.0)
#                                gmo_thick .....|....    18.1423 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.55039e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........    0.83592 in (0.8, 1.2)
# step 594 cost 3.293(28)
# step 595 cost 3.293(28)
# step 596 cost 3.293(28)
# step 597 cost 3.293(28)
# step 598 cost 3.293(28)
# step 600 cost 3.293(28)
# step 602 cost 3.293(28)
# step 603 cost 3.293(28)
# step 605 cost 3.293(28)
# step 606 cost 3.293(28)
# step 607 cost 3.293(28)
# step 609 cost 3.293(28)
# step 611 cost 3.293(28)
# step 612 cost 3.293(28)
# step 613 cost 3.293(28)
# step 615 cost 3.293(28)
# step 617 cost 3.293(28)
# step 618 cost 3.293(28)
# step 619 cost 3.293(28)
# step 620 cost 3.293(28)
#                                Si_dd_bkg |......... 8.41976e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.991775 in (0.8, 1.2)
#                                 ddod rho ........|.    6.62098 in (6, 6.7)
#                            Si_SiO2_rough .....|....     6.0086 in (1.0, 10.0)
#                          SiO2_solv_rough .......|..     8.1956 in (1.0, 10.0)
#                               SiO2_thick ...|......    12.1844 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.43232e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.934318 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.25324e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......   0.925434 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.878592 in (0.0, 1.0)
#                           gmo_solv_rough |.........    1.82409 in (1.0, 10.0)
#                                gmo_thick .....|....    18.1417 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.53258e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.835737 in (0.8, 1.2)
# step 621 cost 3.293(28)
# step 622 cost 3.293(28)
# step 623 cost 3.293(28)
# step 625 cost 3.293(28)
# step 626 cost 3.293(28)
# step 627 cost 3.293(28)
# step 628 cost 3.293(28)
# step 629 cost 3.293(28)
# step 630 cost 3.293(28)
# step 631 cost 3.293(28)
# step 632 cost 3.293(28)
# step 633 cost 3.293(28)
# step 634 cost 3.293(28)
# step 635 cost 3.293(28)
# step 636 cost 3.293(28)
# step 637 cost 3.293(28)
# step 638 cost 3.293(28)
# step 639 cost 3.293(28)
# step 640 cost 3.293(28)
# step 641 cost 3.293(28)
# step 642 cost 3.293(28)
# step 643 cost 3.293(28)
# step 645 cost 3.293(28)
# step 646 cost 3.293(28)
#                                Si_dd_bkg |.........  8.417e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.991777 in (0.8, 1.2)
#                                 ddod rho ........|.    6.62099 in (6, 6.7)
#                            Si_SiO2_rough .....|....    5.96403 in (1.0, 10.0)
#                          SiO2_solv_rough .......|..    8.19803 in (1.0, 10.0)
#                               SiO2_thick ...|......    12.2101 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.42549e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.934344 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.28986e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......   0.925432 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.879729 in (0.0, 1.0)
#                           gmo_solv_rough .|........    1.95366 in (1.0, 10.0)
#                                gmo_thick .....|....    18.1461 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.53373e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.835943 in (0.8, 1.2)
# step 647 cost 3.293(28)
# step 648 cost 3.293(28)
# step 649 cost 3.293(28)
# step 650 cost 3.293(28)
# step 651 cost 3.293(28)
# step 652 cost 3.293(28)
# step 653 cost 3.293(28)
# step 654 cost 3.293(28)
# step 655 cost 3.293(28)
# step 656 cost 3.293(28)
# step 657 cost 3.293(28)
# step 658 cost 3.293(28)
# step 659 cost 3.293(28)
# step 661 cost 3.293(28)
# step 662 cost 3.293(28)
# step 663 cost 3.293(28)
# step 664 cost 3.293(28)
# step 665 cost 3.293(28)
# step 666 cost 3.293(28)
# step 667 cost 3.293(28)
# step 668 cost 3.293(28)
# step 669 cost 3.293(28)
# step 670 cost 3.293(28)
# step 671 cost 3.293(28)
#                                Si_dd_bkg |......... 8.42571e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....    0.99176 in (0.8, 1.2)
#                                 ddod rho ........|.    6.62099 in (6, 6.7)
#                            Si_SiO2_rough .....|....    5.80599 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.22229 in (1.0, 10.0)
#                               SiO2_thick ...|......    12.2667 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.42435e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......    0.93497 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.31635e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......    0.92537 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.880305 in (0.0, 1.0)
#                           gmo_solv_rough .|........     2.0563 in (1.0, 10.0)
#                                gmo_thick .....|....    18.2082 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.53993e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.836698 in (0.8, 1.2)
# step 672 cost 3.293(28)
# step 673 cost 3.293(28)
# step 674 cost 3.293(28)
# step 675 cost 3.293(28)
# step 676 cost 3.293(28)
# step 677 cost 3.293(28)
# step 678 cost 3.293(28)
# step 679 cost 3.293(28)
# step 680 cost 3.293(28)
# step 681 cost 3.293(28)
# step 682 cost 3.293(28)
# step 683 cost 3.293(28)
# step 684 cost 3.293(28)
# step 685 cost 3.293(28)
# step 686 cost 3.293(28)
# step 687 cost 3.293(28)
# step 688 cost 3.293(28)
# step 689 cost 3.293(28)
# step 690 cost 3.293(28)
# step 691 cost 3.293(28)
# step 692 cost 3.293(28)
# step 693 cost 3.293(28)
# step 694 cost 3.293(28)
# step 695 cost 3.293(28)
#                                Si_dd_bkg |......... 8.42725e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.991725 in (0.8, 1.2)
#                                 ddod rho ........|.    6.62106 in (6, 6.7)
#                            Si_SiO2_rough .....|....    5.63192 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.22642 in (1.0, 10.0)
#                               SiO2_thick ...|......    12.3548 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.41181e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.935311 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.35808e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......    0.92533 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.883015 in (0.0, 1.0)
#                           gmo_solv_rough .|........    2.28043 in (1.0, 10.0)
#                                gmo_thick .....|....    18.2277 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.53216e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.836628 in (0.8, 1.2)
# step 696 cost 3.293(28)
# step 697 cost 3.293(28)
# step 698 cost 3.293(28)
# step 699 cost 3.293(28)
# step 700 cost 3.293(28)
# step 701 cost 3.293(28)
# step 703 cost 3.293(28)
# step 704 cost 3.293(28)
# step 705 cost 3.293(28)
# step 707 cost 3.293(28)
# step 709 cost 3.293(28)
# step 710 cost 3.293(28)
# step 712 cost 3.293(28)
# step 713 cost 3.293(28)
# step 715 cost 3.293(28)
# step 717 cost 3.293(28)
# step 719 cost 3.293(28)
# step 721 cost 3.293(28)
# step 722 cost 3.293(28)
# step 724 cost 3.293(28)
#                                Si_dd_bkg |......... 8.42262e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.991735 in (0.8, 1.2)
#                                 ddod rho ........|.    6.62102 in (6, 6.7)
#                            Si_SiO2_rough .....|....    5.68345 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.     8.2193 in (1.0, 10.0)
#                               SiO2_thick ...|......    12.3322 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.41727e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.935147 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.36833e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......   0.925427 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.882186 in (0.0, 1.0)
#                           gmo_solv_rough .|........    2.23424 in (1.0, 10.0)
#                                gmo_thick .....|....     18.223 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.53125e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.836679 in (0.8, 1.2)
# step 726 cost 3.293(28)
# step 728 cost 3.293(28)
# step 729 cost 3.293(28)
# step 730 cost 3.293(28)
# step 732 cost 3.293(28)
# step 734 cost 3.293(28)
# step 736 cost 3.293(28)
# step 737 cost 3.293(28)
# step 738 cost 3.293(28)
# step 739 cost 3.293(28)
# step 741 cost 3.293(28)
# step 743 cost 3.293(28)
# step 745 cost 3.293(28)
# step 747 cost 3.293(28)
# step 748 cost 3.293(28)
# step 750 cost 3.293(28)
# step 752 cost 3.293(28)
# step 754 cost 3.293(28)
#                                Si_dd_bkg |......... 8.43297e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.991739 in (0.8, 1.2)
#                                 ddod rho ........|.    6.62104 in (6, 6.7)
#                            Si_SiO2_rough ....|.....    5.45656 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.24637 in (1.0, 10.0)
#                               SiO2_thick ...|......    12.4203 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.40701e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.936067 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.43512e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......    0.92529 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.884707 in (0.0, 1.0)
#                           gmo_solv_rough .|........    2.43457 in (1.0, 10.0)
#                                gmo_thick .....|....     18.257 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.52236e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.836963 in (0.8, 1.2)
# step 756 cost 3.293(28)
# step 758 cost 3.293(28)
# step 760 cost 3.293(28)
# step 762 cost 3.293(28)
# step 764 cost 3.293(28)
# step 766 cost 3.293(28)
# step 768 cost 3.293(28)
# step 770 cost 3.293(28)
# step 772 cost 3.293(28)
# step 774 cost 3.293(28)
# step 776 cost 3.293(28)
# step 778 cost 3.293(28)
# step 780 cost 3.293(28)
# step 782 cost 3.293(28)
# step 784 cost 3.293(28)
# step 786 cost 3.293(28)
# step 788 cost 3.293(28)
#                                Si_dd_bkg |......... 8.44282e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.991716 in (0.8, 1.2)
#                                 ddod rho ........|.    6.62102 in (6, 6.7)
#                            Si_SiO2_rough ....|.....    5.29502 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.24613 in (1.0, 10.0)
#                               SiO2_thick ...|......    12.5027 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.39981e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.935408 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.49503e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......   0.925396 in (0.8, 1.2)
#                                   gmo_vf ........|.    0.88754 in (0.0, 1.0)
#                           gmo_solv_rough .|........    2.62354 in (1.0, 10.0)
#                                gmo_thick .....|....    18.2611 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.5036e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.836806 in (0.8, 1.2)
# step 790 cost 3.293(28)
# step 792 cost 3.293(28)
# step 794 cost 3.293(28)
# step 796 cost 3.293(28)
# step 798 cost 3.293(28)
# step 800 cost 3.293(28)
# step 802 cost 3.293(28)
# step 804 cost 3.293(28)
# step 806 cost 3.293(28)
# step 807 cost 3.293(28)
# step 809 cost 3.293(28)
# step 811 cost 3.293(28)
# step 813 cost 3.293(28)
# step 815 cost 3.293(28)
# step 817 cost 3.293(28)
# step 819 cost 3.293(28)
# step 821 cost 3.293(28)
#                                Si_dd_bkg |......... 8.44104e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.991724 in (0.8, 1.2)
#                                 ddod rho ........|.    6.62102 in (6, 6.7)
#                            Si_SiO2_rough ....|.....    5.18029 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.24585 in (1.0, 10.0)
#                               SiO2_thick ...|......    12.5446 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.38203e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.935753 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.51401e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......   0.925368 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.888621 in (0.0, 1.0)
#                           gmo_solv_rough .|........    2.70887 in (1.0, 10.0)
#                                gmo_thick .....|....    18.2867 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.50155e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.836986 in (0.8, 1.2)
# step 823 cost 3.293(28)
# step 825 cost 3.293(28)
# step 827 cost 3.293(28)
# step 829 cost 3.293(28)
# step 831 cost 3.293(28)
# step 833 cost 3.293(28)
# step 835 cost 3.293(28)
# step 836 cost 3.293(28)
# step 838 cost 3.293(28)
# step 840 cost 3.293(28)
# step 842 cost 3.293(28)
# step 843 cost 3.293(28)
# step 845 cost 3.293(28)
# step 847 cost 3.293(28)
# step 849 cost 3.293(28)
# step 851 cost 3.293(28)
# step 853 cost 3.293(28)
# step 854 cost 3.293(28)
# step 855 cost 3.293(28)
#                                Si_dd_bkg |......... 8.44382e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.991701 in (0.8, 1.2)
#                                 ddod rho ........|.    6.62102 in (6, 6.7)
#                            Si_SiO2_rough ....|.....    5.06972 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.      8.256 in (1.0, 10.0)
#                               SiO2_thick ...|......    12.5948 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.37892e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.935912 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.5639e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......   0.925404 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.890072 in (0.0, 1.0)
#                           gmo_solv_rough ..|.......    2.82577 in (1.0, 10.0)
#                                gmo_thick .....|....    18.3079 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.49529e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.837227 in (0.8, 1.2)
# step 857 cost 3.293(28)
# step 859 cost 3.293(28)
# step 861 cost 3.293(28)
# step 863 cost 3.293(28)
# step 865 cost 3.293(28)
# step 867 cost 3.293(28)
# step 869 cost 3.293(28)
# step 871 cost 3.293(28)
# step 873 cost 3.293(28)
# step 875 cost 3.293(28)
# step 877 cost 3.293(28)
# step 879 cost 3.293(28)
# step 881 cost 3.293(28)
# step 883 cost 3.293(28)
# step 885 cost 3.293(28)
# step 887 cost 3.293(28)
# step 889 cost 3.293(28)
#                                Si_dd_bkg |......... 8.4439e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....    0.99175 in (0.8, 1.2)
#                                 ddod rho ........|.    6.62101 in (6, 6.7)
#                            Si_SiO2_rough ....|.....    4.94021 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.26684 in (1.0, 10.0)
#                               SiO2_thick ....|.....    12.6408 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.3692e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.936321 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.58951e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......   0.925447 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.890982 in (0.0, 1.0)
#                           gmo_solv_rough ..|.......    2.90216 in (1.0, 10.0)
#                                gmo_thick .....|....    18.3425 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.49131e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.837552 in (0.8, 1.2)
# step 891 cost 3.293(28)
# step 893 cost 3.293(28)
# step 895 cost 3.293(28)
# step 896 cost 3.293(28)
# step 897 cost 3.293(28)
# step 899 cost 3.293(28)
# step 901 cost 3.293(28)
# step 903 cost 3.293(28)
# step 904 cost 3.293(28)
# step 906 cost 3.293(28)
# step 908 cost 3.293(28)
# step 910 cost 3.293(28)
# step 912 cost 3.293(28)
# step 914 cost 3.293(28)
# step 916 cost 3.293(28)
# step 918 cost 3.293(28)
# step 920 cost 3.293(28)
# step 922 cost 3.293(28)
# step 924 cost 3.293(28)
#                                Si_dd_bkg |......... 8.4497e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....   0.991741 in (0.8, 1.2)
#                                 ddod rho ........|.      6.621 in (6, 6.7)
#                            Si_SiO2_rough ....|.....    4.87933 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.27032 in (1.0, 10.0)
#                               SiO2_thick ....|.....    12.6642 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.36876e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.936322 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.59566e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......   0.925429 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.891674 in (0.0, 1.0)
#                           gmo_solv_rough ..|.......     2.9374 in (1.0, 10.0)
#                                gmo_thick .....|....    18.3475 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.48805e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........   0.837653 in (0.8, 1.2)
# step 926 cost 3.293(28)
# step 928 cost 3.293(28)
# step 930 cost 3.293(28)
# step 932 cost 3.293(28)
# step 934 cost 3.293(28)
# step 936 cost 3.293(28)
# step 938 cost 3.293(28)
# step 940 cost 3.293(28)
# step 942 cost 3.293(28)
# step 944 cost 3.293(28)
# step 946 cost 3.293(28)
# step 947 cost 3.293(28)
# step 948 cost 3.293(28)
# step 950 cost 3.293(28)
# step 952 cost 3.293(28)
# step 953 cost 3.293(28)
# step 954 cost 3.293(28)
# step 956 cost 3.293(28)
#                                Si_dd_bkg |......... 8.4504e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....    0.99173 in (0.8, 1.2)
#                                 ddod rho ........|.    6.62102 in (6, 6.7)
#                            Si_SiO2_rough ....|.....    4.83544 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.26904 in (1.0, 10.0)
#                               SiO2_thick ....|.....    12.6791 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.36532e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.936361 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.61602e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......   0.925413 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.892127 in (0.0, 1.0)
#                           gmo_solv_rough ..|.......    2.98723 in (1.0, 10.0)
#                                gmo_thick .....|....    18.3677 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.48829e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........     0.8377 in (0.8, 1.2)
# step 958 cost 3.293(28)
# step 960 cost 3.293(28)
# step 961 cost 3.293(28)
# step 962 cost 3.293(28)
# step 963 cost 3.293(28)
# step 964 cost 3.293(28)
# step 965 cost 3.293(28)
# step 966 cost 3.293(28)
# step 967 cost 3.293(28)
# step 968 cost 3.293(28)
# step 970 cost 3.293(28)
# step 972 cost 3.293(28)
# step 974 cost 3.293(28)
# step 976 cost 3.293(28)
# step 978 cost 3.293(28)
# step 979 cost 3.293(28)
# step 981 cost 3.293(28)
# step 983 cost 3.293(28)
# step 985 cost 3.293(28)
# step 987 cost 3.293(28)
#                                Si_dd_bkg |......... 8.4504e-06 in (1e-10, 0.0001)
#                                Si_dd_int ....|.....    0.99173 in (0.8, 1.2)
#                                 ddod rho ........|.    6.62102 in (6, 6.7)
#                            Si_SiO2_rough ....|.....    4.83544 in (1.0, 10.0)
#                          SiO2_solv_rough ........|.    8.26904 in (1.0, 10.0)
#                               SiO2_thick ....|.....    12.6791 in (1.0, 30.0)
#                                Si_hd_bkg |......... 6.36532e-06 in (1e-10, 0.0001)
#                                Si_hd_int ...|......   0.936361 in (0.8, 1.2)
#                            Si_gmo_dd_bkg |......... 6.61602e-06 in (1e-10, 0.0001)
#                            Si_gmo_dd_int ...|......   0.925413 in (0.8, 1.2)
#                                   gmo_vf ........|.   0.892127 in (0.0, 1.0)
#                           gmo_solv_rough ..|.......    2.98723 in (1.0, 10.0)
#                                gmo_thick .....|....    18.3677 in (1.0, 30.0)
#                            Si_gmo_hd_bkg |......... 5.48829e-06 in (1e-10, 0.0001)
#                            Si_gmo_hd_int |.........     0.8377 in (0.8, 1.2)
# step 989 cost 3.293(28)
# step 990 cost 3.293(28)
# step 991 cost 3.293(28)
# step 992 cost 3.293(28)
# step 993 cost 3.293(28)
# step 994 cost 3.293(28)
# step 995 cost 3.293(28)
# step 996 cost 3.293(28)
# step 998 cost 3.293(28)
# step 999 cost 3.293(28)
# step 1000 cost 3.293(28)
# final chisq 3.293(28)
# === Uncertainty from curvature:     name   value(unc.) ===
#                                Si_dd_bkg   8.45(27)e-6
#                                Si_dd_int   0.9917(27)
#                                 ddod rho   6.6210(18)
#                            Si_SiO2_rough   4.8(35)
#                          SiO2_solv_rough   8.27(28)
#                               SiO2_thick   12.7(13)
#                                Si_hd_bkg   6.37(31)e-6
#                                Si_hd_int   0.936(11)
#                            Si_gmo_dd_bkg   6.6(13)e-6
#                            Si_gmo_dd_int   0.9254(27)
#                                   gmo_vf   0.892(44)
#                           gmo_solv_rough   3.0(30)
#                                gmo_thick   18.37(91)
#                            Si_gmo_hd_bkg   5.49(26)e-6
#                            Si_gmo_hd_int   0.838(10)
# ==========================================================

# %%
{k: v for k, v in zip(problem.labels(), problem.getp())}
# Out:
# {'Si_dd_bkg': np.float64(8.449288901387639e-06),
#  'Si_dd_int': np.float64(0.9917152574231037),
#  'ddod rho': np.float64(6.621010442058339),
#  'Si_SiO2_rough': np.float64(4.837599837953642),
#  'SiO2_solv_rough': np.float64(8.269340373923269),
#  'SiO2_thick': np.float64(12.677381498748511),
#  'Si_hd_bkg': np.float64(6.365664357328857e-06),
#  'Si_hd_int': np.float64(0.9363651227883555),
#  'Si_gmo_dd_bkg': np.float64(6.618007592123579e-06),
#  'Si_gmo_dd_int': np.float64(0.9254077203821265),
#  'gmo_vf': np.float64(0.8922178828555979),
#  'gmo_solv_rough': np.float64(2.9929300438770836),
#  'gmo_thick': np.float64(18.367507797498966),
#  'Si_gmo_hd_bkg': np.float64(5.486070672691205e-06),
#  'Si_gmo_hd_int': np.float64(0.8377129662732575)}

# %%
# the parameters are updated in the problem
np.testing.assert_allclose(problem.getp(), result.x)

# %% [markdown]
# # plot the data & model

# %%
# %matplotlib inline
for mod in problem.models:
    plt.errorbar(x=mod.probe.Q, y=mod.probe.R, yerr=mod.probe.dR, linestyle='None', marker='.')
    plt.plot(*mod.reflectivity(), color='k', zorder=10)
plt.xscale('log')
plt.yscale('log')

# %% [markdown]
# # Plot the structure of the vfp
#
# Use the vfp's plot method to plot the SLD, volume fraction profile and a stochastic simulation of the interface.
#
# In the current implementation, there is no way to plot the posterior, but this will be added.

# %%
dd_vfp_bare.plot() # equivalent to glob_obj.objectives[0].model.structure.components[1].plot()
plt.show()

# %%
dd_vfp_gmo.plot() # equivalent to glob_obj.objectives[2].model.structure.components[1].plot()
plt.show()
